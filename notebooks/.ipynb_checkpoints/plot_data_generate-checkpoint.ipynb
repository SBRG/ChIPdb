# %% [markdown]
# # Data Generation for Plots Notebook

# %% [markdown]
# This notebook generates data used to contruct `binding peak` tables and `venn diagrams` for ChIP-pro, as well as other  visuals. But before you run the notebook, make sure of the following:
#
# > Make sure to rename TF in the gff file to match the TF convention and not gene convension.

# %%
import numpy as np 
import pandas as pd
import glob
import urllib                      
import gzip
from collections import defaultdict

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Functions

# %% [markdown]
# ## Generate Binding peaks

# %% [markdown]
# This function assigns bindings peaks for each TF and fins the corresponsing gene targets using the `gene_info.csv` table.

# %%
def annotate_peaks(TF_name, TF_condition, peak_df,margin,gene_info):
    
    res_df = peak_df.copy()
#     TF = peak_df.condition_name[1][:4]
    for i,row in res_df.iterrows():
        pos = row['binding_peak_start']
        # Identify genes within MARGIN nt of binding peak
        close_genes = gene_info[(gene_info.start_codon_pos > pos-margin) 
                                & (gene_info.start_codon_pos < pos+margin)]
        for strand,group in close_genes.groupby('strand'):
            #Remove genes that are completely transcribed before binding peak
            if strand == '+':
                group = group[group.stop > pos]
            else:
                group = group[group.start < pos]

            operon = group.operon.unique()
            # Ensure that we're only identifying one operon on either side of binding peak
#             if len(operon) > 1:
#                 print (operon)

            # Get all genes in operon
            bnums = gene_info[gene_info.operon.isin(operon)].index
            
            ## Add gene information to dataframe
            if strand == '+':
                res_df.loc[i,'TU_p'] = ','.join(operon)
                res_df.loc[i,'genes_p'] = ','.join(bnums)
            else:
                res_df.loc[i,'TU_m'] = ','.join(operon)
                res_df.loc[i,'genes_m'] = ','.join(bnums)
    res_df['index'] = [TF_name +'-' + str(i) for i in range(1,peak_df.shape[0]+1)]
    res_df['condition'] = [ TF_name.lower() + " + " + TF_condition for i in peak_df.condition_name]
#     [peak_df.condition_name[2][:4]+' + '+peak_df.condition_name[1][5:8]]*peak_df.shape[0]
    cols = ['index','condition','binding_peak_start','binding_peak_end',
            'binding_peak_strength','TU_p','genes_p','TU_m','genes_m']
    return res_df.reindex(columns = cols)

# %% [markdown]
# ## Validate Binding Peaks

# %% [markdown]
# this function validates the accuracy of every gene target from the already indetified gene list for every binding site, identified from the previous function

# %%
def validate_peak_info(df,gene_info):
    locusTag = defaultdict(list)
    geneName = defaultdict(list)
    for i,row in df.iterrows():
        BP = row['binding_peak_start']
        idx_name = i
        genes = [row['genes_p'] , row['genes_m']]
        if ((genes[0] == '' or str(genes[0]) == 'nan') & (genes[1] == '' or str(genes[1]) == 'nan')):
            locusTag[idx_name].append('')
            geneName[idx_name].append('')
        for gene in genes:
            if gene == '' or str(gene) == 'nan':
                continue 
            gene_list = gene.split(',')
            for g in gene_list: 
                name = DF_gene_info.loc[g].gene_name 
                strand = DF_gene_info.loc[g].strand 
                start = DF_gene_info.loc[g].start
                stop = DF_gene_info.loc[g].stop
                if ((start > BP) & (stop > BP) & (strand == '+')) | ((start < BP) & (stop < BP) & (strand == '-')):
                        locusTag[idx_name].append(g)
                        geneName[idx_name].append(name)
                elif ((start < BP) & (stop > BP)) | ((start > BP) & (stop < BP)):
                    locusTag[idx_name].append(g)
                    geneName[idx_name].append(name)
                    
    for k, v in locusTag.items():
        if ((len(v) == 1) & (v[0] == '')): 
            locusTag[k] = ''
            continue
        genes = ','.join(locusTag[k])
        locusTag[k] = genes

    for k, v in geneName.items():
        if ((len(v) == 1) & (v[0] == '')): 
            geneName[k] = ''
            continue
        genes = ','.join(geneName[k])
        geneName[k] = genes

    df_complete = df.loc[:,['index','condition','binding_peak_start',
                            'binding_peak_end','binding_peak_strength']]
    df_complete['target_locus'] = locusTag.values()
    df_complete['target_genes'] = geneName.values()
    return df_complete

# %% [markdown]
# # Venn Diagrams

# %% [markdown]
# Make sure to update the list of `TF_names` as Ye adds more gff files into the dropbox

# %%
def Venn_data_gen(Peak_DF): 
    TF_name = Peak_DF['index'][1][:4]
    gene_list = [i for i in Peak_DF.target_genes if i != '']
    chip_data= ','.join(list(gene_list)).split(',')
    reg_data = TRN_data[TF_name]
    all_genes = [i  for i in chip_data if i not in reg_data] + reg_data
    
    
    TF = TF_name
    reg_genes=reg_data
    reg_only = []
    chip_genes=chip_data
    chip_only = []
    shared_genes=[]
    for i in all_genes: 
        if (i in reg_data) & (i not in chip_data):
            reg_only.append(i)
        elif (i in chip_data) & (i not in reg_data):
            chip_only.append(i)
        elif (i in chip_data) & (i in reg_data):
            shared_genes.append(i)
            
    values = [TF,
          len(reg_genes),
          len(reg_only),
          len(chip_genes),
          len(chip_only),
          len(shared_genes),
          len(all_genes)]
    
    index_name = ['TF',
              'reg_genes',
              'reg_only',
              'chip_genes',
              'chip_only',
              'shared_genes',
              'all_genes']
    
    genes = ['; '.join(precise2_TRN.source[precise2_TRN.index == TF_name].unique()),
         reg_genes,
         reg_only,
         chip_genes,
         chip_only,
         shared_genes,
         all_genes]
    
    same1 = defaultdict(list)
    for i in range(0,len(index_name)):
        same1[index_name[i]].append(values[i])

    finall = pd.DataFrame.from_dict(same1, orient='index', columns = ['value'])
    finall['list'] = genes
    for i, row in finall.iterrows(): 
        if row.value == 0:
            finall.list[i] = ''
    return finall

# %% [markdown]
# # Binding Width Histograms

# %%
def binding_width_gen(TF, peak_df,out_dir): 
    widths = pd.DataFrame(peak_df.binding_peak_end - peak_df.binding_peak_start + 1, columns=["binding_width"])
    widths.to_csv(out_dir+TF+'_widths.csv')

# %% [markdown]
# # Peak Position Scatter

# %%
def peak_position_gen(TF, final_annot_DF,out_dir): 
    peak_scatter_df = pd.DataFrame(columns=final_annot_DF.columns.to_list()+['gene'] +['normalized_dist'])
    counter=0

    for i in range(len(final_annot_DF)):
        peak = final_annot_DF.loc[i+1,:]
        peak_center = np.mean([peak.binding_peak_start, peak.binding_peak_end])

        for gene in peak.target_genes.split(","):
            gene_info = DF_gene_info[DF_gene_info.gene_name == gene]
            try:
                if gene_info.strand[0] == "-":
                    dist = float((gene_info.stop - peak_center)/gene_info.length)
                else:
                    dist = float((peak_center - gene_info.start)/gene_info.length)
                peak_scatter_df.loc[counter] = peak.to_list()+[gene, dist]
                counter+=1
            except:
                continue

    peak_scatter_df['binding_peak_center'] = peak_scatter_df.binding_peak_start/2 + peak_scatter_df.binding_peak_end/2
    peak_scatter_df.to_csv(out_dir+TF+'_positions.csv')

# %% [markdown]
# # E. coli

# %%
org_folder = "../data/e_coli/"

# %%
TF_list = pd.read_csv(org_folder+'TF_list.csv', index_col=0)

TF_list
# Out:
#                                TF          Organism          Strain Media  \
# index
# 0                            BaeR  Escherichia coli     K-12 MG1655    LB
# 1                            CpxR  Escherichia coli     K-12 MG1655    LB
# 2                             Cra  Escherichia coli     K-12 MG1655    M9
# 3                             Fur  Escherichia coli     K-12 MG1655    M9
# 4                            GadE  Escherichia coli     K-12 MG1655    M9
# 5                            GadW  Escherichia coli     K-12 MG1655    M9
# 6                            GadX  Escherichia coli     K-12 MG1655    M9
# 7                            KdpE  Escherichia coli     K-12 MG1655   TMA
# 8                            PhoB  Escherichia coli     K-12 MG1655   M9P
# 9                            RpoB  Escherichia coli     K-12 MG1655    M9
# 10                           YbaO  Escherichia coli     K-12 MG1655    M9
# 11                           YbaQ  Escherichia coli     K-12 MG1655    M9
# 12                           YdcI  Escherichia coli     K-12 MG1655    M9
# 13                           YddM  Escherichia coli     K-12 MG1655    M9
# 14                           YheO  Escherichia coli     K-12 MG1655    M9
# 15                           YiaG  Escherichia coli     K-12 MG1655    M9
# 16                           YieP  Escherichia coli     K-12 MG1655    M9
# 17                           YihL  Escherichia coli     K-12 MG1655    M9
# 18                           YihW  Escherichia coli     K-12 MG1655    M9
# 19                           YjdC  Escherichia coli     K-12 MG1655    M9
# 20                           YjhI  Escherichia coli     K-12 MG1655    M9
# 21                           YneJ  Escherichia coli     K-12 MG1655    M9
# 22                           YnfL  Escherichia coli     K-12 MG1655    M9
# 23                           YpdC  Escherichia coli     K-12 MG1655    M9
# 24                           YqhC  Escherichia coli     K-12 MG1655    M9
# 25                           ZraR  Escherichia coli     K-12 MG1655    LB
# 26                            Fur  Escherichia coli  O157:H7 EDL933    M9
# 27                            Fur  Escherichia coli         SMS-3-5    M9
# 28                            Fur  Escherichia coli          UMN026    M9
# 29                            Dps  Escherichia coli     K-12 MG1655    M9
# 30                            Fis  Escherichia coli     K-12 MG1655    M9
# 31                           GyrA  Escherichia coli     K-12 MG1655    M9
# 32                           GyrB  Escherichia coli     K-12 MG1655    M9
# 33                           H-NS  Escherichia coli     K-12 MG1655    M9
# 34                           HupA  Escherichia coli     K-12 MG1655    M9
# 35                           HupB  Escherichia coli     K-12 MG1655    M9
# 36                           InfA  Escherichia coli     K-12 MG1655    M9
# 37                           MukB  Escherichia coli     K-12 MG1655    M9
# 38                           RdgC  Escherichia coli     K-12 MG1655    M9
# 39                            Rob  Escherichia coli     K-12 MG1655    M9
# 40                           StpA  Escherichia coli     K-12 MG1655    M9
# 41                           TopA  Escherichia coli     K-12 MG1655    M9
# 42                            Tus  Escherichia coli     K-12 MG1655    M9
# 43                           NarL  Escherichia coli     K-12 MG1655    M9
# 44                           PuuR  Escherichia coli     K-12 MG1655    M9
# 45                           RcsA  Escherichia coli     K-12 MG1655    M9
# 46     RpoB (Cra and Crp KO exps)  Escherichia coli     K-12 MG1655    M9
#
#                             Supplement    genome_id organism_id  \
# index
# 0                                 EtOH  NC_000913_3      e_coli
# 1                                 EtOH  NC_000913_3      e_coli
# 2      Fructose, Galactose, or Acetate  NC_000913_3      e_coli
# 3                            Fe or DPD  NC_000913_3      e_coli
# 4                                  NaN  NC_000913_3      e_coli
# 5                                  NaN  NC_000913_3      e_coli
# 6                                  NaN  NC_000913_3      e_coli
# 7                                  KCl  NC_000913_3      e_coli
# 8                                  NaN  NC_000913_3      e_coli
# 9                            Fe or DPD  NC_000913_3      e_coli
# 10                                 NaN  NC_000913_3      e_coli
# 11                                 NaN  NC_000913_3      e_coli
# 12                                 NaN  NC_000913_3      e_coli
# 13                                 NaN  NC_000913_3      e_coli
# 14                                 NaN  NC_000913_3      e_coli
# 15                                 NaN  NC_000913_3      e_coli
# 16                                 3HP  NC_000913_3      e_coli
# 17                                 NaN  NC_000913_3      e_coli
# 18                                 NaN  NC_000913_3      e_coli
# 19                                 NaN  NC_000913_3      e_coli
# 20                                 NaN  NC_000913_3      e_coli
# 21                                 NaN  NC_000913_3      e_coli
# 22                                 NaN  NC_000913_3      e_coli
# 23                                 NaN  NC_000913_3      e_coli
# 24                                 NaN  NC_000913_3      e_coli
# 25                               ZnCl2  NC_000913_3      e_coli
# 26                                 NaN  AE_005174_2      e_coli
# 27                                 NaN  NC_010498_1      e_coli
# 28                                 NaN  CU_928163_2      e_coli
# 29                                 NaN  NC_000913_3      e_coli
# 30                                 NaN  NC_000913_3      e_coli
# 31                                 NaN  NC_000913_3      e_coli
# 32                                 NaN  NC_000913_3      e_coli
# 33                                 NaN  NC_000913_3      e_coli
# 34                                 NaN  NC_000913_3      e_coli
# 35                                 NaN  NC_000913_3      e_coli
# 36                                 NaN  NC_000913_3      e_coli
# 37                                 NaN  NC_000913_3      e_coli
# 38                                 NaN  NC_000913_3      e_coli
# 39                                 NaN  NC_000913_3      e_coli
# 40                                 NaN  NC_000913_3      e_coli
# 41                                 NaN  NC_000913_3      e_coli
# 42                                 NaN  NC_000913_3      e_coli
# 43                             Nitrate  NC_000913_3      e_coli
# 44                          Putrescine  NC_000913_3      e_coli
# 45                               Oxida  NC_000913_3      e_coli
# 46                             Acetate  NC_000913_3      e_coli
#
#        num_binding_sites  num_samples  num_cond       project  \
# index
# 0                    NaN            4         1           TCS
# 1                    NaN            2         1           TCS
# 2                    NaN            8         4      known_TF
# 3                    NaN            4         2      known_TF
# 4                    NaN            2         1      known_TF
# 5                    NaN            2         1      known_TF
# 6                    NaN            2         1      known_TF
# 7                    NaN            2         1           TCS
# 8                    NaN            4         1           TCS
# 9                    NaN            4         2      known_TF
# 10                   4.0            2         1          yTF1
# 11                  41.0            2         1          yTF1
# 12                  40.0            6         3          yTF1
# 13                  18.0            2         1          yTF1
# 14                   4.0            2         1          yTF1
# 15                   NaN            2         1          yTF1
# 16                  23.0            4         1          yTF1
# 17                   NaN            2         0          yTF2
# 18                   NaN            2         0          yTF2
# 19                   NaN            2         1          yTF1
# 20                   NaN            2         0          yTF2
# 21                   NaN            2         0          yTF2
# 22                   NaN            2         0          yTF2
# 23                   NaN            2         0          yTF2
# 24                   NaN            2         1          yTF2
# 25                   NaN            3         0           TCS
# 26                   NaN            2         0        EDL933
# 27                   NaN            2         0       SMS-3-5
# 28                   NaN            2         0        UMN026
# 29                   NaN            4         2  conformation
# 30                   NaN            4         2  conformation
# 31                   NaN            4         2  conformation
# 32                   NaN            4         2  conformation
# 33                   NaN            4         2  conformation
# 34                   NaN            4         2  conformation
# 35                   NaN            4         2  conformation
# 36                   NaN            4         2  conformation
# 37                   NaN            4         2  conformation
# 38                   NaN            4         2  conformation
# 39                   NaN            4         2  conformation
# 40                   NaN            4         2  conformation
# 41                   NaN            4         2  conformation
# 42                   NaN            4         2  conformation
# 43                   NaN            2         1          Misc
# 44                   NaN            2         1          Misc
# 45                   NaN            2         1          Misc
# 46                   NaN            6         3          Misc
#
#                                           binding tables  \
# index
# 0                      EtOH|baer_EtOH_binding_table.json
# 1                      EtOH|cpxr_EtOH_binding_table.json
# 2      acetate|cra_acetate_binding_table.json;M9|cra_...
# 3      fe|fur_fe_binding_table.json;dpd|fur_dpd_bindi...
# 4                          M9|gade_M9_binding_table.json
# 5                          M9|gadw_M9_binding_table.json
# 6                          M9|gadx_M9_binding_table.json
# 7                        KCl|kdpe_KCl_binding_table.json
# 8                        M9P|phob_M9P_binding_table.json
# 9      fe|rpob_fe_binding_table.json;dpd|rpob_dpd_bin...
# 10                                M9|ybao_M9_curated.gff
# 11                                M9|ybaq_M9_curated.gff
# 12     ph7|ydci_ph7_curated.gff;ph8|ydci_ph8_curated....
# 13                                M9|yddm_M9_curated.gff
# 14                                M9|yheo_M9_curated.gff
# 15                                M9|yiag_M9_curated.gff
# 16                                M9|yiep_M9_curated.gff
# 17                                                   NaN
# 18                                                   NaN
# 19                                M9|yjdc_M9_curated.gff
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                M9|yqhc_M9_curated.gff
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29     sta|dps_sta_curated.gff;expo|dps_expo_curated.gff
# 30     expo|fis_expo_curated.gff;sta|fis_sta_curated.gff
# 31     sta|gyra_sta_curated.gff;expo|gyra_expo_curate...
# 32     expo|gyrb_expo_curated.gff;sta|gyrb_sta_curate...
# 33     expo|h-ns_expo_curated.gff;sta|h-ns_sta_curate...
# 34     sta|hupa_sta_curated.gff;expo|hupa_expo_curate...
# 35     sta|hupb_sta_curated.gff;expo|hupb_expo_curate...
# 36     sta|infa_sta_curated.gff;expo|infa_expo_curate...
# 37     sta|mukb_sta_curated.gff;expo|mukb_expo_curate...
# 38     sta|rdgc_sta_curated.gff;expo|rdgc_expo_curate...
# 39     expo|rob_expo_curated.gff;sta|rob_sta_curated.gff
# 40     expo|stpa_expo_curated.gff;sta|stpa_sta_curate...
# 41     expo|topa_expo_curated.gff;sta|topa_sta_curate...
# 42     sta|tus_sta_curated.gff;expo|tus_expo_curated.gff
# 43                      nitrate|narl_nitrate_curated.gff
# 44                putrescine|puur_putrescine_curated.gff
# 45                          oxida|rcsa_oxida_curated.gff
# 46     crp-ko ace|rpob (cra and crp ko exps)_crp-ko a...
#
#                 BWcond1_1_name             BWcond1_1           BWcond1_2_name  \
# index
# 0                bio-rep1 – R1     BaeR_R1_S31_R1.bw            bio-rep1 – R2
# 1                           R1       CpxRR1_S1_R1.bw                       R2
# 2                     Glu – R1          cra_glu_1.bw                 Glu – R2
# 3                      Fe – R1           fur_fe_1.bw                  Fe – R2
# 4                           R1             gade_1.bw                       R2
# 5                           R1             gadw_1.bw                       R2
# 6                           R1             gadx_1.bw                       R2
# 7                           R1    KdpeE_R2_S34_R1.bw                       R2
# 8                bio-rep1 – R1      PhoB_1_S16_R1.bw            bio-rep1 – R2
# 9                      Fe – R1           rpob_fe1.bw                  Fe – R2
# 10                          R1             ybao_1.bw                       R2
# 11                          R1             ybaq_1.bw                       R2
# 12                    pH5 – R1         ydci_ph5_1.bw                 pH5 – R2
# 13                          R1             yddm_1.bw                       R2
# 14                          R1             yheo_1.bw                       R2
# 15                          R1             yiag_1.bw                       R2
# 16                          R1             yiep_1.bw                       R2
# 17                          R1             yihl_1.bw                       R2
# 18                          R1             yihw_1.bw                       R2
# 19                          R1             yjdc_1.bw                       R2
# 20                          R1             yjhi_1.bw                       R2
# 21                          R1             ynej_1.bw                       R2
# 22                          R1             ynfl_1.bw                       R2
# 23                          R1             ypdc_1.bw                       R2
# 24                          R1             yqhc_1.bw                       R2
# 25               bio-rep1 – R1       ZraR_1_S3_R1.bw            bio-rep1 – R2
# 26                          R1    edl933furfinal1.bw                       R2
# 27                          R1       smsfurfinal1.bw                       R2
# 28                          R1    umn026furfinal1.bw                       R2
# 29     exponential growth – R1         dps_expo_1.bw  exponential growth – R2
# 30     exponential growth – R1         fis_expo_1.bw  exponential growth – R2
# 31     exponential growth – R1        gyra_expo_1.bw  exponential growth – R2
# 32     exponential growth – R1        gyrb_expo_1.bw  exponential growth – R2
# 33     exponential growth – R1         hns_expo_1.bw  exponential growth – R2
# 34     exponential growth – R1        hupa_expo_1.bw  exponential growth – R2
# 35     exponential growth – R1        hupb_expo_1.bw  exponential growth – R2
# 36     exponential growth – R1        infa_expo_1.bw  exponential growth – R2
# 37     exponential growth – R1        mukb_expo_1.bw  exponential growth – R2
# 38     exponential growth – R1        rdgc_expo_1.bw  exponential growth – R2
# 39     exponential growth – R1         rob_expo_1.bw  exponential growth – R2
# 40     exponential growth – R1        stpa_expo_1.bw  exponential growth – R2
# 41     exponential growth – R1        topa_expo_1.bw  exponential growth – R2
# 42     exponential growth – R1         tus_expo_1.bw  exponential growth – R2
# 43                          R1     narl_nitrate_1.bw                       R2
# 44                          R1  puur_putrescine_1.bw                       R2
# 45                          R1       rcsa_oxida_1.bw                       R2
# 46           control (WT) – R1   mg1655_ace_rpob1.bw        control (WT) – R2
#
#                   BWcond1_2          BWcond2_1_name            BWcond2_1  \
# index
# 0         BaeR_R1_S31_R2.bw           bio-rep2 – R1   BaerR_R2_S32_R1.bw
# 1           CpxRR2_S2_R2.bw                     NaN                  NaN
# 2              cra_glu_2.bw                Fru – R1         cra_fru_1.bw
# 3               fur_fe_2.bw                DPD – R1         fur_dpd_1.bw
# 4                 gade_2.bw                     NaN                  NaN
# 5                 gadw_2.bw                     NaN                  NaN
# 6                 gadx_2.bw                     NaN                  NaN
# 7        KdpeE_R2_S34_R2.bw                     NaN                  NaN
# 8          PhoB_1_S16_R2.bw           bio-rep2 – R1      PhoB_2_S6_R1.bw
# 9               rpob_fe2.bw                DPD – R1         rpob_dpd1.bw
# 10                ybao_2.bw                     NaN                  NaN
# 11                ybaq_2.bw                     NaN                  NaN
# 12            ydci_ph5_2.bw                pH7 – R1        ydci_ph7_1.bw
# 13                yddm_2.bw                     NaN                  NaN
# 14                yheo_2.bw                     NaN                  NaN
# 15                yiag_2.bw                     NaN                  NaN
# 16                yiep_2.bw                3HP – R1        yiep_3hp_1.bw
# 17                yihl_2.bw                     NaN                  NaN
# 18                yihw_2.bw                     NaN                  NaN
# 19                yjdc_2.bw                     NaN                  NaN
# 20                yjhi_2.bw                     NaN                  NaN
# 21                ynej_2.bw                     NaN                  NaN
# 22                ynfl_2.bw                     NaN                  NaN
# 23                ypdc_2.bw                     NaN                  NaN
# 24                yqhc_2.bw                     NaN                  NaN
# 25          ZraR_1_S3_R2.bw           bio-rep2 – R1      ZraR_2_S4_R1.bw
# 26       edl933furfinal2.bw                     NaN                  NaN
# 27          smsfurfinal2.bw                     NaN                  NaN
# 28       umn026furfinal2.bw                     NaN                  NaN
# 29            dps_expo_2.bw  stationary growth – R1         dps_sta_1.bw
# 30            fis_expo_2.bw  stationary growth – R1         fis_sta_1.bw
# 31           gyra_expo_2.bw  stationary growth – R1        gyra_sta_1.bw
# 32           gyrb_expo_2.bw  stationary growth – R1        gyrb_sta_1.bw
# 33            hns_expo_2.bw  stationary growth – R1         hns_sta_1.bw
# 34           hupa_expo_2.bw  stationary growth – R1        hupa_sta_1.bw
# 35           hupb_expo_2.bw  stationary growth – R1        hupb_sta_1.bw
# 36           infa_expo_2.bw  stationary growth – R1        infa_sta_1.bw
# 37           mukb_expo_2.bw  stationary growth – R1        mukb_sta_1.bw
# 38           rdgc_expo_2.bw  stationary growth – R1        rdgc_sta_1.bw
# 39            rob_expo_2.bw  stationary growth – R1         rob_sta_1.bw
# 40           stpa_expo_2.bw  stationary growth – R1        stpa_sta_1.bw
# 41           topa_expo_2.bw  stationary growth – R1        topa_sta_1.bw
# 42            tus_expo_2.bw  stationary growth – R1         tus_sta_1.bw
# 43        narl_nitrate_2.bw                     NaN                  NaN
# 44     puur_putrescine_2.bw                     NaN                  NaN
# 45          rcsa_oxida_2.bw                     NaN                  NaN
# 46      mg1655_ace_rpob2.bw             cra-KO – R1  cra_ko_ace_rpob1.bw
#
#                BWcond2_2_name            BWcond2_2 BWcond3_1_name  \
# index
# 0               bio-rep2 – R2   BaerR_R2_S32_R2.bw            NaN
# 1                         NaN                  NaN            NaN
# 2                    Fru – R2         cra_fru_2.bw       Gal – R1
# 3                    DPD – R2         fur_dpd_2.bw            NaN
# 4                         NaN                  NaN            NaN
# 5                         NaN                  NaN            NaN
# 6                         NaN                  NaN            NaN
# 7                         NaN                  NaN            NaN
# 8               bio-rep2 – R2      PhoB_2_S6_R2.bw            NaN
# 9                    DPD – R2         rpob_dpd2.bw            NaN
# 10                        NaN                  NaN            NaN
# 11                        NaN                  NaN            NaN
# 12                   pH7 – R2        ydci_ph7_2.bw       pH8 – R1
# 13                        NaN                  NaN            NaN
# 14                        NaN                  NaN            NaN
# 15                        NaN                  NaN            NaN
# 16                   3HP – R2        yiep_3hp_2.bw            NaN
# 17                        NaN                  NaN            NaN
# 18                        NaN                  NaN            NaN
# 19                        NaN                  NaN            NaN
# 20                        NaN                  NaN            NaN
# 21                        NaN                  NaN            NaN
# 22                        NaN                  NaN            NaN
# 23                        NaN                  NaN            NaN
# 24                        NaN                  NaN            NaN
# 25                        NaN                  NaN            NaN
# 26                        NaN                  NaN            NaN
# 27                        NaN                  NaN            NaN
# 28                        NaN                  NaN            NaN
# 29     stationary growth – R2         dps_sta_2.bw            NaN
# 30     stationary growth – R2         fis_sta_2.bw            NaN
# 31     stationary growth – R2        gyra_sta_2.bw            NaN
# 32     stationary growth – R2        gyrb_sta_2.bw            NaN
# 33     stationary growth – R2         hns_sta_2.bw            NaN
# 34     stationary growth – R2        hupa_sta_2.bw            NaN
# 35     stationary growth – R2        hupb_sta_2.bw            NaN
# 36     stationary growth – R2        infa_sta_2.bw            NaN
# 37     stationary growth – R2        mukb_sta_2.bw            NaN
# 38     stationary growth – R2        rdgc_sta_2.bw            NaN
# 39     stationary growth – R2         rob_sta_2.bw            NaN
# 40     stationary growth – R2        stpa_sta_2.bw            NaN
# 41     stationary growth – R2        topa_sta_2.bw            NaN
# 42     stationary growth – R2         tus_sta_2.bw            NaN
# 43                        NaN                  NaN            NaN
# 44                        NaN                  NaN            NaN
# 45                        NaN                  NaN            NaN
# 46                cra-KO – R2  cra_ko_ace_rpob2.bw    crp-KO – R1
#
#                  BWcond3_1 BWcond3_2_name            BWcond3_2 BWcond4_1_name  \
# index
# 0                      NaN            NaN                  NaN            NaN
# 1                      NaN            NaN                  NaN            NaN
# 2             cra_gal_1.bw       Gal – R2         cra_gal_2.bw       Ace – R1
# 3                      NaN            NaN                  NaN            NaN
# 4                      NaN            NaN                  NaN            NaN
# 5                      NaN            NaN                  NaN            NaN
# 6                      NaN            NaN                  NaN            NaN
# 7                      NaN            NaN                  NaN            NaN
# 8                      NaN            NaN                  NaN            NaN
# 9                      NaN            NaN                  NaN            NaN
# 10                     NaN            NaN                  NaN            NaN
# 11                     NaN            NaN                  NaN            NaN
# 12           ydci_ph8_1.bw       pH8 – R2        ydci_ph8_2.bw            NaN
# 13                     NaN            NaN                  NaN            NaN
# 14                     NaN            NaN                  NaN            NaN
# 15                     NaN            NaN                  NaN            NaN
# 16                     NaN            NaN                  NaN            NaN
# 17                     NaN            NaN                  NaN            NaN
# 18                     NaN            NaN                  NaN            NaN
# 19                     NaN            NaN                  NaN            NaN
# 20                     NaN            NaN                  NaN            NaN
# 21                     NaN            NaN                  NaN            NaN
# 22                     NaN            NaN                  NaN            NaN
# 23                     NaN            NaN                  NaN            NaN
# 24                     NaN            NaN                  NaN            NaN
# 25                     NaN            NaN                  NaN            NaN
# 26                     NaN            NaN                  NaN            NaN
# 27                     NaN            NaN                  NaN            NaN
# 28                     NaN            NaN                  NaN            NaN
# 29                     NaN            NaN                  NaN            NaN
# 30                     NaN            NaN                  NaN            NaN
# 31                     NaN            NaN                  NaN            NaN
# 32                     NaN            NaN                  NaN            NaN
# 33                     NaN            NaN                  NaN            NaN
# 34                     NaN            NaN                  NaN            NaN
# 35                     NaN            NaN                  NaN            NaN
# 36                     NaN            NaN                  NaN            NaN
# 37                     NaN            NaN                  NaN            NaN
# 38                     NaN            NaN                  NaN            NaN
# 39                     NaN            NaN                  NaN            NaN
# 40                     NaN            NaN                  NaN            NaN
# 41                     NaN            NaN                  NaN            NaN
# 42                     NaN            NaN                  NaN            NaN
# 43                     NaN            NaN                  NaN            NaN
# 44                     NaN            NaN                  NaN            NaN
# 45                     NaN            NaN                  NaN            NaN
# 46     crp_ko_ace_rpob1.bw    crp-KO – R2  crp_ko_ace_rpob2.bw            NaN
#
#           BWcond4_1 BWcond4_2_name     BWcond4_2
# index
# 0               NaN            NaN           NaN
# 1               NaN            NaN           NaN
# 2      cra_ace_1.bw       Ace – R2  cra_ace_2.bw
# 3               NaN            NaN           NaN
# 4               NaN            NaN           NaN
# 5               NaN            NaN           NaN
# 6               NaN            NaN           NaN
# 7               NaN            NaN           NaN
# 8               NaN            NaN           NaN
# 9               NaN            NaN           NaN
# 10              NaN            NaN           NaN
# 11              NaN            NaN           NaN
# 12              NaN            NaN           NaN
# 13              NaN            NaN           NaN
# 14              NaN            NaN           NaN
# 15              NaN            NaN           NaN
# 16              NaN            NaN           NaN
# 17              NaN            NaN           NaN
# 18              NaN            NaN           NaN
# 19              NaN            NaN           NaN
# 20              NaN            NaN           NaN
# 21              NaN            NaN           NaN
# 22              NaN            NaN           NaN
# 23              NaN            NaN           NaN
# 24              NaN            NaN           NaN
# 25              NaN            NaN           NaN
# 26              NaN            NaN           NaN
# 27              NaN            NaN           NaN
# 28              NaN            NaN           NaN
# 29              NaN            NaN           NaN
# 30              NaN            NaN           NaN
# 31              NaN            NaN           NaN
# 32              NaN            NaN           NaN
# 33              NaN            NaN           NaN
# 34              NaN            NaN           NaN
# 35              NaN            NaN           NaN
# 36              NaN            NaN           NaN
# 37              NaN            NaN           NaN
# 38              NaN            NaN           NaN
# 39              NaN            NaN           NaN
# 40              NaN            NaN           NaN
# 41              NaN            NaN           NaN
# 42              NaN            NaN           NaN
# 43              NaN            NaN           NaN
# 44              NaN            NaN           NaN
# 45              NaN            NaN           NaN
# 46              NaN            NaN           NaN

# %%
strain = 'NC_000913_3'
DF_gene_info = pd.read_csv(org_folder+strain+'/annotation/gene_info.csv',index_col=0)
DF_gene_info['start_codon_pos'] = [row.start if row.strand == '+' else row.stop for idx,row in DF_gene_info.iterrows()]
TRN = pd.read_csv(org_folder+strain+'/annotation/trn.csv',index_col=0)

DF_gene_info
# Out:
#          start     stop strand gene_name  length   operon  \
# b0001      189      255      +      thrL      66  thrLABC
# b0002      336     2799      +      thrA    2463  thrLABC
# b0003     2800     3733      +      thrB     933  thrLABC
# b0004     3733     5020      +      thrC    1287  thrLABC
# b0005     5233     5530      +      yaaX     297     yaaX
# ...        ...      ...    ...       ...     ...      ...
# b4399  4636695  4638120      +      creC    1425  creABCD
# b4400  4638177  4639530      +      creD    1353  creABCD
# b4401  4639589  4640306      -      arcA     717     arcA
# b4402  4640401  4640542      +      yjjY     141     yjjY
# b4403  4640941  4641628      +      yjtD     687     yjtD
#
#                                                    cog  start_codon_pos
# b0001                                No COG Annotation              189
# b0002                                No COG Annotation              336
# b0003              Amino acid transport and metabolism             2800
# b0004              Amino acid transport and metabolism             3733
# b0005                                 Function unknown             5233
# ...                                                ...              ...
# b4399                   Signal transduction mechanisms          4636695
# b4400                               Defense mechanisms          4638177
# b4401                   Signal transduction mechanisms          4640306
# b4402                                 Function unknown          4640401
# b4403  Translation, ribosomal structure and biogenesis          4640941
#
# [4386 rows x 8 columns]

# %%
for TF_index in range(len(TF_list)):

    TF_name= TF_list.TF[TF_index].lower()
    strain = TF_list.genome_id[TF_index]

    #find files and format
    curated_loc = glob.glob(org_folder+strain+"/curated_input/"+TF_name+"_*.gff")
    curated_files = [i.split("/")[-1] for i in curated_loc]
    curated_cond = [i.split("_")[1] for i in curated_files]
    table_string =";".join([curated_cond[i]+"|"+TF_name+"_"+curated_cond[i]+'_binding_table.json' for i in range(len(curated_loc))])
    TF_list.loc[TF_index, 'binding tables'] = table_string
    TF_list.loc[TF_index, 'num_cond'] = len(curated_loc)
    
    #write plot data files to folders
    for file_index in range(len(curated_files)):
        try:
            file = curated_files[file_index]
            df = pd.read_csv(org_folder+strain+"/curated_input/"+file,index_col=0, 
                                     delimiter='\t', header=None, 
                                     names = ['ref','condition', 'condition_name', 
                                              "binding_peak_start",'binding_peak_end', 
                                              'binding_peak_strength', 'direction', '.','ID'])
            df = df.set_index(pd.Series(range(1,len(df)+1)))
            peak_annot_DF = annotate_peaks(TF_list.TF[TF_index], curated_cond[file_index], df, 500, DF_gene_info)
            final_annot_DF = validate_peak_info(peak_annot_DF,DF_gene_info)
            final_annot_DF.to_json(org_folder+strain+"/table/"+TF_name+"_"+curated_cond[file_index]+'_binding_table.json',orient='records')
            binding_width_gen(TF_list.TF[TF_index], df, org_folder+strain+"/binding_widths/")
            peak_position_gen(TF_list.TF[TF_index], final_annot_DF, org_folder+strain+"/positions/")
        except:
            continue
# Out:
# ['raiA' 'pheLA']
# ['raiA' 'pheLA']
# ['arfA' 'yhdN-zntR']
# ['rpsLG-fusA-tufA' 'yheO-tusDCB']
# ['yiaG' 'cspA']
# ['yjfN' 'bsmA']
# ['yjfN' 'bsmA']
# ['topAI-yjhQ' 'yjhX']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# ['b0150,b0151,b0152,b0153', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b0281']
# [nan, 'b0610']
# [nan, 'b0610']
# [nan, 'b0613,b0614,b0615,b0616,b0617,b0618']
# ['b0623', nan]
# ['b0623', nan]
# ['b0681,b0682', nan]
# [nan, 'b0683,b4637,b0684']
# [nan, 'b0720']
# ['b0733,b0734', nan]
# ['b0972,b0973,b0974,b0975,b0976,b0977', 'b0970']
# [nan, 'b1521']
# [nan, 'b1521']
# ['b1655', 'b1654']
# ['b1661', nan]
# ['b1677', nan]
# [nan, 'b1743']
# [nan, 'b1743']
# [nan, 'b1743']
# [nan, 'b1838']
# [nan, nan]
# [nan, 'b1908']
# [nan, 'b1908']
# [nan, 'b1908']
# [nan, 'b1908']
# [nan, nan]
# ['b1982', nan]
# ['b1982', nan]
# ['b2074,b2075,b2076,b2077,b2078,b2079', 'b4668']
# ['b2074,b2075,b2076,b2077,b2078,b2079', 'b4668']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# ['b2172', nan]
# ['b2172', nan]
# ['b2175', nan]
# ['b2175', nan]
# ['b2175', nan]
# ['b2216,b2217', 'b2215']
# ['b2232', 'b2231']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# ['b2380,b2381,b2382', 'b2379']
# [nan, 'b2400']
# ['b2448,b2449', nan]
# ['b2448,b2449', nan]
# ['b2448,b2449', nan]
# ['b2450', nan]
# ['b2471,b2472,b4547', 'b4606']
# ['b2471,b2472,b4547', 'b4606']
# [nan, 'b2476']
# ['b2479', 'b2477,b2478']
# ['b2504', 'b2503']
# ['b2597', nan]
# ['b2597', nan]
# ['b2597', nan]
# ['b2597,b2598,b2599', nan]
# ['b2597,b2598,b2599', nan]
# ['b2598,b2599', nan]
# [nan, nan]
# ['b2622', nan]
# ['b2622', nan]
# ['b2622', nan]
# ['b2775,b2776', 'b2774']
# ['b2801,b2802,b2803,b2804,b2805', nan]
# [nan, 'b2808']
# ['b2810,b2811', 'b2808']
# ['b2837', 'b2835,b2836']
# [nan, 'b2863']
# ['b2912', nan]
# ['b2912', nan]
# ['b3042', 'b3041']
# ['b3042', 'b3041']
# ['b3065,b3066,b3067', 'b3064']
# [nan, 'b3068']
# ['b3088', nan]
# ['b3093', 'b3091,b3092']
# ['b3094', nan]
# [nan, 'b4471,b3113,b3114,b3115,b3116,b3117,b3118']
# ['b3119', 'b4471,b3113,b3114,b3115,b3116,b3117,b3118']
# [nan, 'b3162,b4685']
# [nan, 'b3163']
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3175']
# [nan, 'b3175']
# ['b3180', 'b3178,b3179']
# [nan, 'b3228,b3229']
# [nan, 'b3228,b3229']
# ['b3267', nan]
# ['b3267', nan]
# ['b3267', nan]
# [nan, 'b3280,b3281,b3282,b3283']
# [nan, 'b3280,b3281,b3282,b3283']
# [nan, 'b3284']
# [nan, 'b4550,b3292,b3293']
# [nan, 'b3292,b3293']
# [nan, 'b3299,b3300,b3301,b3302,b3303,b3304,b3305,b3306,b3307,b3308,b3309,b3310']
# [nan, 'b3339,b3340,b3341,b3342']
# [nan, 'b3339,b3340,b3341,b3342,b3343,b3344,b3345,b3346']
# ['b3357', 'b3356']
# ['b3357', 'b3356']
# ['b3364', 'b3363']
# ['b3364', 'b3363']
# ['b3364', 'b3363']
# [nan, nan]
# ['b3398', 'b3397']
# [nan, 'b4476,b3437,b3438']
# ['b3459', 'b3454,b3455,b3456,b3457,b3458']
# ['b3459', 'b3454,b3455,b3456,b3457,b3458']
# [nan, 'b3461']
# [nan, 'b3461']
# [nan, 'b3461']
# [nan, 'b3461']
# [nan, 'b3497,b3498']
# ['b3499', 'b3497,b3498']
# ['b3499', 'b3497,b3498']
# ['b3536,b3537,b3538', nan]
# ['b3536,b3537,b3538', nan]
# [nan, 'b3540,b3541,b3542,b3543,b3544']
# ['b3555,b3556', nan]
# ['b3556', nan]
# ['b3602', 'b4554']
# ['b3619,b3620,b3621,b3622', 'b3618']
# ['b3633,b3634', 'b3623,b3624,b3625,b3626,b3627,b3628,b3629,b3630,b3631,b3632']
# [nan, 'b3635,b3636,b3637,b3638']
# [nan, 'b3635,b3636,b3637,b3638']
# ['b3640,b3641', nan]
# ['b3684', 'b4556,b3683']
# ['b3688', 'b3686,b3687']
# ['b3707,b3708,b3709', nan]
# ['b3715', 'b3714']
# [nan, 'b3718,b3719,b3720']
# [nan, 'b3754,b3755']
# [nan, 'b3754,b3755']
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', 'b3765']
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', 'b3765']
# ['b3781', 'b3780']
# ['b3781', 'b3780']
# ['b3783', 'b3780']
# ['b3783', nan]
# [nan, nan]
# ['b3871', 'b3868,b3869,b3870']
# ['b3895', 'b3891,b3892,b3893,b3894']
# ['b4484', 'b3911,b3912']
# [nan, 'b3929,b3930']
# [nan, 'b3974']
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3989', nan]
# [nan, 'b4005,b4006']
# ['b4140', 'b4138,b4139']
# ['b4147', 'b4146']
# ['b4155', 'b4151,b4152,b4153,b4154']
# [nan, nan]
# ['b4167,b4168,b4169,b4170,b4171,b4172,b4173,b4174,b4175', nan]
# ['b4167,b4168,b4169,b4170,b4171,b4172,b4173,b4174,b4175', nan]
# ['b4167,b4168,b4169,b4170,b4171,b4172,b4173,b4174,b4175', nan]
# ['b4190', 'b4188,b4189']
# ['b4190', 'b4188,b4189']
# ['b4200,b4201,b4202,b4203', 'b4199']
# ['b4217', 'b4216']
# [nan, 'b4307,b4566']
# ['b4322,b4323', 'b4321']
# ['b4342', nan]
# ['b4351', 'b4348,b4349,b4350']
# [nan, nan]
# ['b4381,b4382,b4383,b4384', nan]
# ['b4402', 'b4401']
# ['b4402', 'b4401']
# ['b4402', 'b4401']
# ['b4403', 'b4401']
# ['yaiI' 'aroL-yaiA-aroM']
# ['raiA' 'pheLA']
# ['ygeG' 'ygeH']
# ['b0113,b0114,b0115,b0116', 'b0112']
# ['b0118', 'b0117']
# ['b0161', nan]
# [nan, 'b0278,b0279']
# [nan, 'b0278,b0279']
# [nan, 'b0278,b0279']
# [nan, 'b0281']
# [nan, 'b0281']
# ['b0287', 'b0283,b0284,b0285,b0286']
# [nan, nan]
# ['b0387,b0388,b0389,b0390', nan]
# ['b0388,b0389,b0390', nan]
# [nan, 'b0460,b0461']
# [nan, 'b0602']
# [nan, 'b0610']
# [nan, 'b0629']
# [nan, 'b0632']
# [nan, 'b0656']
# ['b0733,b0734', nan]
# ['b0733,b0734', nan]
# ['b0925', nan]
# ['b0953', nan]
# [nan, 'b0970']
# ['b4490_1,b4490_2', nan]
# [nan, 'b1056,b1057']
# ['b1177', nan]
# ['b1205', 'b1203,b1204']
# ['b1205', 'b1203,b1204']
# ['b4522,b4523', nan]
# [nan, 'b1552']
# [nan, 'b1552']
# ['b1586', 'b1585']
# [nan, 'b1593,b1594']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# ['b1785', nan]
# ['b1814', nan]
# [nan, 'b1891,b1892']
# [nan, 'b1891,b1892']
# ['b1973', nan]
# ['b2175', nan]
# ['b2216,b2217', 'b2215']
# ['b2232', 'b2231']
# ['b2232', 'b2231']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# ['b2448,b2449', nan]
# ['b2471,b2472,b4547', 'b4606']
# ['b2504', 'b2503']
# ['b2504', 'b2503']
# ['b2574', 'b2570,b2571,b2572,b2573']
# ['b2597,b2598,b2599', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b2650']
# [nan, 'b2754,b2755,b2756,b2757,b2758,b2759,b2760']
# ['b2794', 'b2793']
# ['b2851', nan]
# ['b2851,b2852', nan]
# ['b2910', 'b2906,b2907,b2908,b2909']
# ['b2910', 'b2906,b2907,b2908,b2909']
# ['b2912', nan]
# ['b2912', nan]
# [nan, 'b2921']
# ['b3035,b3037,b3038', nan]
# ['b3093', 'b3091,b3092']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3196,b3197,b3198,b3199,b3200,b3201,b3202,b3203,b3204,b3205,b3206', 'b3191,b3192,b3193,b3194,b3195']
# ['b3212,b3213,b3214', nan]
# [nan, 'b3228,b3229']
# ['b3263', nan]
# [nan, 'b3299,b3300,b3301,b3302,b3303,b3304,b3305,b3306,b3307,b3308,b3309,b3310']
# ['b3364', 'b3363']
# ['b3398', 'b3397']
# ['b3426', 'b3423_2,b3423_1,b3424,b3425']
# [nan, 'b4476,b3437,b3438']
# [nan, 'b3461']
# ['b3493', 'b3492']
# ['b3493', 'b3492']
# ['b3499', 'b3497,b3498']
# [nan, 'b3546']
# ['b3556', nan]
# ['b3575,b3576,b3577,b3578,b3579,b3580,b3581,b3582,b3583', nan]
# [nan, 'b3589']
# ['b3603,b3604,b3605', nan]
# ['b3619,b3620,b3621,b3622', 'b3618']
# [nan, 'b3623,b3624,b3625,b3626,b3627,b3628,b3629,b3630,b3631,b3632']
# ['b3707,b3708,b3709', nan]
# ['b3707,b3708,b3709', nan]
# [nan, 'b3731,b3732,b3733,b3734,b3735,b3736,b3737,b3738,b3739']
# [nan, 'b3731,b3732,b3733,b3734,b3735,b3736,b3737,b3738,b3739']
# [nan, 'b3801']
# [nan, nan]
# ['b3859,b3860', 'b3856,b3857']
# [nan, 'b3878']
# ['b3895', 'b3891,b3892,b3893,b3894']
# ['b4484', 'b3911,b3912']
# ['b4484', 'b3911,b3912']
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# [nan, 'b4005,b4006']
# [nan, 'b4031']
# [nan, 'b4031']
# ['b4038_1,b4038_2,b4038_3', nan]
# ['b4039,b4040', nan]
# ['b4039,b4040', nan]
# ['b4217', 'b4216']
# ['b4314,b4315,b4316,b4317,b4318,b4319,b4320', nan]
# ['b4314,b4315,b4316,b4317,b4318,b4319,b4320', nan]
# ['b4314,b4315,b4316,b4317,b4318,b4319,b4320', nan]
# ['b4355', 'b4354']
# ['b4381,b4382,b4383,b4384', nan]
# ['b4403', nan]
# ['yeaC' 'msrB']
# ['b0113,b0114,b0115,b0116', 'b0112']
# ['b0150,b0151,b0152,b0153', nan]
# [nan, nan]
# [nan, nan]
# ['b1136', 'b1134,b1135']
# ['b1242', 'b1241']
# ['b1676', 'b1675']
# [nan, 'b1777,b1778']
# ['b1779,b1780', 'b1778']
# ['b1817,b1818,b1819', 'b1816']
# [nan, 'b1838']
# [nan, 'b1850,b1851']
# [nan, 'b1908']
# [nan, nan]
# [nan, nan]
# [nan, 'b1985']
# [nan, 'b2007']
# [nan, nan]
# ['b2170', 'b2167,b2168,b2169']
# [nan, 'b2181']
# [nan, 'b2181']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# ['b2389', 'b2388']
# [nan, nan]
# ['b2415,b2416,b2417', nan]
# ['b2448,b2449', nan]
# [nan, nan]
# [nan, 'b2556']
# ['b2597', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b2787,b2788,b2789']
# [nan, 'b2921']
# [nan, 'b2921']
# [nan, 'b2925,b2926,b2927']
# [nan, 'b2968,b2969']
# ['b3065,b3066,b3067', 'b3064']
# [nan, 'b3162,b4685']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3173']
# ['b3187', 'b3183,b3184,b3185,b3186']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# ['b3357', 'b3356']
# ['b3365,b3366,b3367,b3368', nan]
# [nan, 'b3376,b3377,b3378,b3379,b3380,b3381']
# ['b3476,b3477,b3478,b3479,b3480,b3481', nan]
# ['b3476,b3477,b3478,b3479,b3480,b3481', nan]
# [nan, nan]
# ['b3556', nan]
# ['b3612,b3613,b3614', 'b3608,b3609,b3610,b3611']
# [nan, 'b3667,b3668,b3669,b3670,b3671,b3672']
# ['b3710', nan]
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', 'b3765']
# ['b3783', nan]
# ['b3800', nan]
# [nan, nan]
# ['b3916', nan]
# [nan, 'b3919']
# [nan, 'b3919']
# ['b3980', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b4014,b4015,b4016', nan]
# ['b4233', 'b4232']
# [nan, 'b4239,b4240']
# [nan, 'b4244,b4245,b4246']
# ['b0113,b0114,b0115,b0116', 'b0112']
# ['b0150,b0151,b0152,b0153', nan]
# ['b0217', nan]
# [nan, 'b0281']
# [nan, nan]
# ['b1136', 'b1134,b1135']
# ['b1242', 'b1241']
# [nan, 'b1521']
# ['b1676', 'b1675']
# ['b1676', 'b1675']
# [nan, 'b1777']
# ['b1779,b1780', 'b1778']
# ['b1817,b1818,b1819', 'b1816']
# [nan, 'b1908']
# [nan, 'b1985']
# ['b2170', 'b2167,b2168,b2169']
# [nan, 'b2181']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# ['b2389', 'b2388']
# ['b2398,b2399', 'b2395']
# [nan, 'b2400']
# ['b2415,b2416,b2417', nan]
# ['b2448,b2449', nan]
# [nan, nan]
# ['b2673,b2674,b2675,b2676', nan]
# [nan, nan]
# [nan, 'b2787,b2788,b2789']
# [nan, 'b2921']
# [nan, 'b2925,b2926,b2927']
# ['b3093', 'b3091,b3092']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# ['b3441', 'b3440']
# ['b3556', nan]
# ['b3612,b3613,b3614', 'b3608,b3609,b3610,b3611']
# ['b3800', nan]
# [nan, nan]
# ['b3916', nan]
# ['b3916', nan]
# [nan, 'b3919']
# ['b0150,b0151,b0152,b0153', nan]
# [nan, nan]
# ['b1242', 'b1241']
# ['b1676', 'b1675']
# [nan, 'b1777']
# ['b1779,b1780', 'b1778']
# ['b1817,b1818,b1819', 'b1816']
# [nan, 'b1908']
# ['b2170', 'b2167,b2168,b2169']
# [nan, 'b2181']
# [nan, 'b2181']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# ['b2389', 'b2388']
# ['b2415,b2416,b2417', nan]
# ['b2448,b2449', nan]
# [nan, 'b2556']
# [nan, nan]
# [nan, 'b2787,b2788,b2789']
# [nan, 'b2925,b2926,b2927']
# ['b3710', nan]
# ['b3800', nan]
# [nan, nan]
# ['b3916', nan]
# [nan, 'b3919']
# [nan, nan]
# ['b0150,b0151,b0152,b0153', nan]
# ['b0217', nan]
# [nan, '']
# [nan, 'b0281']
# [nan, nan]
# [nan, 'b0930']
# ['b1242', 'b1241']
# [nan, 'b1521']
# ['b1667', 'b1664']
# [nan, 'b1777']
# [nan, 'b1908']
# ['b1978', nan]
# [nan, 'b1985']
# [nan, 'b1988']
# ['b2170', 'b2167,b2168,b2169']
# ['b2398,b2399', 'b2395']
# [nan, nan]
# ['b2415,b2416,b2417', nan]
# ['b2448,b2449', nan]
# [nan, 'b2556']
# [nan, 'b2790,b2791,b2792']
# [nan, 'b2813']
# [nan, 'b2925,b2926,b2927']
# ['b3093', 'b3091,b3092']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, nan]
# ['b3556', nan]
# ['b3710', nan]
# ['b3800', nan]
# ['b3916', nan]
# ['ymgJ' 'ycgI_1']
# ['ymgGD' 'ymgI']
# ['ymgE' 'ycgY']
# ['hybOABCDEFG' 'yghW']
# ['insA-7' 'insB1']
# ['b0097,b0098,b0099', nan]
# ['b0150,b0151,b0152,b0153', nan]
# ['b0169,b0170', 'b0166,b0167,b0168']
# ['b0230', 'b0229']
# ['b0238', 'b0237']
# ['b4688', 'b0273']
# ['b0468', 'b0466,b0467']
# ['b0474', nan]
# ['b0585,b4511,b0586,b0587', 'b0583,b0584']
# ['b0591', 'b0588,b0589,b0590']
# ['b0593,b0594,b0595,b0596,b0597', 'b0592']
# [nan, nan]
# [nan, 'b0755']
# [nan, 'b0805']
# ['b0894,b0895,b0896', nan]
# ['b4490_1,b4490_2', nan]
# [nan, 'b1021,b1022,b1023,b1024']
# ['b1103,b1104,b1105,b1106,b1107,b1108', 'b1102']
# ['b1168', nan]
# ['b4594,b4521_1', 'b1171,b1172,b4593']
# ['b1195,b1196', 'b1194']
# ['b1276', nan]
# ['b1452', 'b1451']
# [nan, 'b1495,b1496']
# [nan, nan]
# ['b1626,b1627,b1628,b1629,b1630,b1631,b1632,b1633', nan]
# ['b1705', nan]
# ['b1820', nan]
# ['b1833,b1834', 'b1832']
# [nan, 'b1845']
# ['b1902', nan]
# [nan, 'b1916']
# ['b4582_1', 'b4641']
# [nan, 'b2155']
# [nan, 'b2211']
# ['b2253,b2254,b2255,b2256,b2257,b4544,b2258', nan]
# ['b2321', 'b2317,b2318,b2319,b2320']
# ['b2393', 'b2392']
# ['b2450', nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b2598,b2599', nan]
# ['b2616', nan]
# ['b2673,b2674,b2675,b2676', nan]
# ['b2710,b2711', nan]
# [nan, nan]
# [nan, 'b2790,b2791,b2792']
# [nan, 'b2990,b2991,b2992,b2993,b2994,b2995,b2996,b2997,b2998']
# ['b3008', 'b3005,b3006']
# ['b3071', 'b3070']
# ['b3207', nan]
# ['b3408,b3409,b3410', nan]
# ['b3441', 'b3440']
# ['b3908', 'b3907']
# ['b4294,b4576', 'b4292,b4293']
# ['b4342', nan]
# ['b4567', 'b4367']
# ['sfmA' 'sfmCD']
# ['ymgJ' 'ycgI_1']
# ['ymgGD' 'ymgI']
# ['ymgE' 'ycgY']
# ['yoaK' 'yoaJ']
# ['insH-6' 'yoeG_2' 'yoeG_1']
# ['b4659_1,b4659_2', nan]
# ['b0064', 'b0061,b0062,b0063']
# ['', '']
# [nan, nan]
# ['', nan]
# [nan, 'b0197,b0198,b0199']
# [nan, nan]
# ['b0230', 'b0229']
# ['b0238', 'b0237']
# [nan, 'b4505,b0266,b0267']
# [nan, nan]
# [nan, nan]
# ['b0327', nan]
# ['b0347,b0348,b0349,b0350,b0351,b0352', nan]
# ['b0365,b0366,b0367,b0368', 'b0364']
# [nan, 'b0396']
# [nan, 'b0397,b0398']
# ['b0401,b0402', nan]
# ['b0437,b0438,b0439', nan]
# [nan, nan]
# ['b0497,b0498,b0499', nan]
# ['b0530,b0531,b0532', nan]
# ['b0533,b0534', nan]
# [nan, 'b0612']
# ['b0622', 'b0621']
# [nan, 'b0675,b0676,b0677,b0678']
# ['b0681,b0682', nan]
# [nan, 'b0691']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b0736,b0737,b0738,b0739', nan]
# ['b0754', 'b0753']
# ['b0767', 'b0766']
# ['b0779', nan]
# ['b0787', nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b0848', 'b0847']
# ['b0850,b0851,b0852,b0853', nan]
# [nan, nan]
# [nan, 'b0869,b0870,b0871,b0872,b0873']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b0907,b0908', nan]
# ['b0909', nan]
# ['b0913,b0914,b0915,b0916', nan]
# [nan, nan]
# ['b0939,b0940,b0941,b0942,b0943,b0944', nan]
# [nan, 'b0984,b0985,b0986']
# ['b1001', 'b0999,b1000']
# ['', nan]
# [nan, 'b1021,b1022,b1023,b1024']
# [nan, nan]
# ['b1025', nan]
# ['b1082,b1083', nan]
# ['b1082,b1083', nan]
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1101', nan]
# ['b1109', nan]
# ['b1168', nan]
# ['b4594,b4521_1', 'b1171,b1172,b4593']
# ['b1195,b1196', 'b1194']
# ['b1220', 'b1219']
# ['b4522,b4523', nan]
# [nan, nan]
# [nan, nan]
# ['b1343', nan]
# [nan, 'b1344']
# ['b1365,b1366', nan]
# ['b1368,b4570_1', nan]
# [nan, 'b1379']
# ['b1388,b1389,b1390,b1391,b1392,b1393,b1394,b1395,b1396,b1397,b1398', nan]
# ['b1421', nan]
# ['b1432', 'b4578']
# ['b1456,b1457', nan]
# [nan, 'b1521']
# ['b1583,b1584', nan]
# [nan, 'b1669,b1670,b1671,b1672,b1673,b1674']
# ['b1697,b1698,b1699,b1700,b1701', nan]
# [nan, 'b1707']
# [nan, 'b1743']
# ['b1766', 'b1763,b1764,b1765']
# ['b4676,b4675', nan]
# ['b1801,b1802', nan]
# [nan, 'b1805']
# [nan, 'b1816']
# [nan, 'b1829']
# [nan, 'b1856']
# ['b1869,b1870,b1871', nan]
# [nan, nan]
# [nan, 'b1994,b4640_2,b4640_1']
# ['b2018,b2019,b2020,b2021,b2022,b2023,b2024,b2025,b2026', 'b4539,b2017']
# [nan, 'b2035,b2036']
# [nan, 'b2082']
# [nan, 'b2112']
# ['b2173,b2174', nan]
# [nan, nan]
# ['b2221,b2222,b2223,b2224', nan]
# ['b2443', nan]
# ['b2481,b2482,b2483,b2484,b2485,b2486,b2487,b2488,b2489,b2490,b2491,b2492', nan]
# [nan, 'b2503']
# [nan, nan]
# [nan, 'b2648']
# ['b4462', nan]
# [nan, 'b2790,b2791,b2792']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b3442,b3443_1,b3444,b3445,b3443_2', nan]
# ['b3459', 'b3454,b3455,b3456,b3457,b3458']
# ['b3928', 'b3925,b3926,b3927']
# [nan, 'b4295']
# [nan, 'b4297,b4298,b4299']
# ['holE' 'yobB-exoX']
# ['ypjD' 'yfjD']
# ['b0217', nan]
# [nan, 'b0281']
# ['b0382', 'b0381']
# [nan, 'b1492,b1493']
# [nan, 'b1521']
# [nan, 'b1838']
# ['b1842,b1843,b1844', 'b1839,b1840,b1841']
# [nan, 'b1908']
# ['b1978', nan]
# [nan, 'b1985']
# ['b2172', nan]
# ['b2175', nan]
# ['b2216,b2217', 'b2215']
# [nan, nan]
# ['b2448,b2449', nan]
# ['b2450', nan]
# ['b2611,b4461', nan]
# ['b2622', nan]
# [nan, 'b2813']
# ['b3065,b3066,b3067', 'b3064']
# ['b3093', 'b3091,b3092']
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3212,b3213,b3214', nan]
# ['b3364', 'b3363']
# [nan, 'b3449,b3450,b3451,b3452,b3453']
# ['b3511', 'b3508,b3509,b3510']
# ['b3512,b3513,b3514', nan]
# ['b3521', 'b3520']
# ['b3710', nan]
# ['b3783', nan]
# [nan, nan]
# ['', nan]
# [nan, 'b3990,b3991,b4407,b3992,b3993,b3994']
# ['b4111', nan]
# ['b4200,b4201,b4202,b4203', 'b4199']
# ['ybiJ' 'ybiI']
# ['b0150,b0151,b0152,b0153', nan]
# ['b0217', nan]
# [nan, 'b0281']
# ['b0485,b0486', 'b0484']
# [nan, 'b0720']
# [nan, 'b0802,b0803']
# [nan, 'b0809,b0810,b0811']
# ['b0814', 'b0813']
# ['b1116,b1117,b1118', 'b1115']
# ['b1201', 'b1198,b1199,b1200']
# ['b1434', 'b1433']
# [nan, 'b1521']
# [nan, 'b1908']
# [nan, 'b1985']
# ['b2018,b2019,b2020,b2021,b2022,b2023,b2024,b2025,b2026', 'b4539,b2017']
# ['b2172', nan]
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# ['b2398,b2399', 'b2395']
# [nan, 'b2400']
# ['b2448,b2449', nan]
# [nan, 'b2606,b2607,b2608,b2609']
# [nan, 'b2790,b2791,b2792']
# [nan, 'b4466']
# ['b3093', 'b3091,b3092']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3173']
# ['b3212,b3213,b3214', nan]
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# ['b3364', 'b3363']
# [nan, 'b3515,b3516,b3517']
# [nan, nan]
# ['b3710', nan]
# ['b3800', nan]
# ['b3871', 'b3868,b3869,b3870']
# [nan, nan]
# ['b4111', nan]
# ['b4271', 'b4269']
# ['asr' 'ydgU' 'ydgD']
# ['blr' 'cnu']
# [nan, nan]
# ['b0150,b0151,b0152,b0153', nan]
# ['b0217', nan]
# [nan, 'b0280']
# [nan, 'b0281']
# ['b0485,b0486', 'b0484']
# [nan, nan]
# ['b1201', 'b1198,b1199,b1200']
# ['b1236', nan]
# ['b4529', 'b1377,b1378']
# [nan, 'b1492,b1493']
# [nan, 'b1492,b1493']
# [nan, 'b1521']
# [nan, 'b1580,b1581']
# ['b1597,b4601,b1598', nan]
# ['b4409,b1625', 'b1624']
# [nan, 'b1908']
# [nan, 'b1985']
# ['b2172', nan]
# [nan, 'b2233']
# [nan, 'b2400']
# ['b2448,b2449', nan]
# ['b2450', nan]
# ['b2850_1,b2850_2', 'b2849']
# [nan, nan]
# [nan, 'b2903,b2904,b2905']
# ['b2942', nan]
# ['b3093', 'b3091,b3092']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# ['b3441', 'b3440']
# ['b3495', 'b3494']
# ['b3501,b3502,b3503', nan]
# ['b3504_1,b3504_2', nan]
# ['b3506,b3507', nan]
# [nan, nan]
# [nan, 'b3515,b3516,b3517']
# [nan, 'b3515,b3516,b3517']
# ['b3521', 'b3520']
# ['b3561', 'b4553']
# ['b3710', nan]
# ['b3800', nan]
# ['b3922,b3923', nan]
# ['gpt' 'frsA']
# ['ybfA' 'rhsC-ybfB']
# ['raiA' 'pheLA']
# ['ypjD' 'yfjD']
# ['yiaG' 'cspA']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# ['b0097,b0098,b0099', nan]
# [nan, nan]
# ['b0231,b0232,b0233,b0234', nan]
# ['b0238,b0239', nan]
# [nan, 'b0281']
# [nan, 'b0281']
# ['b0347,b0348,b0349,b0350,b0351,b0352', nan]
# [nan, 'b0428,b0429,b0430,b0431,b0432']
# [nan, 'b0457']
# ['b0699', 'b0696,b0697,b0698,b4513']
# ['b0699', 'b0696,b0697,b0698,b4513']
# ['b0699,b0700,b0702', 'b0696,b0697,b0698,b4513']
# ['b0781,b0782,b0783,b0784,b0785', 'b0780']
# [nan, 'b0903,b0904']
# [nan, 'b0929']
# ['b0938', 'b0933,b0934,b0935,b0936,b0937']
# [nan, '']
# ['b1164,b1165,b1166,b1167', 'b1163']
# [nan, 'b1194']
# ['b1201', 'b1198,b1199,b1200']
# ['b1201', 'b1198,b1199,b1200']
# ['b1418', 'b4493_2,b4493_1']
# ['b1418', 'b4493_2,b4493_1']
# ['b1434', 'b1433']
# ['b1434', 'b1433']
# [nan, 'b1521']
# [nan, 'b1521']
# ['b1853', 'b1852']
# ['b2172', nan]
# ['b2448,b2449', nan]
# ['b2448,b2449', nan]
# ['b2448,b2449', nan]
# ['b2450', nan]
# [nan, 'b2555']
# ['b2597', nan]
# ['b2597,b2598,b2599', nan]
# [nan, 'b2606,b2607,b2608,b2609']
# ['b2611,b4461', nan]
# [nan, nan]
# [nan, 'b2813']
# [nan, 'b2819,b2820,b2821']
# ['b2912', nan]
# ['b2912', nan]
# ['b3008', 'b3005,b3006']
# ['b3065,b3066,b3067', 'b3064']
# ['b3093', 'b3091,b3092']
# ['b3094', nan]
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3230,b3231']
# [nan, 'b3299,b3300,b3301,b3302,b3303,b3304,b3305,b3306,b3307,b3308,b3309,b3310']
# [nan, 'b3339,b3340,b3341,b3342']
# [nan, 'b3376,b3377,b3378,b3379,b3380,b3381']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b3441', 'b3440']
# ['b3501,b3502,b3503', 'b4613']
# ['b3536,b3537,b3538', nan]
# ['b3555,b3556', nan]
# ['b3556', nan]
# ['b3556', nan]
# [nan, 'b3635,b3636,b3637,b3638']
# ['b3703,b3704', nan]
# ['b3710', nan]
# ['b3715', 'b3714']
# [nan, 'b3754,b3755']
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', 'b3765']
# ['b3829', 'b3828']
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# [nan, 'b4005,b4006']
# ['b4050', nan]
# ['b4111', nan]
# ['b4322,b4323', 'b4321']
# ['b0399,b0400', 'b0397,b0398']
# ['b1139', 'b1137,b1138']
# [nan, nan]
# [nan, nan]
# ['b3136,b3137,b3138,b3139,b3140,b3141', nan]
# [nan, 'b3173']
# [nan, 'b3173']
# [nan, 'b3724,b3725,b3726,b3727,b3728']
# [nan, 'b3724,b3725,b3726,b3727,b3728']
# [nan, 'b3817,b3818']
# ['b3871', 'b3868,b3869,b3870']
# ['yaaY' 'ribF-ileS-lspA-fkpB-ispH']
# ['yaaY' 'ribF-ileS-lspA-fkpB-ispH']
# ['yaaY' 'ribF-ileS-lspA-fkpB-ispH']
# ['cdsA' 'rseP']
# ['ykfM' 'yafU']
# ['iraP' 'phoA-psiF']
# ['iraP' 'phoA-psiF']
# ['hupB' 'ppiD']
# ['hupB' 'ppiD']
# ['maa' 'tomB-hha']
# ['maa' 'tomB-hha']
# ['acrR' 'mscK']
# ['rhsD-ybbC-ylbH-ybbD' 'ybbD']
# ['renD-emrE' 'ybcK']
# ['ylcH' 'ybcN-ninE-ybcO-rusA-ylcG']
# ['hokE' 'insL-2']
# ['hokE' 'insL-2']
# ['acrZ' 'modABC']
# ['opgE' 'rybA-mntS']
# ['cmk-rpsA-ihfB' 'ycaI-msbA-lpxK-ycaQ']
# ['insA' 'insA-4AB-4B-4']
# ['gfcBCD' 'gfcA']
# ['solA-yceO' 'bssS']
# ['yceQ' 'rluC']
# ['ymfTLMNR-beeE-jayE-ymfQ-ycfK-tfaP' 'oweE']
# ['ymgJ' 'ycgI_1' 'ycgI_2']
# ['ymgGD' 'ymgI']
# ['ycgL' 'ycgM']
# ['purU' 'ychJ']
# ['purU' 'ychJ']
# ['hokB' 'mokB']
# ['hokB' 'mokB']
# ['ydcH' 'rimL']
# ['ortT' 'ydcY']
# ['ortT' 'ydcY']
# ['maeA' 'bdm-sra']
# ['dicA' 'ydfABC']
# ['blr' 'cnu']
# ['cnu' 'ydgK-rsxABCDGE-nth']
# ['ydhF' 'ydhL']
# ['ydhP' 'ynhF']
# ['ydiZ' 'yniA']
# ['yeaC' 'msrB']
# ['rlmA' 'yobF-cspC']
# ['yebO' 'mgrB']
# ['yebV' 'yebW']
# ['holE' 'yobB-exoX']
# ['holE' 'yobB-exoX']
# ['yebF' 'yebG']
# ['ruvAB' 'yobI']
# ['yecJ' 'azuC']
# ['yedMN_2N_3' 'yedN_1']
# ['dgcQ' 'yodC']
# ['insH-6' 'yoeG_2' 'yoeG_1']
# ['yoeG_2' 'yoeG_1']
# ['yoeG_1' 'yoeH']
# ['gnd' 'wbbL_2']
# ['gnd' 'wbbL_2']
# ['yegLK' 'ibsA']
# ['yegLK' 'ibsA']
# ['yehDCBA' 'yehE']
# ['insH-8' 'yejO']
# ['menFDHBCE' 'elaB']
# ['fadIJ' 'yfcZ']
# ['bamB-der' 'yfgM']
# ['shoB' 'rnc-era-recO-pdxJ-acpS']
# ['trxC' 'yfiP-patZ']
# ['yfiL' 'yfiR-dgcN-yfiB']
# ['yfiL' 'yfiR-dgcN-yfiB']
# ['ypjI_1' 'ypjI_2' 'yfjXY-ypjJ-yfjZ-ypjF']
# ['gshA' 'yqaBA']
# ['gshA' 'yqaBA']
# ['yqcG' 'ygcG']
# ['yqcG' 'ygcG']
# ['yqcG' 'ygcG']
# ['ygdR' 'tas']
# ['yqeL' 'yqeK']
# ['ygeI' 'pbl']
# ['yghG' 'pppA']
# ['ibsD' 'ibsE']
# ['yqjF' 'yqjG']
# ['tdcR' 'yhaBC']
# ['tdcR' 'yhaBC']
# ['yraH' 'yraIJK']
# ['yhdE' 'mreBCD']
# ['yrdE_1' 'yrdE_2']
# ['rpsLG-fusA-tufA' 'yheO-tusDCB']
# ['greB' 'yhgF']
# ['yhiS_1' 'slp-dctR']
# ['yhiS_1' 'slp-dctR']
# ['bcsQ' 'yhjR']
# ['bcsQ' 'yhjR']
# ['yiaG' 'cspA']
# ['yiaG' 'cspA']
# ['glyQS' 'ysaB']
# ['glyQS' 'ysaB']
# ['yihI' 'hemN']
# ['yihI' 'hemN']
# ['cpxPQ' 'fieF']
# ['hupA' 'yjaH']
# ['yjdIJ' 'ghoST']
# ['yjdQ_2' 'yjdQ_1']
# ['ecnAB' 'sugE']
# ['ecnAB' 'sugE']
# ['ampC' 'frdABCD']
# ['insA-7' 'insB1']
# ['insA-7' 'insB1']
# ['b0001,b0002,b0003,b0004', nan]
# ['b0001,b0002,b0003,b0004', nan]
# ['b0008', 'b0007']
# ['b0008', 'b0007']
# ['b0014,b0015', 'b0013']
# ['b0014,b0015', 'b0013']
# [nan, 'b0018,b4412']
# [nan, 'b0018,b4412']
# ['b0019,b0020', 'b0018,b4412']
# ['b0019,b0020', 'b0018,b4412']
# ['b0019,b0020', 'b0018,b4412']
# ['b0019,b0020', 'b0018,b4412']
# ['b0019,b0020', nan]
# [nan, nan]
# ['b0024,b0025,b0026,b0027,b0028,b0029', 'b0023']
# ['b0024,b0025,b0026,b0027,b0028,b0029', 'b0023']
# ['b0024,b0025,b0026,b0027,b0028,b0029', 'b0023']
# ['b0032,b0033', nan]
# ['b0034', nan]
# [nan, 'b0049,b0050,b0051,b0052,b0053,b0054']
# ['b0055', 'b0049,b0050,b0051,b0052,b0053,b0054']
# ['b4659_1,b4659_2', nan]
# ['b4659_1,b4659_2', nan]
# ['b4659_1,b4659_2', nan]
# [nan, 'b0058,b0059']
# [nan, 'b0058,b0059']
# [nan, 'b0060']
# ['b0065', nan]
# ['b4662,b0070', 'b0066,b0067,b0068,b0069']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# ['b0081,b0082,b0083,b0084,b0085,b0086,b0087,b0088,b0089,b0090,b0091,b0092,b0093,b0094,b0095,b0096', nan]
# ['b0081,b0082,b0083,b0084,b0085,b0086,b0087,b0088,b0089,b0090,b0091,b0092,b0093,b0094,b0095,b0096', nan]
# ['b0081,b0082,b0083,b0084,b0085,b0086,b0087,b0088,b0089,b0090,b0091,b0092,b0093,b0094,b0095,b0096', nan]
# ['b0097,b0098,b0099', nan]
# ['b0104', 'b0101,b0102,b0103']
# ['b0104', 'b0101,b0102,b0103']
# ['b0113,b0114,b0115,b0116', 'b0112']
# ['b0113,b0114,b0115,b0116', 'b0112']
# ['b0113,b0114,b0115,b0116', nan]
# ['b0113,b0114,b0115,b0116', nan]
# ['b0113,b0114,b0115,b0116', nan]
# ['b0118', 'b0117']
# ['b0118', 'b0117']
# ['b0119', nan]
# ['b0123', 'b0120,b0121,b0122']
# ['b0125', 'b0124']
# ['b0127,b0128', 'b0126']
# ['b0130', nan]
# [nan, 'b0133,b0134']
# [nan, nan]
# [nan, 'b0135,b0136,b0137,b0138']
# [nan, 'b0135,b0136,b0137,b0138']
# [nan, 'b0135,b0136,b0137,b0138']
# [nan, 'b0135,b0136,b0137,b0138']
# [nan, 'b0139,b0140']
# [nan, 'b0139,b0140']
# [nan, 'b0139,b0140']
# [nan, 'b0139,b0140']
# [nan, 'b0144,b0145,b0146']
# [nan, 'b0144,b0145,b0146']
# ['b0155', 'b0154']
# ['b0155', 'b0154']
# ['b0155', 'b0154']
# ['b0155', 'b0154']
# ['b0156', nan]
# ['b0160', 'b0157,b0158,b0159']
# ['b0161', nan]
# ['b0161', nan]
# ['b0161', nan]
# [nan, 'b0163']
# [nan, 'b0163']
# ['b0169,b0170', 'b0166,b0167,b0168']
# ['b0169,b0170', 'b0166,b0167,b0168']
# ['b0172', nan]
# ['b0172', nan]
# ['b0175,b0176', nan]
# ['b0177,b0178,b0179,b0180,b0181,b0182,b0183,b0184', nan]
# ['b0177,b0178,b0179,b0180,b0181,b0182,b0183,b0184', nan]
# ['b0185', nan]
# ['b0186', nan]
# ['b0190,b0191,b0192', 'b0189,b4406']
# [nan, 'b0193']
# [nan, 'b0193']
# [nan, 'b0194']
# [nan, 'b0195,b0196']
# ['b0200', 'b0197,b0198,b0199']
# [nan, nan]
# [nan, nan]
# ['b0207', nan]
# ['b0209,b0210', 'b0208']
# [nan, 'b0211']
# [nan, 'b0211']
# ['b0215', 'b0214']
# ['b0217', nan]
# ['b4503', 'b4586,b0218']
# ['b0222', 'b0221']
# ['b0222', 'b0221']
# ['b0222', 'b0221']
# [nan, 'b0224']
# ['b0227', 'b0225,b0226']
# ['b0227', 'b0225,b0226']
# ['b0227', 'b0225,b0226']
# ['b0231,b0232,b0233,b0234', nan]
# ['b0231,b0232,b0233,b0234', nan]
# ['b0238', 'b0237']
# ['b0238', 'b0237']
# ['b0239', nan]
# ['b0240_1,b0240_2', nan]
# ['b0242,b0243', 'b0241']
# [nan, '']
# [nan, '']
# [nan, 'b0252,b0253']
# [nan, 'b0252,b0253']
# ['b4688', 'b0273']
# [nan, nan]
# [nan, 'b0277']
# [nan, 'b0277']
# [nan, 'b0278,b0279']
# [nan, 'b0280']
# [nan, 'b0280']
# [nan, 'b0280']
# [nan, 'b0281']
# [nan, 'b0281']
# [nan, 'b0281']
# ['b0287', 'b0283,b0284,b0285,b0286']
# ['b0287', 'b0283,b0284,b0285,b0286']
# ['b0287', 'b0283,b0284,b0285,b0286']
# [nan, 'b4506,b0296']
# [nan, nan]
# ['b4631', 'b0300']
# ['b4631', 'b0300']
# [nan, 'b0301,b0303,b0304']
# ['b0315', nan]
# ['b0327', nan]
# ['b0327', nan]
# [nan, 'b0342,b0343,b0344']
# ['b0347,b0348,b0349,b0350,b0351,b0352', 'b0345,b0346']
# [nan, nan]
# [nan, 'b0364']
# ['b0365,b0366,b0367,b0368', 'b0364']
# [nan, 'b0369']
# ['b4580_1', nan]
# [nan, nan]
# [nan, nan]
# ['b0382', 'b0381']
# ['b0382', 'b0381']
# ['b0382,b0383,b0384', 'b0381']
# ['b0382,b0383,b0384', 'b0381']
# ['b0388,b0389,b0390', nan]
# ['b0388,b0389,b0390', nan]
# ['b0388,b0389,b0390', nan]
# ['b0401,b0402', nan]
# ['b0401,b0402', nan]
# ['b0405', 'b0404']
# ['b0413,b0414,b0415,b0416,b0417,b0418', 'b0412']
# ['b0413,b0414,b0415,b0416,b0417,b0418', nan]
# [nan, 'b0419,b0420,b0421,b0422']
# [nan, 'b0419,b0420,b0421,b0422']
# ['b0423', 'b0419,b0420,b0421,b0422']
# ['b0423', 'b0419,b0420,b0421,b0422']
# ['b0426', 'b0424,b0425']
# [nan, 'b0428,b0429,b0430,b0431,b0432']
# ['b0435', 'b0433,b0434']
# ['b0435', 'b0433,b0434']
# ['b0435', 'b0433,b0434']
# ['b0437,b0438,b0439', nan]
# ['b0437,b0438,b0439', nan]
# ['b0437,b0438,b0439', nan]
# ['b0437,b0438,b0439', nan]
# ['b0437,b0438,b0439', nan]
# ['b0440,b0441', nan]
# ['b0440,b0441', nan]
# ['b0441', nan]
# ['b0453', 'b0452']
# ['b0453', 'b0452']
# ['b0453', 'b0452']
# ['b0456', 'b0454']
# [nan, 'b0457']
# [nan, 'b0458']
# [nan, 'b0458']
# [nan, 'b0459,b0460,b0461']
# [nan, 'b0459,b0460,b0461']
# [nan, 'b0460,b0461']
# [nan, 'b0460,b0461']
# [nan, 'b0460,b0461']
# [nan, 'b0460,b0461']
# [nan, 'b0460,b0461']
# ['b0464', 'b0462,b0463']
# ['b0464,b0465', 'b0462,b0463']
# ['b0465', nan]
# ['b0465', nan]
# ['b0465', nan]
# ['b0469', 'b0466,b0467']
# ['b0470', nan]
# ['b0473', nan]
# ['b0477', 'b0476']
# [nan, 'b0478']
# [nan, 'b0481']
# [nan, 'b0481']
# ['b0483', 'b0482']
# ['b0485,b0486', 'b0484']
# ['b0485,b0486', 'b0484']
# ['b0490,b0491', 'b0488,b0489']
# [nan, 'b0492']
# [nan, 'b0492']
# ['b0497,b0498,b0499', nan]
# ['b0497,b0498,b0499', nan]
# ['b0497,b0498,b0499', nan]
# ['b0497,b0498,b0499,b0501', nan]
# ['b0501', nan]
# ['b0501', nan]
# [nan, 'b0522,b0523']
# ['b0526', 'b0524,b0525']
# ['b0530', 'b0528,b0529']
# [nan, 'b0535']
# [nan, 'b0535']
# [nan, 'b0535']
# ['b0542_1,b0542_2,b0543', nan]
# ['b0542_1,b0542_2,b0543', nan]
# ['b0542_1,b0542_2,b0543', nan]
# ['b0542_1,b0542_2,b0543,b0544', nan]
# ['b0544', nan]
# [nan, nan]
# ['b0545,b0546', nan]
# ['b0545,b0546', nan]
# ['b0545,b0546', nan]
# ['b0545,b0546', nan]
# ['b0545,b0546', nan]
# ['b0545,b0546', nan]
# ['b4588,b0547,b0548,b0549,b0550,b4509', nan]
# ['', '']
# [nan, 'b0553_2,b0553_1']
# ['b0554,b0555,b0556', 'b0553_2,b0553_1']
# ['b0554,b0555,b0556', 'b0553_2,b0553_1']
# ['b0559', 'b0558']
# ['b0559', 'b0558']
# ['b0564', nan]
# ['b0564', nan]
# ['b0564', nan]
# [nan, 'b0565,b0566']
# [nan, 'b0565,b0566']
# [nan, 'b0565,b0566']
# [nan, 'b0568,b0569']
# ['b4415', 'b0581']
# ['b4415,b0582', 'b0581']
# ['b4415,b0582', 'b0581']
# [nan, nan]
# [nan, 'b0603']
# ['b0605,b0606', 'b0604']
# ['b0608', 'b0607']
# ['b0608', 'b0607']
# ['b0608', 'b0607']
# [nan, 'b0610']
# [nan, 'b0613,b0614,b0615,b0616,b0617,b0618']
# [nan, 'b0621']
# ['b0622', 'b0621']
# ['b0622', 'b0621']
# ['b0622', nan]
# ['b0623', nan]
# ['b4581_1,b4581_2', 'b0624']
# [nan, 'b0628']
# [nan, 'b0630,b0631']
# [nan, 'b0630,b0631']
# [nan, 'b0630,b0631']
# [nan, 'b0630,b0631']
# [nan, 'b0633,b0634,b0635,b0636,b0637']
# [nan, 'b0633,b0634,b0635,b0636,b0637']
# ['b0643', 'b0638,b0639,b0640,b0641,b0642']
# ['b0643', 'b0638,b0639,b0640,b0641,b0642']
# ['b0645,b0646', 'b0644']
# ['b0645,b0646', nan]
# [nan, 'b0656']
# [nan, 'b0656']
# [nan, 'b0657,b0658,b0659,b0660']
# [nan, 'b0657,b0658,b0659,b0660']
# ['b0662', 'b0661']
# [nan, nan]
# [nan, 'b0675,b0676,b0677,b0678']
# ['b0679', 'b0675,b0676,b0677,b0678']
# ['b0680', nan]
# ['b0680', nan]
# ['b0681,b0682', nan]
# [nan, 'b0683,b4637,b0684']
# [nan, 'b0683,b4637,b0684']
# [nan, 'b0683,b4637,b0684']
# ['b0687,b0688', 'b0686']
# [nan, nan]
# [nan, 'b0691']
# ['b0699', 'b0696,b0697,b0698,b4513']
# ['b0699', 'b0696,b0697,b0698,b4513']
# ['b0699', 'b0696,b0697,b0698,b4513']
# ['b0700,b0702', nan]
# ['b0706', nan]
# ['b0707,b0708', nan]
# ['b0710,b0711,b0712,b0713,b0714', 'b0709']
# ['b0710,b0711,b0712,b0713,b0714', 'b0709']
# [nan, 'b0715']
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', 'b0720']
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', 'b0720']
# [nan, nan]
# ['b0733,b0734', nan]
# ['b0733,b0734', nan]
# [nan, nan]
# [nan, nan]
# ['b0750,b0751', nan]
# ['b0754', 'b0753']
# ['b0754', 'b0753']
# [nan, 'b0755']
# [nan, 'b0756,b0757,b0758,b0759']
# [nan, 'b0756,b0757,b0758,b0759']
# [nan, 'b0756,b0757,b0758,b0759']
# [nan, 'b0756,b0757,b0758,b0759']
# ['b0762', 'b0760,b0761']
# ['b0762,b0763,b0764,b0765', 'b0760,b0761']
# ['b0767', 'b0766']
# ['b0779', nan]
# ['b0781,b0782,b0783,b0784,b0785', 'b0780']
# ['b0786', nan]
# ['b0786', nan]
# ['b0787', nan]
# [nan, nan]
# ['b0791', 'b0788,b0789,b0790']
# ['b0797', 'b0792,b0793,b0794,b0795,b0796']
# [nan, 'b0802']
# [nan, 'b0803']
# [nan, 'b0808']
# [nan, 'b0809,b0810,b0811']
# [nan, 'b0809,b0810,b0811']
# [nan, 'b0809,b0810,b0811']
# [nan, 'b0812']
# [nan, 'b0812']
# [nan, 'b0812']
# ['b0814', 'b0813']
# ['b0814', 'b0813']
# ['b0817,b0818', 'b0815,b4705']
# ['b0817,b0818', 'b4705']
# ['b0820', 'b0819']
# ['b0820', 'b0819']
# ['b0828,b0829,b0830,b0831,b0832', 'b0826,b0827']
# ['b0828,b0829,b0830,b0831,b0832', 'b0826,b0827']
# ['b0833,b0834', nan]
# ['b0833,b0834', nan]
# ['b0836', 'b0835']
# ['b0839', 'b0838']
# ['b0839', 'b0838']
# ['b0842', 'b0841']
# ['b0842', 'b0841']
# [nan, nan]
# ['b0848', 'b0847']
# ['b0848', 'b0847']
# ['b0848', 'b0847']
# ['b0854,b0855,b0856,b0857', nan]
# [nan, 'b0861,b0862,b0863,b0864']
# ['b0866,b0867', 'b0865']
# ['b0876', 'b0875']
# ['b0876', 'b0875']
# ['b0876', 'b0875']
# ['b0876', 'b0875']
# ['b0878,b0879', 'b0877']
# ['b0878,b0879', 'b0877']
# [nan, nan]
# [nan, nan]
# [nan, '']
# [nan, '']
# [nan, '']
# [nan, 'b0884']
# [nan, 'b0884']
# [nan, 'b0885']
# [nan, 'b0888']
# ['b0889', nan]
# ['b0890', nan]
# ['b0893', nan]
# ['b0893', nan]
# ['b0898', 'b0897']
# ['b0899', nan]
# [nan, nan]
# [nan, 'b0902']
# [nan, 'b0903,b0904']
# [nan, 'b0903,b0904']
# ['b0906', 'b0905']
# ['b0910,b0911,b0912', nan]
# ['b0910,b0911,b0912', nan]
# ['b0910,b0911,b0912', nan]
# ['b0910,b0911,b0912,b0913,b0914,b0915,b0916', nan]
# ['b0917,b0918', nan]
# ['b0925', nan]
# ['b0926,b0927', nan]
# [nan, 'b0928']
# [nan, 'b0929']
# [nan, 'b0929']
# [nan, 'b0929']
# [nan, 'b0929']
# [nan, 'b0929']
# [nan, 'b0930']
# ['b0932', 'b0931']
# ['b0932', 'b0931']
# ['b0945', nan]
# ['b0945', nan]
# ['b0946', nan]
# ['b0946', nan]
# ['b0950,b0951,b0952', nan]
# ['b0953', nan]
# [nan, 'b0954']
# [nan, nan]
# ['b0956', 'b0955']
# [nan, 'b0957']
# [nan, 'b0957']
# [nan, 'b0957']
# [nan, 'b0957']
# [nan, 'b0957']
# [nan, 'b0957']
# ['b0959', 'b0958']
# ['b0959', 'b0958']
# [nan, 'b0966']
# [nan, 'b0966']
# [nan, 'b0966']
# [nan, 'b0970']
# ['b0972,b0973,b0974,b0975,b0976,b0977', 'b0970']
# ['b4516,b0988', 'b0984,b0985,b0986,b0987']
# [nan, nan]
# [nan, '']
# [nan, '']
# ['b0990', 'b0989']
# ['b0996,b0997,b0998', 'b0995']
# ['b0996,b0997,b0998', 'b0995']
# ['b1001', 'b0999,b1000']
# ['b1001', 'b0999,b1000']
# ['b1001', 'b0999,b1000']
# ['b1001', nan]
# ['b1001', nan]
# ['b4518', 'b1003,b1004']
# ['b1020', nan]
# ['b1020', nan]
# [nan, 'b1021,b1022,b1023,b1024']
# ['b1025', 'b1021,b1022,b1023,b1024']
# ['b1025', 'b1021,b1022,b1023,b1024']
# ['b1025', nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b1036', nan]
# ['b1036', nan]
# [nan, 'b1037,b1038,b1039,b1040']
# ['b1044,b1045,b1046', nan]
# ['b1044,b1045,b1046', nan]
# ['b1048,b1049', 'b1047']
# ['b1048,b1049', 'b1047']
# [nan, 'b1051']
# ['b1055', 'b1054']
# [nan, 'b1058,b1059,b1060']
# [nan, 'b1062']
# [nan, 'b1064']
# ['b1085,b1086', 'b1084']
# ['b1086', 'b1084']
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', 'b1087']
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', 'b1087']
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1096,b1097,b1098,b1099,b1100', nan]
# ['b1101', nan]
# ['b1103,b1104,b1105,b1106,b1107,b1108', 'b1102']
# ['b1103,b1104,b1105,b1106,b1107,b1108', 'b1102']
# ['b1112', 'b1111']
# ['b1112', 'b1111']
# ['b1116,b1117,b1118', 'b1115']
# [nan, 'b1128']
# [nan, 'b1128']
# [nan, 'b1129,b1130']
# ['b1136', 'b1134,b1135']
# ['b1136', 'b1134,b1135']
# ['b1136', 'b1134,b1135']
# [nan, nan]
# ['b1139', 'b1137,b1138']
# ['b1146,b1147,b1148,b4693,b1150,b1151,b1152,b1153,b1154,b1155', 'b1145']
# ['b1146,b1147,b1148,b4693,b1150,b1151,b1152,b1153,b1154,b1155', 'b1145']
# ['b1146,b1147,b1148,b4692,b4693,b1150,b1151,b1152,b1153,b1154,b1155', nan]
# ['b1159', nan]
# ['b1159', nan]
# [nan, 'b1160']
# [nan, 'b1160']
# [nan, 'b1161']
# [nan, 'b1161']
# [nan, 'b1162']
# [nan, 'b1162']
# [nan, 'b1162']
# [nan, 'b1163']
# ['b1164,b1165,b1166,b1167', 'b1163']
# ['b1164,b1165,b1166,b1167', 'b1163']
# ['b1164,b1165,b1166,b1167', 'b1163']
# ['b1164,b1165,b1166,b1167', 'b1163']
# ['b1168', nan]
# ['b4520', nan]
# ['b4520', nan]
# ['b4520', nan]
# ['b4520', nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['', 'b1171,b1172']
# ['b4594,b4521_1,b4521_2', 'b1171,b1172,b4593']
# ['b1177', 'b1174,b1175,b1176']
# ['b1179', 'b1178']
# ['b1179,b1180', 'b1178']
# ['b1181', nan]
# [nan, 'b1185']
# ['b1187', 'b1186']
# ['b1187', 'b1186']
# ['b1189,b1190', 'b1188']
# [nan, 'b1191']
# ['b1195', 'b1194']
# [nan, nan]
# [nan, 'b1203,b1204']
# ['b1205', 'b1203,b1204']
# [nan, 'b1207,b1208,b1209']
# ['b1210,b1211,b1212', 'b1207,b1208,b1209']
# ['b1210,b1211,b1212', 'b1207,b1208,b1209']
# [nan, 'b4419']
# [nan, 'b4421']
# [nan, 'b4423']
# ['b1217,b1218', 'b1216']
# ['b1217,b1218', 'b1216']
# ['b1220', 'b1219']
# ['b1224,b1225,b1226,b1227', nan]
# ['b1224,b1225,b1226,b1227', nan]
# [nan, 'b1229']
# [nan, 'b1232,b1233']
# ['b1234,b1235', 'b1232,b1233']
# ['b1234,b1235', nan]
# [nan, 'b1237']
# [nan, 'b1237']
# ['b1238', 'b1237']
# ['b1238', nan]
# ['b1242', 'b1241']
# ['b1242', 'b1241']
# ['b1242', 'b1241']
# [nan, nan]
# [nan, nan]
# ['b1243,b1244,b1245,b1246,b1247', nan]
# ['b1243,b1244,b1245,b1246,b1247', nan]
# ['b1243,b1244,b1245,b1246,b1247', nan]
# ['b1243,b1244,b1245,b1246,b1247', nan]
# ['b4595', 'b1248,b1249']
# ['b4595', 'b1248,b1249']
# ['b1252', 'b1251']
# ['b1252', 'b1251']
# ['b1256', 'b1254,b1255']
# ['b1269', nan]
# ['b1272', 'b1270,b1271']
# ['b1274', 'b1273']
# ['b1274', 'b1273']
# ['b4522,b4523', nan]
# ['b4522,b4523', nan]
# ['b4522,b4523', nan]
# ['b1276', nan]
# ['b1278', 'b1277']
# ['b1278', 'b1277']
# ['b1278', nan]
# ['b1279,b1280,b1281,b1282', nan]
# ['b1279,b1280,b1281,b1282', nan]
# [nan, 'b1283']
# [nan, 'b1283']
# [nan, 'b1284,b4596']
# [nan, 'b1286']
# [nan, 'b1288']
# [nan, 'b1290,b1291,b1292,b1293,b1294']
# [nan, 'b1290,b1291,b1292,b1293,b1294']
# ['b1298,b1299,b1300,b1301,b1302', 'b1296,b1297']
# ['b1304,b1305,b1306,b1307,b1308', 'b1303']
# ['b1304,b1305,b1306,b1307,b1308', 'b1303']
# ['b1321,b1322,b1323', 'b1320']
# ['b1321,b1322,b1323', nan]
# ['b1325', 'b1324']
# ['b1329', nan]
# ['b1331', 'b1330']
# ['b1331', 'b1330']
# ['b1331', 'b1330']
# ['b1332', nan]
# ['b1332', nan]
# [nan, 'b1333']
# [nan, 'b1334']
# [nan, 'b1334']
# ['b1342', 'b1341']
# ['b1342', 'b1341']
# ['b1342', 'b1341']
# [nan, 'b1345,b1346,b1347,b1348,b1349,b1350']
# ['b1353', 'b4526,b1352']
# ['b1357,b1358,b1359,b1360,b1361,b1362', 'b1356']
# ['b1357,b1358,b1359,b1360,b1361,b1362', 'b1356']
# ['b1365,b1366', nan]
# ['b1368,b4570_1', nan]
# ['b1368,b4570_1', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b1375']
# [nan, 'b1375']
# [nan, 'b1376']
# ['b4529', 'b1377,b1378']
# ['b4529', 'b1377,b1378']
# ['b4529', 'b1377,b1378']
# ['b4529', 'b1377,b1378']
# ['b1399,b1400', nan]
# ['b1399,b1400', nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b1407', nan]
# ['b1413', 'b1412']
# ['b1413', 'b1412']
# ['b1414', nan]
# ['b1418', 'b4493_2,b4493_1']
# ['b1418', 'b4493_2,b4493_1']
# ['b1418', 'b4493_2,b4493_1']
# ['b1421', 'b4428,b1420']
# ['b1421', 'b4428,b1420']
# ['b1423', 'b1422']
# ['b1426,b1427', nan]
# ['b1429,b1430', 'b1428']
# ['b1431', nan]
# ['b1431', nan]
# ['b1432', 'b4578']
# ['b1434', 'b1433']
# ['b4532,b1438', 'b1436']
# ['b4532,b1438', 'b1436']
# ['b1440,b1441,b1442,b1443,b1444', nan]
# ['b1445', '']
# ['b1445,b1446', 'b4598']
# ['b1445,b1446', 'b4598']
# ['b1446', 'b4598']
# ['b1450', nan]
# ['b1450', nan]
# ['b1452', 'b1451']
# ['b1454', 'b1453']
# ['b1461', nan]
# ['b1461', nan]
# [nan, nan]
# [nan, 'b1469']
# [nan, nan]
# [nan, nan]
# [nan, 'b1479']
# [nan, 'b1479,b1480,b1481']
# ['b1482', 'b1480,b1481']
# ['b1482', 'b1480,b1481']
# ['b1482', 'b1480,b1481']
# [nan, 'b1489,b1490']
# [nan, 'b1489,b1490']
# [nan, 'b1507,b1508']
# [nan, 'b1507,b1508']
# [nan, 'b1520']
# ['b1528', nan]
# ['b1528', nan]
# ['b1528', nan]
# ['b4599', nan]
# ['b4599', nan]
# ['b4599', nan]
# ['', nan]
# ['b1537', 'b1536']
# ['b1540', nan]
# [nan, 'b1542']
# [nan, 'b4600_2']
# ['b1544', 'b4600_2']
# ['b1544', 'b4600_2']
# ['b1545', nan]
# [nan, 'b1550']
# ['b1558', 'b1557']
# ['b1558', 'b1557']
# ['b1558', 'b1557']
# ['b1558', nan]
# ['', nan]
# ['', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b1559,b1560']
# ['b1565', 'b1562,b1563,b1564']
# ['b1570', 'b1567,b1568,b1569']
# ['b1570,b1571,b1572,b1573', 'b1567,b1568,b1569']
# ['', nan]
# ['b1575,b1576,b1577,b1578,b1579', nan]
# ['b1575,b1576,b1577,b1578,b1579', nan]
# [nan, nan]
# ['b1583,b1584', 'b1582']
# ['b1583,b1584', 'b1582']
# [nan, nan]
# ['b1586', 'b1585']
# [nan, nan]
# ['b1596', 'b1595']
# ['b1596', 'b1595']
# ['b1596', 'b1595']
# ['b1597', nan]
# ['b1598', nan]
# ['b1601', 'b1599,b1600']
# ['b1601', 'b1599,b1600']
# ['b1604', 'b1602,b1603']
# ['b1608,b1609', 'b1607']
# ['b1614', nan]
# [nan, 'b1618']
# ['b1623', nan]
# ['b1623', nan]
# ['b4409', 'b1624']
# ['b4409,b1625', 'b1624']
# ['b1625,b1626,b1627,b1628,b1629,b1630,b1631,b1632,b1633', 'b1624']
# ['b1626,b1627,b1628,b1629,b1630,b1631,b1632,b1633', nan]
# ['b1634', nan]
# ['b1635', nan]
# [nan, 'b1636,b1637,b1638']
# ['b1641', 'b1640']
# ['b1641', 'b1640']
# ['b1643,b1644,b1645', 'b1642']
# [nan, 'b1646']
# ['b1649,b1650,b1651', 'b1647,b1648']
# ['b1655', 'b1654']
# ['b1655', 'b1654']
# ['b1655', 'b1654']
# ['b1655', 'b1654']
# ['b1656', nan]
# ['b1658', 'b1657,b4602']
# ['b1661', nan]
# ['b1661', nan]
# ['b1661', nan]
# ['b1663', 'b1662']
# ['b1667', 'b1664']
# ['b1668', nan]
# [nan, 'b1669,b1670,b1671,b1672,b1673,b1674']
# [nan, 'b1675']
# [nan, 'b1675']
# ['b1676', 'b1675']
# ['b1676', 'b1675']
# ['b1676', 'b1675']
# ['b1676', 'b1675']
# ['b1677', nan]
# ['b1677', nan]
# ['b1677', nan]
# ['b1677', nan]
# [nan, 'b1678']
# [nan, 'b1679,b1680,b1681,b1682,b1683,b1684']
# [nan, 'b1679,b1680,b1681,b1682,b1683,b1684']
# [nan, 'b1679,b1680,b1681,b1682,b1683,b1684']
# [nan, 'b1685,b1686,b1687']
# ['b1689', nan]
# ['b1703', 'b1702']
# ['b1703', 'b1702']
# ['b1703', 'b1702']
# ['b1703', 'b1702']
# [nan, 'b1706']
# [nan, 'b1707']
# [nan, 'b1707']
# [nan, 'b1709,b1710,b1711']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# ['b4494_1,b4494_2', 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# ['b4494_1,b4494_2', 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# ['b1723', 'b1722']
# ['b1723', 'b1722']
# ['b1723', 'b1722']
# ['b1724,b1725', nan]
# ['b1727', 'b1726']
# ['b1729', nan]
# ['b1732', 'b1731']
# ['b1740', 'b1739']
# ['b1741', nan]
# [nan, 'b1743']
# ['b1749', 'b1744,b1745,b1746,b1747,b1748']
# [nan, 'b1763,b1764,b1765']
# ['b1779,b1780', 'b1777,b1778']
# ['b1779,b1780', 'b1778']
# ['b1783,b1784', 'b1782']
# ['b1783,b1784', 'b1782']
# ['b1786', nan]
# ['b1786', nan]
# ['b1794', 'b1793']
# ['b1794', 'b1793']
# ['', 'b1795']
# [nan, 'b1804']
# [nan, 'b1804']
# ['b1810', nan]
# ['b1814', nan]
# ['b1814', nan]
# ['b1815', nan]
# ['b1817,b1818,b1819', 'b1816']
# ['b1817,b1818,b1819', 'b1816']
# [nan, 'b1822']
# [nan, 'b1822,b1823,b1824']
# [nan, 'b1823,b1824']
# [nan, 'b1823,b1824']
# [nan, 'b1823,b1824']
# [nan, '']
# [nan, '']
# ['b4536', 'b1825']
# ['b4536', 'b1825,b1826']
# ['b1828', 'b1827']
# [nan, 'b1829']
# ['b1836,b1837', nan]
# ['b1837', nan]
# [nan, 'b1838']
# [nan, 'b1838']
# [nan, 'b1838']
# ['b1842,b1843,b1844', 'b1839,b1840,b1841']
# ['b1842,b1843,b1844', 'b1839,b1840,b1841']
# [nan, 'b1845']
# ['b1849', 'b1847,b1848']
# ['b1853', 'b1852']
# [nan, nan]
# ['b1858,b1859', 'b1857']
# ['b1858,b1859', 'b1857']
# ['b1858,b1859', 'b1857']
# ['b1862', 'b1860,b1861']
# ['b1862', 'b1860,b1861,b4677']
# ['b1867,b1868', 'b1866']
# ['b1869,b1870,b1871', nan]
# [nan, nan]
# ['b1876', 'b1874,b1875']
# ['b1877', nan]
# [nan, 'b1891,b1892']
# [nan, 'b1891,b1892']
# [nan, nan]
# [nan, 'b1896,b1897']
# [nan, 'b1896,b1897']
# [nan, 'b4460,b1900,b1901']
# ['b1902', nan]
# ['b1902', nan]
# ['b1902', nan]
# ['b1904', 'b4537']
# ['b1904', 'b4537,b4663']
# ['b1905', nan]
# ['b1905', nan]
# ['b1907', 'b1906']
# [nan, 'b1908']
# [nan, nan]
# [nan, 'b1912']
# ['b1915', 'b1913,b1914']
# ['b1915', 'b1913,b1914']
# [nan, 'b1916']
# [nan, 'b1920,b1921,b1922']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b1929,b1930', 'b1928']
# ['b1932', nan]
# ['b1936', 'b4495_3,b4495_2']
# ['b1936', 'b4495_3,b4495_2,b4495_1']
# ['b1953', 'b1952']
# ['b1955', 'b1952']
# ['b1955', 'b1952']
# ['b1955', nan]
# [nan, 'b1956']
# [nan, 'b1956']
# [nan, 'b1956,b1957']
# ['b1959', 'b1958']
# ['b1959', 'b1958']
# [nan, 'b1962,b1963']
# ['b1967', nan]
# ['b1967', nan]
# ['b1967', nan]
# ['b1971,b1972', nan]
# ['b1973', nan]
# ['b1973', nan]
# ['b1974', nan]
# ['b1974', nan]
# ['b1976', nan]
# [nan, nan]
# ['b1978', nan]
# ['b1978', nan]
# [nan, nan]
# [nan, nan]
# ['b1981', 'b4497']
# ['b1981', 'b4497']
# ['b1982', nan]
# ['b1983', nan]
# [nan, nan]
# [nan, 'b1985']
# [nan, 'b1985']
# [nan, 'b1988']
# [nan, 'b1988']
# [nan, nan]
# [nan, 'b1990']
# [nan, 'b1990']
# [nan, 'b1994,b4640_2,b4640_1']
# [nan, 'b4640_2,b4640_1']
# [nan, 'b4640_1']
# ['b4582_1', 'b4640_1']
# ['b4582_1', 'b4640_1,b4641']
# ['b4582_1', 'b4641']
# ['b4582_1', 'b4641']
# ['b4582_1', 'b4641']
# ['b2011', 'b2010']
# [nan, 'b2012,b2013']
# [nan, 'b2016']
# ['b2018,b2019,b2020,b2021,b2022,b2023,b2024,b2025,b2026', 'b4539,b2017']
# ['b2018,b2019,b2020,b2021,b2022,b2023,b2024,b2025,b2026', 'b4539,b2017']
# [nan, 'b2027']
# [nan, 'b2028']
# [nan, 'b2029']
# [nan, 'b2029,b4571_2']
# [nan, 'b2029,b4571_2']
# [nan, 'b2032,b2033,b2034']
# [nan, 'b2032,b2033,b2034']
# [nan, 'b2037,b2038,b2039,b2040,b2041']
# [nan, 'b2037,b2038,b2039,b2040,b2041']
# [nan, 'b2037,b2038,b2039,b2040,b2041']
# [nan, 'b2042']
# [nan, 'b2042']
# ['b2067', 'b2065,b2066']
# ['b2067', 'b2065,b2066']
# [nan, 'b2072,b2073']
# ['b2074,b2075,b2076,b2077,b2078,b2079', 'b2072,b2073,b4667']
# ['b2074,b2075,b2076,b2077,b2078,b2079', 'b2072,b2073,b4667']
# ['b2080', nan]
# ['b2086', 'b2083,b2085']
# [nan, '']
# [nan, 'b4498_1']
# [nan, 'b4498_1']
# ['b2098,b2099,b2100', 'b2097']
# ['b2106,b2107', 'b2103,b2104']
# [nan, 'b2108,b2109,b2110,b2111,b2112']
# [nan, 'b2112']
# ['b2114', 'b2113']
# [nan, nan]
# ['b2119,b2120,b2121,b2122', nan]
# ['b2119,b2120,b2121,b2122', nan]
# ['b2127', 'b2125,b2126']
# ['b4542', nan]
# [nan, 'b2128,b2129,b2130,b2131']
# ['b2136', 'b2135']
# [nan, 'b2137']
# ['b4679', 'b2139_2,b2139_1']
# ['b4679', 'b2139_2,b2139_1']
# [nan, nan]
# ['b2154', 'b2152,b2153']
# ['b2154', 'b2152,b2153']
# ['b2159', nan]
# ['b2175', nan]
# ['b2175', nan]
# ['b2177,b2178,b2179,b2180', nan]
# [nan, '']
# [nan, '']
# [nan, 'b2181']
# [nan, 'b2181']
# [nan, 'b2181']
# ['b2184', 'b2183']
# ['b2185', nan]
# ['b2187,b2188', 'b2186']
# ['b2187,b2188', 'b2186']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b2190_2,b2190_1']
# ['b2193', 'b2190_2,b2192,b2190_1']
# ['b2209', 'b2194,b2195,b2196,b2197,b2198,b2199,b2200,b2201,b2202,b2203,b2204,b2205,b2206,b2207,b2208']
# [nan, 'b2215']
# [nan, 'b2215']
# ['b2216,b2217', 'b2215']
# ['b2216,b2217', 'b2215']
# ['b2216,b2217', 'b2215']
# ['b2216,b2217', nan]
# ['b2216,b2217', nan]
# ['b2216,b2217', nan]
# ['b2216,b2217', nan]
# ['b2219,b2220', 'b2218']
# ['b2232', 'b2231']
# ['', 'b2237']
# ['b2253,b2254,b2255,b2256,b2257,b4544,b2258', 'b2252']
# ['b2253,b2254,b2255,b2256,b2257,b4544,b2258', 'b2252']
# [nan, 'b2259']
# [nan, 'b2260,b2261,b2262,b2263,b2264,b2265']
# [nan, 'b2260,b2261,b2262,b2263,b2264,b2265']
# [nan, 'b2260,b2261,b2262,b2263,b2264,b2265,b2266']
# ['b2271', 'b2270']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# [nan, nan]
# [nan, 'b2289']
# [nan, 'b2289']
# ['b2290,b2291', 'b2289']
# ['b2296,b2297', 'b2295']
# ['b2296,b2297', 'b2295']
# ['b2296,b2297', 'b2295']
# ['b2296,b2297', nan]
# ['b2296,b2297', nan]
# [nan, 'b2306,b2307,b2308,b2309,b2310']
# [nan, 'b2311,b2312,b2313']
# [nan, 'b2311,b2312,b2313']
# [nan, 'b2316']
# [nan, nan]
# ['b2324', 'b2323']
# ['b2324', 'b2323']
# ['b2324', 'b2323']
# ['b2331', 'b2325,b2326,b2327,b2328,b2329,b2330']
# ['b2331', 'b2325,b2326,b2327,b2328,b2329,b2330']
# [nan, 'b2332,b2333,b2334,b2335,b2336,b4661']
# [nan, 'b2332,b2333,b2334,b2335,b2336,b4661']
# [nan, 'b2332,b2333,b2334,b2335,b2336,b4661']
# [nan, 'b2339']
# [nan, 'b2339']
# [nan, 'b2339']
# [nan, 'b2340']
# [nan, 'b2340']
# [nan, 'b2340']
# ['b2344', 'b2341,b2342,b2343']
# ['b2345', nan]
# ['b2345', nan]
# ['b2345', nan]
# ['b2345', nan]
# ['b2347', 'b2346']
# ['b2349', nan]
# ['b2349', nan]
# ['b2350,b2351,b2352', nan]
# ['b2350,b2351,b2352', nan]
# ['b2353', nan]
# ['b2353', nan]
# ['b2353', nan]
# ['b4501', nan]
# [nan, nan]
# [nan, 'b2367,b2368']
# [nan, 'b2367,b2368']
# [nan, 'b2367,b2368']
# ['b2369,b2370', 'b2367,b2368']
# ['b2369,b2370', 'b2367,b2368']
# ['b2369,b2370', 'b2367,b2368']
# [nan, nan]
# [nan, nan]
# ['b2378', 'b2377']
# ['b2378', 'b2377']
# ['b2378', 'b2377']
# ['b2380,b2381,b2382', 'b2379']
# ['b2380,b2381,b2382', 'b2379']
# ['b2380,b2381,b2382', 'b2379']
# ['b2380,b2381,b2382', 'b2379']
# ['b2393', 'b2392']
# ['b2393', 'b2392']
# [nan, 'b2395']
# ['b2398,b2399', 'b2395']
# ['b2398,b2399', 'b2395']
# [nan, 'b2400']
# [nan, 'b2400']
# [nan, 'b2400']
# ['b2410', 'b2409']
# [nan, 'b4546,b2411']
# [nan, 'b4546,b2411']
# ['b2413', 'b2412']
# ['b2413', 'b2412']
# ['b2413', 'b2412']
# ['b2414', nan]
# ['b2415,b2416,b2417', nan]
# ['b2415,b2416,b2417', nan]
# [nan, nan]
# ['b2415,b2416,b2417', nan]
# [nan, 'b2431,b2432']
# ['b2435,b2436', 'b2433,b2434']
# ['b2435,b2436', 'b2433,b2434']
# [nan, 'b2437,b2438,b2439,b2440,b2441']
# ['b2443', nan]
# [nan, 'b2457,b2458,b2459,b2460,b2461,b2462']
# ['b2464,b2465', 'b2463']
# ['b2464,b2465', 'b2463']
# ['b2469', 'b2468']
# ['b2471,b2472,b4547', 'b4606']
# ['b2471,b2472,b4547', 'b4606']
# ['b2471,b2472,b4547', 'b4606']
# ['b2471,b2472,b4547', 'b4606']
# ['b2471,b2472,b4547', 'b4606']
# [nan, 'b2476']
# ['b2479', 'b2477,b2478']
# ['b2494,b2495', 'b2493']
# ...
# [nan, nan]
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# [nan, 'b0071,b0072,b0073,b0074,b0075']
# ['b0076', 'b0071,b0072,b0073,b0074,b0075']
# ['b0081,b0082,b0083,b0084,b0085,b0086,b0087,b0088,b0089,b0090,b0091,b0092,b0093,b0094,b0095,b0096', nan]
# ['b0081,b0082,b0083,b0084,b0085,b0086,b0087,b0088,b0089,b0090,b0091,b0092,b0093,b0094,b0095,b0096', nan]
# [nan, nan]
# ['b0104', 'b0101,b0102,b0103']
# ['b0104', 'b0101,b0102,b0103']
# ['b0118', 'b0117']
# ['b0118', 'b0117']
# ['b0118', 'b0117']
# ['b0118', nan]
# ['b0169,b0170', 'b0166,b0167,b0168']
# ['b0169,b0170', 'b0166,b0167,b0168']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b0207', nan]
# [nan, nan]
# ['b0217', nan]
# ['b0217', nan]
# [nan, '']
# [nan, '']
# ['b0380', 'b0379']
# ['b0380', 'b0379']
# ['', nan]
# ['b0388,b0389,b0390', nan]
# ['b0388,b0389,b0390', nan]
# [nan, 'b0428,b0429,b0430,b0431,b0432']
# [nan, 'b0428,b0429,b0430,b0431,b0432']
# [nan, 'b0459']
# [nan, 'b0459,b0460,b0461']
# [nan, 'b0459,b0460,b0461']
# [nan, 'b0460,b0461']
# [nan, 'b0460,b0461']
# [nan, 'b0460,b0461']
# [nan, 'b0535']
# [nan, 'b0552']
# [nan, 'b0553_2,b0553_1']
# ['b0554,b0555,b0556', 'b0553_2,b0553_1']
# ['b0554,b0555,b0556', 'b0553_2,b0553_1']
# ['b0554,b0555,b0556', 'b0553_2,b0553_1']
# [nan, nan]
# [nan, 'b0565,b0566']
# [nan, 'b0565,b0566']
# ['b0598', nan]
# ['b0598', nan]
# [nan, 'b0610']
# ['b0622', nan]
# ['b0623', nan]
# [nan, nan]
# [nan, nan]
# ['b0681,b0682', nan]
# [nan, 'b0683,b4637,b0684']
# [nan, 'b0683,b4637,b0684']
# [nan, 'b0683,b4637,b0684']
# [nan, nan]
# [nan, 'b0720']
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', 'b0720']
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', nan]
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', nan]
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', nan]
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', nan]
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', nan]
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', nan]
# ['b0721,b0722,b0723,b0724,b0726,b0727,b0728,b0729', nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b0750,b0751', nan]
# ['b0750,b0751', nan]
# [nan, 'b0812']
# ['b0814', 'b0813']
# ['b0817,b0818', 'b0815,b4705']
# ['b0820', 'b0819']
# ['b0820', 'b0819']
# ['b0881', 'b0880']
# ['b0881', 'b0880']
# ['b0882', nan]
# ['b0882', nan]
# [nan, nan]
# [nan, '']
# [nan, 'b0884']
# [nan, 'b0884']
# [nan, 'b0884']
# ['b0910,b0911,b0912', nan]
# ['b0910,b0911,b0912', nan]
# ['b0910,b0911,b0912', nan]
# ['b0910,b0911,b0912,b0913,b0914,b0915,b0916', nan]
# ['b0926,b0927', nan]
# ['b0926,b0927', nan]
# ['b0926,b0927', nan]
# [nan, 'b0928']
# [nan, nan]
# [nan, 'b0929']
# [nan, 'b0930']
# ['b0953', nan]
# ['', 'b0954']
# [nan, nan]
# [nan, 'b0957']
# [nan, 'b0957']
# [nan, 'b0958']
# ['b0972,b0973,b0974,b0975,b0976,b0977', 'b0970']
# ['b4516,b0988', 'b0987']
# ['b0988', nan]
# [nan, '']
# [nan, '']
# [nan, '']
# ['b0990', 'b0989']
# ['b0990', 'b0989']
# ['b0990', 'b0989']
# ['b1020', nan]
# ['b1025', 'b1021,b1022,b1023,b1024']
# ['b1025', nan]
# ['b1033', nan]
# [nan, 'b1037,b1038,b1039,b1040']
# ['b1085,b1086', 'b1084']
# ['b1085,b1086', 'b1084']
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', 'b1087']
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', 'b1087']
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1088,b1089,b1090,b1091,b1092,b1093,b1094,b1095', nan]
# ['b1136', 'b1134,b1135']
# ['b1136', 'b1134,b1135']
# ['b1136', 'b1134,b1135']
# ['b1136', 'b1134,b1135']
# [nan, nan]
# ['b1205', 'b1203,b1204']
# ['b1205', 'b1203,b1204']
# [nan, 'b1207,b1208,b1209']
# [nan, 'b1207,b1208,b1209']
# [nan, 'b4419']
# [nan, 'b4423']
# [nan, 'b1229']
# ['b1276', nan]
# [nan, 'b1334']
# ['b1357,b1358,b1359,b1360,b1361,b1362', 'b1356']
# ['b4529', 'b1377,b1378']
# ['b1415', nan]
# [nan, 'b4493_2,b4493_1']
# [nan, 'b4493_2,b4493_1']
# ['b1418', 'b4493_2,b4493_1']
# ['b1418', 'b4493_2,b4493_1']
# ['b1418', 'b4493_2,b4493_1']
# ['b1418', 'b4493_2,b4493_1']
# ['b1418,b1419', nan]
# ['b1421', 'b4428,b1420']
# ['b1423', 'b1422']
# [nan, 'b1492,b1493']
# [nan, 'b1492,b1493']
# ['b1558', 'b1557']
# ['b1558', 'b1557']
# [nan, nan]
# ['b1625,b1626,b1627,b1628,b1629,b1630,b1631,b1632,b1633', nan]
# ['b1655', 'b1654']
# ['b1661', nan]
# ['b1661', nan]
# [nan, nan]
# ['b1667', 'b1664']
# ['b1667', 'b1664']
# ['b1676', 'b1675']
# ['b1677', nan]
# ['b1677', nan]
# ['b1677', nan]
# ['b1677', nan]
# [nan, 'b1702']
# ['b1703', 'b1702']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# [nan, 'b1712,b1713,b1714,b1715,b1716,b1717,b1718,b1719']
# [nan, nan]
# ['b1723', 'b1722']
# [nan, 'b1777']
# [nan, 'b1777,b1778']
# ['b1779,b1780', 'b1778']
# ['b1779,b1780', 'b1778']
# ['b1779,b1780', 'b1778']
# ['b1779,b1780', nan]
# ['b1817,b1818,b1819', 'b1816']
# [nan, 'b1822']
# [nan, 'b1822']
# [nan, 'b1823,b1824']
# [nan, 'b1823,b1824']
# [nan, 'b1823,b1824']
# [nan, '']
# [nan, 'b1830,b1831']
# ['b1833,b1834', 'b1832']
# ['', nan]
# [nan, 'b1838']
# [nan, 'b1838']
# [nan, 'b1838']
# [nan, 'b1838']
# [nan, 'b1838']
# ['b1842,b1843,b1844', 'b1839,b1840,b1841']
# [nan, nan]
# [nan, 'b1908']
# [nan, 'b1908']
# [nan, 'b1908']
# [nan, nan]
# [nan, 'b1912']
# ['b1976', nan]
# ['b1976', nan]
# ['b1976', nan]
# [nan, nan]
# ['b1978', nan]
# ['b1978', nan]
# [nan, 'b1985']
# [nan, 'b1985']
# [nan, 'b1988']
# ['b2018,b2019,b2020,b2021,b2022,b2023,b2024,b2025,b2026', 'b4539,b2017']
# [nan, 'b2037,b2038,b2039,b2040,b2041']
# [nan, 'b2037,b2038,b2039,b2040,b2041']
# [nan, 'b2037,b2038,b2039,b2040,b2041']
# [nan, 'b2037,b2038,b2039,b2040,b2041']
# [nan, 'b2042']
# [nan, 'b2072,b2073']
# [nan, 'b2072,b2073,b4667']
# ['b2074,b2075,b2076,b2077,b2078,b2079', 'b2072,b2073,b4667']
# ['b2074,b2075,b2076,b2077,b2078,b2079', 'b4667,b4668']
# [nan, '']
# [nan, 'b4498_1']
# [nan, 'b4498_1']
# [nan, 'b4498_1']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# [nan, 'b2091,b2092_2,b2092_1,b2093,b2094,b2095,b2096']
# ['b2175', nan]
# ['b2175', nan]
# ['b2175', nan]
# ['b2175', nan]
# [nan, '']
# [nan, 'b2181']
# [nan, 'b2181']
# ['b2185', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b2215']
# ['b2216,b2217', 'b2215']
# [nan, 'b2276,b2277,b2278,b2279,b2280,b2281,b2282,b2283,b2284,b2285,b2286,b2287,b2288']
# ['b2369,b2370', 'b2367,b2368']
# ['b2369,b2370', 'b2367,b2368']
# ['b2369,b2370', 'b2367,b2368']
# ['b2369,b2370', nan]
# [nan, 'b2395']
# [nan, 'b2400']
# [nan, 'b2400']
# [nan, nan]
# [nan, nan]
# [nan, 'b2412']
# ['b2413', 'b2412']
# [nan, nan]
# ['b2415,b2416,b2417', nan]
# ['b2415,b2416,b2417', nan]
# ['b2415,b2416,b2417', nan]
# ['b2504', 'b2503']
# ['b2504', 'b2503']
# ['b2505,b2506', nan]
# ['b2509', 'b2507,b2508']
# ['b2509', 'b2507,b2508']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b2533', 'b2532']
# [nan, 'b2556']
# [nan, 'b2570,b2571,b2572,b2573']
# ['b2585', nan]
# ['b2586', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b2587']
# [nan, 'b2587']
# [nan, 'b2587']
# [nan, 'b2587']
# [nan, 'b2587']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b2595', 'b2593,b2594']
# ['b2597', nan]
# ['b2597', nan]
# ['b2598,b2599', nan]
# [nan, 'b2606,b2607,b2608,b2609']
# [nan, 'b2606,b2607,b2608,b2609']
# [nan, nan]
# ['b2622', nan]
# ['b2622', nan]
# ['b2630,b2631', nan]
# ['b2673,b2674,b2675,b2676', nan]
# ['b2673,b2674,b2675,b2676', nan]
# [nan, 'b2689,b2690']
# [nan, nan]
# [nan, nan]
# [nan, '']
# [nan, '']
# [nan, 'b2696']
# [nan, nan]
# [nan, 'b2741,b2742']
# [nan, nan]
# [nan, nan]
# ['b2775,b2776', 'b2774']
# [nan, 'b2790,b2791,b2792']
# [nan, 'b2790,b2791,b2792']
# [nan, 'b2790,b2791,b2792']
# [nan, 'b2813']
# ['b2845', 'b2844']
# [nan, 'b2863']
# ['b2910', 'b2906,b2907,b2908,b2909']
# ['b2910', 'b2906,b2907,b2908,b2909']
# ['b2912', nan]
# ['b2912', '']
# [nan, 'b2913']
# [nan, 'b2913']
# ['b2942', nan]
# ['b2942', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b2968,b2969']
# [nan, 'b2968,b2969']
# [nan, 'b3005,b3006']
# ['b3008', 'b3005,b3006']
# [nan, 'b3030,b3031,b3032,b3033,b3034']
# ['b3035,b3037,b3038', 'b3030,b3031,b3032,b3033,b3034']
# ['b3042', 'b3041']
# ['b4664', nan]
# ['b4664,b4666', nan]
# ['b4664,b4666', nan]
# ['b4666', nan]
# ['', nan]
# ['b3065,b3066,b3067', 'b3064']
# ['b3065,b3066,b3067', nan]
# ['b3088', nan]
# [nan, 'b3162,b4685']
# [nan, 'b3162,b4685']
# [nan, 'b3163']
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# [nan, 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3172', 'b3164,b3165,b3166,b3167,b3168,b3169,b3170']
# ['b3172', nan]
# [nan, 'b3173']
# [nan, 'b3175']
# ['b3180', 'b3178,b3179']
# ['b3180', 'b3178,b3179']
# ['', 'b3178,b3179']
# ['b3182', 'b3181']
# ['b3187', 'b3183,b3184,b3185,b3186']
# ['b3207', nan]
# [nan, 'b3208,b3209']
# [nan, 'b3208,b3209']
# [nan, 'b3208,b3209']
# [nan, 'b3211']
# [nan, 'b3211']
# ['b3212,b3213,b3214', 'b3211']
# ['b3212,b3213,b3214', nan]
# ['b3212,b3213,b3214', nan]
# [nan, 'b3228,b3229']
# [nan, 'b3228,b3229']
# [nan, 'b3230,b3231']
# [nan, 'b3236']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b3279', nan]
# ['b3279', nan]
# [nan, 'b3280,b3281,b3282,b3283']
# [nan, 'b3280,b3281,b3282,b3283,b3284']
# [nan, 'b3292,b3293,b3294,b3295,b3296,b3297,b3298']
# [nan, 'b3294,b3295,b3296,b3297,b3298']
# [nan, 'b3294,b3295,b3296,b3297,b3298']
# [nan, 'b3294,b3295,b3296,b3297,b3298']
# [nan, 'b3294,b3295,b3296,b3297,b3298']
# [nan, 'b3299,b3300,b3301,b3302,b3303,b3304,b3305,b3306,b3307,b3308,b3309,b3310']
# [nan, 'b3299,b3300,b3301,b3302,b3303,b3304,b3305,b3306,b3307,b3308,b3309,b3310']
# [nan, 'b3299,b3300,b3301,b3302,b3303,b3304,b3305,b3306,b3307,b3308,b3309,b3310']
# [nan, 'b3299,b3300,b3301,b3302,b3303,b3304,b3305,b3306,b3307,b3308,b3309,b3310']
# [nan, 'b3299,b3300,b3301,b3302,b3303,b3304,b3305,b3306,b3307,b3308,b3309,b3310']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3311,b3312,b3313,b3314,b3315,b3316,b3317,b3318,b3319,b3320,b3321']
# [nan, 'b3336,b3337']
# [nan, 'b3336,b3337']
# [nan, 'b3336,b3337']
# [nan, 'b3339,b3340,b3341,b3342']
# [nan, 'b3339,b3340,b3341,b3342']
# [nan, 'b3339,b3340,b3341,b3342']
# [nan, 'b3339,b3340,b3341,b3342']
# [nan, 'b3339,b3340,b3341,b3342,b3343,b3344,b3345,b3346']
# ['b3357', 'b3356']
# ['b3357,b3358', 'b3356']
# ['b3398', 'b3397']
# ['b3398', 'b3397']
# ['b3398', 'b3397']
# ['b3441', 'b3440']
# ['b3441', 'b3440']
# ['b3459', 'b3454,b3455,b3456,b3457,b3458']
# [nan, 'b3460']
# [nan, 'b3461']
# [nan, 'b3461']
# [nan, 'b3508,b3509,b3510']
# [nan, 'b3508,b3509,b3510']
# ['b3511', 'b3508,b3509,b3510']
# ['b3511', nan]
# [nan, nan]
# [nan, nan]
# [nan, 'b3515,b3516,b3517']
# [nan, 'b3515,b3516,b3517']
# [nan, nan]
# [nan, 'b3515,b3516,b3517']
# [nan, 'b3515,b3516,b3517']
# [nan, 'b3515,b3516,b3517']
# [nan, 'b3515,b3516,b3517']
# [nan, 'b3534']
# ['b3536,b3537,b3538', 'b3534,b3535']
# ['b3536,b3537,b3538', 'b3535']
# ['b3536,b3537,b3538', nan]
# ['b3536,b3537,b3538', nan]
# [nan, nan]
# [nan, 'b3540,b3541,b3542,b3543,b3544']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b3555,b3556', nan]
# ['b3556', nan]
# ['b3556,b3557', '']
# [nan, 'b3570']
# [nan, 'b3570']
# [nan, 'b3635,b3636,b3637,b3638']
# [nan, 'b3635,b3636,b3637,b3638']
# [nan, 'b3667,b3668,b3669,b3670,b3671,b3672']
# [nan, 'b3667,b3668,b3669,b3670,b3671,b3672']
# [nan, 'b3667,b3668,b3669,b3670,b3671,b3672']
# ['b4618', 'b3667,b3668,b3669,b3670,b3671,b3672']
# ['b4618', 'b3667,b3668,b3669,b3670,b3671,b3672']
# ['b3703,b3704', 'b3700,b3701,b3702']
# ['b3703,b3704', 'b3700,b3701,b3702']
# ['b3703,b3704', nan]
# ['b3703,b3704,b4557', nan]
# ['b3707,b3708,b3709', nan]
# ['b3707,b3708,b3709', nan]
# ['b3707,b3708,b3709', nan]
# [nan, 'b3731,b3732,b3733,b3734,b3735,b3736,b3737,b3738,b3739']
# [nan, 'b3731,b3732,b3733,b3734,b3735,b3736,b3737,b3738,b3739']
# [nan, 'b3731,b3732,b3733,b3734,b3735,b3736,b3737,b3738,b3739']
# [nan, 'b3731,b3732,b3733,b3734,b3735,b3736,b3737,b3738,b3739']
# [nan, 'b3731,b3732,b3733,b3734,b3735,b3736,b3737,b3738,b3739']
# [nan, 'b3731,b3732,b3733,b3734,b3735,b3736,b3737,b3738,b3739']
# ['b3748,b3749,b3750,b3751,b3752,b3753', nan]
# [nan, 'b3754,b3755']
# [nan, 'b3754,b3755']
# [nan, 'b3754,b3755']
# [nan, 'b3754,b3755']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', 'b3765']
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', 'b3765']
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', 'b3765']
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', nan]
# ['b3766,b4669,b4488_1,b4488_2,b3769,b3770,b3771,b3772', nan]
# ['b3781', 'b3780']
# ['b3783', nan]
# [nan, nan]
# [nan, nan]
# ['b3800', nan]
# ['b3800', nan]
# [nan, nan]
# ['b3847,b3848,b3849,b3850', nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b3871', 'b3868,b3869,b3870']
# ['b3936', 'b3935']
# ['b3936', 'b3935']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b3972,b3973', nan]
# ['b3972,b3973', nan]
# [nan, 'b3974']
# [nan, 'b3974']
# ['b3980', nan]
# ['b3981,b3982', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3983,b3984,b3985,b3986,b3987,b3988', nan]
# ['b3996,b3997,b3998', 'b3990,b3991,b4407,b3992,b3993,b3994,b3995']
# [nan, 'b4005,b4006']
# [nan, 'b4005,b4006']
# [nan, 'b4005,b4006']
# [nan, 'b4005,b4006']
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# [nan, nan]
# ['b4011', nan]
# ['b4011', nan]
# ['b4011', nan]
# ['b4014,b4015,b4016', nan]
# ['b4014,b4015,b4016', nan]
# ['b4014,b4015,b4016', nan]
# [nan, nan]
# ['b4014,b4015,b4016', nan]
# [nan, 'b4654_2,b4654_1']
# [nan, 'b4654_2,b4654_1']
# ['', nan]
# ['b4148', nan]
# ['b4162', nan]
# [nan, nan]
# [nan, nan]
# ['b4670', nan]
# ['b4670', nan]
# ['b4670', nan]
# ['b4670', nan]
# ['b4167,b4168,b4169,b4170,b4171,b4172,b4173,b4174,b4175', nan]
# ['b4167,b4168,b4169,b4170,b4171,b4172,b4173,b4174,b4175', nan]
# ['b4167,b4168,b4169,b4170,b4171,b4172,b4173,b4174,b4175', nan]
# ['b4177', nan]
# ['b4178,b4179,b4180,b4181,b4182', nan]
# ['b4200,b4201,b4202,b4203', 'b4199']
# ['b4200,b4201,b4202,b4203', 'b4199']
# ['b4702,b4242', 'b4241']
# ['b4702,b4242', 'b4241']
# [nan, 'b4244,b4245,b4246']
# ['b4271', 'b4269']
# [nan, 'b4307,b4566']
# [nan, 'b4307,b4566']
# ['b4342', nan]
# ['b4342', nan]
# ['b4342', nan]
# ['b4365,b4366', nan]
# [nan, nan]
# [nan, nan]
# ['b4567', 'b4367']
# ['', 'b4367']
# [nan, nan]
# ['b4381,b4382,b4383,b4384', nan]
# ['b4381,b4382,b4383,b4384', nan]
# ['b4402', 'b4401']
# ['b4402', 'b4401']

# %%
len(df)
# Out:
# 1921

# %%
len(locus)

# %%
TF_list.to_csv(org_folder+'TF_list.csv')

# %%
for i in range (0, len(database)): 
    peak_annot_DF = annotate_peaks(TF_list[i], TF_condition[i],database[i],500,DF_gene_info).fillna('')
    final_annot_DF = validate_peak_info(peak_annot_DF,DF_gene_info)
    venn_files = Venn_data_gen(final_annot_DF)
    final_annot_DF.to_json(out_data_table+TF_list[i]+'_binding_table.json',orient='records')
    venn_files.to_json(path.join(out_data_venn, TF_list[i]+'_venn.json'),orient='records')
    binding_width_gen(TF_list[i], database[i], '../../data/e_coli/NC_000913_3/binding_widths/')
    peak_position_gen(TF_list[i], final_annot_DF, '../../data/e_coli/NC_000913_3/positions/')

# %%
file = 'phob_M9P_curated.gff'
df = pd.read_csv(org_folder+strain+"/curated_input/"+file,index_col=0, 
                                 delimiter='\t', header=None, 
                                 names = ['ref','condition', 'condition_name', 
                                          "binding_peak_start",'binding_peak_end', 
                                          'binding_peak_strength', 'direction', '.','ID'])
df = df.set_index(pd.Series(range(1,len(df)+1)))
df.head()
# Out:
#   condition   condition_name  binding_peak_start  binding_peak_end  \
# 1      MACE   _filtered_0.95              417086            417115
# 2      MACE   _filtered_0.95             1198372           1198398
# 3      MACE   _filtered_0.95             2774093           2774126
# 4      MACE   _filtered_0.95             2774321           2774354
# 5      MACE   _filtered_0.95             3284518           3284522
#
#    binding_peak_strength direction  .   ID
# 1                   1.92         +  .  SFB
# 2                   1.88         +  .  GSB
# 3                   1.82         +  .  SFB
# 4                   1.82         +  .  SRB
# 5                   1.23         +  .  GSB

# %%
peak_annot_DF = annotate_peaks('PhoB', 'M9P', df, 500, DF_gene_info)
final_annot_DF = validate_peak_info(peak_annot_DF,DF_gene_info)

final_annot_DF
# Out:
#       index   condition  binding_peak_start  binding_peak_end  \
# 1    PhoB-1  phob + M9P              417086            417115
# 2    PhoB-2  phob + M9P             1198372           1198398
# 3    PhoB-3  phob + M9P             2774093           2774126
# 4    PhoB-4  phob + M9P             2774321           2774354
# 5    PhoB-5  phob + M9P             3284518           3284522
# 6    PhoB-6  phob + M9P             3321253           3321291
# 7    PhoB-7  phob + M9P             3321485           3321524
# 8    PhoB-8  phob + M9P             3911549           3911584
# 9    PhoB-9  phob + M9P             3911629           3911670
# 10  PhoB-10  phob + M9P             4003031           4003074
# 11  PhoB-11  phob + M9P             4058198           4058242
#
#     binding_peak_strength                   target_locus  \
# 1                    1.92        b0399,b0400,b0397,b0398
# 2                    1.88              b1139,b1137,b1138
# 3                    1.82
# 4                    1.82
# 5                    1.23        b3138,b3139,b3140,b3141
# 6                    1.69                          b3173
# 7                    2.08                          b3173
# 8                    8.13  b3724,b3725,b3726,b3727,b3728
# 9                    6.93  b3724,b3725,b3726,b3727,b3728
# 10                   2.05                    b3817,b3818
# 11                   1.65        b3871,b3868,b3869,b3870
#
#                 target_genes
# 1        phoB,phoR,sbcC,sbcD
# 2              lit,ymfD,ymfE
# 3
# 4
# 5        agaB,agaC,agaD,agaI
# 6                       yhbX
# 7                       yhbX
# 8   phoU,pstB,pstA,pstC,pstS
# 9   phoU,pstB,pstA,pstC,pstS
# 10                 yigF,yigG
# 11       typA,glnG,glnL,glnA

# %%
len(df)
# Out:
# 136

# %%
float('nan')
# Out:
# nan

# %%
[i for i in peak_annot_DF.genes_m][0]
# Out:
# nan

# %%
peak_annot_DF
# Out:
#        index   condition  binding_peak_start  binding_peak_end  \
# 1      Dps-1  dps + expo                 235               261
# 2      Dps-2  dps + expo              111536            111543
# 3      Dps-3  dps + expo              167456            167466
# 4      Dps-4  dps + expo              246985            247015
# 5      Dps-5  dps + expo              256349            256373
# ..       ...         ...                 ...               ...
# 132  Dps-132  dps + expo             4406423           4406463
# 133  Dps-133  dps + expo             4474258           4474288
# 134  Dps-134  dps + expo             4527665           4527698
# 135  Dps-135  dps + expo             4566141           4566162
# 136  Dps-136  dps + expo             4605695           4605707
#
#      binding_peak_strength                 TU_p  \
# 1                     1.50              thrLABC
# 2                     2.28
# 3                     1.95              fhuACDB
# 4                     1.13                 yafL
# 5                     1.54             gpt,frsA
# ..                     ...                  ...
# 132                   1.01  nsrR-rnr-rlmB-yjfIJ
# 133                   1.11                 bdcR
# 134                   1.11                  NaN
# 135                   1.19                  NaN
# 136                   1.77                 yjjZ
#
#                            genes_p        TU_m  \
# 1          b0001,b0002,b0003,b0004         NaN
# 2
# 3          b0150,b0151,b0152,b0153         NaN
# 4                            b0227   dinJ-yafQ
# 5                      b0238,b0239         NaN
# ..                             ...         ...
# 132  b4178,b4179,b4180,b4181,b4182         NaN
# 133                          b4251        bdcA
# 134                            NaN  sgcXBCQAER
# 135                            NaN       yjiML
# 136                          b4567        fhuF
#
#                                        genes_m
# 1                                          NaN
# 2
# 3                                          NaN
# 4                                  b0225,b0226
# 5                                          NaN
# ..                                         ...
# 132                                        NaN
# 133                                      b4249
# 134  b4300,b4301,b4302,b4303,b4304,b4565,b4305
# 135                                b4334,b4335
# 136                                      b4367
#
# [136 rows x 9 columns]

# %%
def annotate_peaks(TF_name, TF_condition, peak_df,margin,gene_info):
    
    res_df = peak_df.copy()
#     TF = peak_df.condition_name[1][:4]
    for i,row in res_df.iterrows():
        pos = row['binding_peak_start']
        # Identify genes within MARGIN nt of binding peak
        close_genes = gene_info[(gene_info.start_codon_pos > pos-margin) 
                                & (gene_info.start_codon_pos < pos+margin)]
        for strand,group in close_genes.groupby('strand'):
            #Remove genes that are completely transcribed before binding peak
            if strand == '+':
                group = group[group.stop > pos]
            else:
                group = group[group.start < pos]

            operon = group.operon.unique()
            # Ensure that we're only identifying one operon on either side of binding peak
            if len(operon) > 1:
                print (operon)

            # Get all genes in operon
            bnums = gene_info[gene_info.operon.isin(operon)].index
            
            ## Add gene information to dataframe
            if strand == '+':
                res_df.loc[i,'TU_p'] = ','.join(operon)
                res_df.loc[i,'genes_p'] = ','.join(bnums)
            else:
                res_df.loc[i,'TU_m'] = ','.join(operon)
                res_df.loc[i,'genes_m'] = ','.join(bnums)
    res_df['index'] = [TF_name +'-' + str(i) for i in range(1,peak_df.shape[0]+1)]
    res_df['condition'] = [ TF_name.lower() + " + " + TF_condition for i in peak_df.condition_name]
#     [peak_df.condition_name[2][:4]+' + '+peak_df.condition_name[1][5:8]]*peak_df.shape[0]
    cols = ['index','condition','binding_peak_start','binding_peak_end',
            'binding_peak_strength','TU_p','genes_p','TU_m','genes_m']
    return res_df.reindex(columns = cols)
