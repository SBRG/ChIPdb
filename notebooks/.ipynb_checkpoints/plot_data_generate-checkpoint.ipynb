# %% [markdown]
# # Data Generation for Plots Notebook

# %% [markdown]
# This notebook generates data used to contruct `binding peak` tables and `venn diagrams` for ChIP-pro, as well as other  visuals. But before you run the notebook, make sure of the following:
#
# > Make sure to rename TF in the gff file to match the TF convention and not gene convension.

# %%
import numpy as np 
import pandas as pd
import glob
import urllib                      
import gzip
from collections import defaultdict

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Functions

# %% [markdown]
# ## Generate Binding peaks

# %% [markdown]
# This function assigns bindings peaks for each TF and fins the corresponsing gene targets using the `gene_info.csv` table.

# %%
def annotate_peaks(TF_name, TF_condition, peak_df,margin,gene_info):
    
    res_df = peak_df.copy()
#     TF = peak_df.condition_name[1][:4]
    for i,row in res_df.iterrows():
        pos = row['binding_peak_start']
        # Identify genes within MARGIN nt of binding peak
        close_genes = gene_info[(gene_info.start_codon_pos > pos-margin) 
                                & (gene_info.start_codon_pos < pos+margin)]
        for strand,group in close_genes.groupby('strand'):
            #Remove genes that are completely transcribed before binding peak
            if strand == '+':
                group = group[group.stop > pos]
            else:
                group = group[group.start < pos]

            operon = group.operon.unique()
            # Ensure that we're only identifying one operon on either side of binding peak
#             if len(operon) > 1:
#                 print (operon)

            # Get all genes in operon
            bnums = gene_info[gene_info.operon.isin(operon)].index
            
            ## Add gene information to dataframe
            if strand == '+':
                res_df.loc[i,'TU_p'] = ','.join(operon)
                res_df.loc[i,'genes_p'] = ','.join(bnums)
            else:
                res_df.loc[i,'TU_m'] = ','.join(operon)
                res_df.loc[i,'genes_m'] = ','.join(bnums)
    res_df['index'] = [TF_name +'-' + str(i) for i in range(1,peak_df.shape[0]+1)]
    res_df['condition'] = [ TF_name.lower() + " + " + TF_condition for i in peak_df.condition_name]
#     [peak_df.condition_name[2][:4]+' + '+peak_df.condition_name[1][5:8]]*peak_df.shape[0]
    cols = ['index','condition','binding_peak_start','binding_peak_end',
            'binding_peak_strength','TU_p','genes_p','TU_m','genes_m']
    return res_df.reindex(columns = cols)

# %% [markdown]
# ## Validate Binding Peaks

# %% [markdown]
# this function validates the accuracy of every gene target from the already indetified gene list for every binding site, identified from the previous function

# %%
# helper for closest gene

def closest_locus_nc000913(peak_start, peak_stop, gene_info):
    df_pos = gene_info[gene_info.strand=="+"]
    df_pos = df_pos[df_pos.stop >= peak_start]
    try:
        gene_pos = df_pos.iloc[0,:]['gene_name']
        dist_pos = abs(peak_stop - df_pos.iloc[0,:]['start'])
    except:
        dist_pos = np.inf
    
    df_neg = gene_info[gene_info.strand=="-"]
    df_neg = df_neg[df_neg.start <= peak_stop]
    try:
        gene_neg = df_neg.iloc[-1,:]['gene_name']
        dist_neg = abs(peak_start - df_neg.iloc[-1,:]['stop'])
    except:
        dist_neg = np.inf
    
    if dist_pos <= dist_neg:
        return(gene_pos)
    else:
        return(gene_neg)

# %%
def validate_peak_info(df,gene_info):
    locusTag = defaultdict(list)
    geneName = defaultdict(list)
    for i,row in df.iterrows():
        BP = row['binding_peak_start']
        idx_name = i
        genes = [row['genes_p'] , row['genes_m']]
        if ((genes[0] == '' or str(genes[0]) == 'nan') & (genes[1] == '' or str(genes[1]) == 'nan')):
            locusTag[idx_name].append('')
            geneName[idx_name].append('')
        for gene in genes:
            if gene == '' or str(gene) == 'nan':
                continue 
            gene_list = gene.split(',')
            for g in gene_list: 
                name = DF_gene_info.loc[g].gene_name 
                strand = DF_gene_info.loc[g].strand 
                start = DF_gene_info.loc[g].start
                stop = DF_gene_info.loc[g].stop
                if ((start >= BP) & (stop >= BP) & (strand == '+')) | ((start <= BP) & (stop <= BP) & (strand == '-')):
                        locusTag[idx_name].append(g)
                        geneName[idx_name].append(name)
                elif ((start <= BP) & (stop >= BP)) | ((start >= BP) & (stop <= BP)):
                    locusTag[idx_name].append(g)
                    geneName[idx_name].append(name)
    
    for k, v in locusTag.items():
        if ((len(v) == 1) & (v[0] == '')): 
            locusTag[k] = ''
            continue
        genes = ','.join(locusTag[k])
        locusTag[k] = genes

    for k, v in geneName.items():
        if ((len(v) == 1) & (v[0] == '')): 
            geneName[k] = ''
            continue
        genes = ','.join(geneName[k])
        geneName[k] = genes

    df_complete = df.loc[:,['index','condition','binding_peak_start',
                            'binding_peak_end','binding_peak_strength']]
    df_complete['target_locus'] = locusTag.values()
    df_complete['target_genes'] = geneName.values()
    df_complete['closest_gene'] = [closest_locus_nc000913(df_complete.binding_peak_start.iloc[i], 
                                           df_complete.binding_peak_end.iloc[i],
                                           gene_info) for i in range(len(df_complete))]
    return df_complete

# %% [markdown]
# # Venn Diagrams

# %% [markdown]
# Make sure to update the list of `TF_names` as Ye adds more gff files into the dropbox

# %%
def Venn_data_gen(Peak_DF, TRN_data): 
    TF_name = Peak_DF['index'][1].split("-")[0].split(" ")[0]
    gene_list = [i for i in Peak_DF.target_genes if i != '']
    chip_data= ','.join(list(gene_list)).split(',')
    reg_data = TRN_data.loc[TF_name].gene_name.to_list()
    all_genes = [i  for i in chip_data if i not in reg_data] + reg_data
    
    
    TF = TF_name
    reg_genes=reg_data
    reg_only = []
    chip_genes=chip_data
    chip_only = []
    shared_genes=[]
    for i in all_genes: 
        if (i in reg_data) & (i not in chip_data):
            reg_only.append(i)
        elif (i in chip_data) & (i not in reg_data):
            chip_only.append(i)
        elif (i in chip_data) & (i in reg_data):
            shared_genes.append(i)
            
    values = [TF,
          len(reg_genes),
          len(reg_only),
          len(chip_genes),
          len(chip_only),
          len(shared_genes),
          len(all_genes)]
    
    index_name = ['TF',
              'reg_genes',
              'reg_only',
              'chip_genes',
              'chip_only',
              'shared_genes',
              'all_genes']
    
    genes = ['; '.join(TRN_data.source[TRN_data.index == TF_name].unique()),
         reg_genes,
         reg_only,
         chip_genes,
         chip_only,
         shared_genes,
         all_genes]
    
    same1 = defaultdict(list)
    for i in range(0,len(index_name)):
        same1[index_name[i]].append(values[i])

    finall = pd.DataFrame.from_dict(same1, orient='index', columns = ['value'])
    finall['list'] = genes
    for i, row in finall.iterrows(): 
        if row.value == 0:
            finall.list[i] = ''
    return finall

# %% [markdown]
# # Binding Width Histograms

# %%
def binding_width_gen(TF, peak_df,out_dir): 
    widths = pd.DataFrame(peak_df.binding_peak_end - peak_df.binding_peak_start + 1, columns=["binding_width"])
    widths.to_csv(out_dir+TF+'_widths.csv')

# %% [markdown]
# # Peak Position Scatter

# %%
def peak_position_gen(TF, final_annot_DF,out_dir): 
    peak_scatter_df = pd.DataFrame(columns=final_annot_DF.columns.to_list()+['gene'] +['normalized_dist'])
    counter=0

    for i in range(len(final_annot_DF)):
        peak = final_annot_DF.loc[i+1,:]
        peak_center = np.mean([peak.binding_peak_start, peak.binding_peak_end])

        gene = peak.closest_gene
        gene_info = DF_gene_info[DF_gene_info.gene_name == gene]
        try:
            if gene_info.strand[0] == "-":
                dist = float((gene_info.stop - peak_center)/gene_info.length)
            else:
                dist = float((peak_center - gene_info.start)/gene_info.length)
            peak_scatter_df.loc[counter] = peak.to_list()+[gene, dist]
            counter+=1
        except:
            continue

    peak_scatter_df['binding_peak_center'] = peak_scatter_df.binding_peak_start/2 + peak_scatter_df.binding_peak_end/2
    peak_scatter_df.to_csv(out_dir+TF+'_positions.csv')

# %% [markdown]
# # E. coli - NC_000913.3

# %%
org_folder = "../data/e_coli/"

# %%
TF_list = pd.read_csv(org_folder+'TF_list.csv', index_col=0)
TF_list.drop(["curated information"], axis=1, inplace=True)

TF_list
# Out:
#                                TF          Organism          Strain  \
# index
# 0                            BaeR  Escherichia coli     K-12 MG1655
# 1                            CpxR  Escherichia coli     K-12 MG1655
# 2                             Cra  Escherichia coli     K-12 MG1655
# 3                             Fur  Escherichia coli     K-12 MG1655
# 4                            GadE  Escherichia coli     K-12 MG1655
# 5                            GadW  Escherichia coli     K-12 MG1655
# 6                            GadX  Escherichia coli     K-12 MG1655
# 7                            KdpE  Escherichia coli     K-12 MG1655
# 8                            PhoB  Escherichia coli     K-12 MG1655
# 9                            RpoB  Escherichia coli     K-12 MG1655
# 10                           YbaO  Escherichia coli     K-12 MG1655
# 11                           YbaQ  Escherichia coli     K-12 MG1655
# 12                           YdcI  Escherichia coli     K-12 MG1655
# 13                           YddM  Escherichia coli     K-12 MG1655
# 14                           YheO  Escherichia coli     K-12 MG1655
# 15                           YiaG  Escherichia coli     K-12 MG1655
# 16                           YieP  Escherichia coli     K-12 MG1655
# 17                           YihL  Escherichia coli     K-12 MG1655
# 18                           YihW  Escherichia coli     K-12 MG1655
# 19                           YjdC  Escherichia coli     K-12 MG1655
# 20                           YjhI  Escherichia coli     K-12 MG1655
# 21                           YneJ  Escherichia coli     K-12 MG1655
# 22                           YnfL  Escherichia coli     K-12 MG1655
# 23                           YpdC  Escherichia coli     K-12 MG1655
# 24                           YqhC  Escherichia coli     K-12 MG1655
# 25                           ZraR  Escherichia coli     K-12 MG1655
# 26                            Fur  Escherichia coli  O157:H7 EDL933
# 27                            Fur  Escherichia coli         SMS-3-5
# 28                            Fur  Escherichia coli          UMN026
# 29                            Dps  Escherichia coli     K-12 MG1655
# 30                            Fis  Escherichia coli     K-12 MG1655
# 31                           GyrA  Escherichia coli     K-12 MG1655
# 32                           GyrB  Escherichia coli     K-12 MG1655
# 33                           H-NS  Escherichia coli     K-12 MG1655
# 34                           HupA  Escherichia coli     K-12 MG1655
# 35                           HupB  Escherichia coli     K-12 MG1655
# 36                           InfA  Escherichia coli     K-12 MG1655
# 37                           MukB  Escherichia coli     K-12 MG1655
# 38                           RdgC  Escherichia coli     K-12 MG1655
# 39                            Rob  Escherichia coli     K-12 MG1655
# 40                           StpA  Escherichia coli     K-12 MG1655
# 41                           TopA  Escherichia coli     K-12 MG1655
# 42                            Tus  Escherichia coli     K-12 MG1655
# 43                           NarL  Escherichia coli     K-12 MG1655
# 44                           PuuR  Escherichia coli     K-12 MG1655
# 45                           RcsA  Escherichia coli     K-12 MG1655
# 46     RpoB (Cra and Crp KO exps)  Escherichia coli     K-12 MG1655
# 47                           FlhC  Escherichia coli     K-12 MG1655
# 48                           FlhD  Escherichia coli     K-12 MG1655
# 49                           FliA  Escherichia coli     K-12 MG1655
# 50                            Fnr  Escherichia coli     K-12 MG1655
# 51                           RpoD  Escherichia coli     K-12 MG1655
#
#                         Media  \
# index
# 0                          LB
# 1                          LB
# 2                          M9
# 3                          M9
# 4                          M9
# 5                          M9
# 6                          M9
# 7      Tris-maleic acid (TMA)
# 8                         M9P
# 9                          M9
# 10                         M9
# 11                         M9
# 12                         M9
# 13                         M9
# 14                         M9
# 15                         M9
# 16                         M9
# 17                         M9
# 18                         M9
# 19                         M9
# 20                         M9
# 21                         M9
# 22                         M9
# 23                         M9
# 24                         M9
# 25                         LB
# 26                         M9
# 27                         M9
# 28                         M9
# 29                         M9
# 30                         M9
# 31                         M9
# 32                         M9
# 33                         M9
# 34                         M9
# 35                         M9
# 36                         M9
# 37                         M9
# 38                         M9
# 39                         M9
# 40                         M9
# 41                         M9
# 42                         M9
# 43                         M9
# 44                         M9
# 45                         M9
# 46                         M9
# 47                         LB
# 48                         LB
# 49                         LB
# 50                       MOPS
# 51                       MOPS
#
#                                               Supplement    genome_id  \
# index
# 0                                                5% EtOH  NC_000913.3
# 1                                                5% EtOH  NC_000913.3
# 2          0.2% Fructose, Galactose, Acetate, or Glucose  NC_000913.3
# 3             0.1 mM FeCl2 or 0.2 mM 2,2-dipyridyl (DPD)  NC_000913.3
# 4                             pH 5.5 (adjusted with HCl)  NC_000913.3
# 5                             pH 5.5 (adjusted with HCl)  NC_000913.3
# 6                             pH 5.5 (adjusted with HCl)  NC_000913.3
# 7                                             0.1 mM KCl  NC_000913.3
# 8      Low phosphate concentration (10% of the M9 med...  NC_000913.3
# 9             0.1 mM FeCl2 or 0.2 mM 2,2-dipyridyl (DPD)  NC_000913.3
# 10                                                   NaN  NC_000913.3
# 11                                                   NaN  NC_000913.3
# 12                             pH 5.5, pH 7.0, or pH 8.5  NC_000913.3
# 13                                                   NaN  NC_000913.3
# 14                                                   NaN  NC_000913.3
# 15                                                   NaN  NC_000913.3
# 16                 100 mM 3-hydroxypropionic acid (3-HP)  NC_000913.3
# 17                                                   NaN  NC_000913.3
# 18                                                   NaN  NC_000913.3
# 19                                                   NaN  NC_000913.3
# 20                                                   NaN  NC_000913.3
# 21                                                   NaN  NC_000913.3
# 22                                                   NaN  NC_000913.3
# 23                                                   NaN  NC_000913.3
# 24                                                   NaN  NC_000913.3
# 25                                            1 mM ZnCl2  NC_000913.3
# 26            0.1 mM FeCl2 or 0.2 mM 2,2-dipyridyl (DPD)   AE005174.2
# 27            0.1 mM FeCl2 or 0.2 mM 2,2-dipyridyl (DPD)  NC_010498.1
# 28            0.1 mM FeCl2 or 0.2 mM 2,2-dipyridyl (DPD)   CU928163.2
# 29                                                   NaN  NC_000913.3
# 30                                                   NaN  NC_000913.3
# 31                                                   NaN  NC_000913.3
# 32                                                   NaN  NC_000913.3
# 33                                                   NaN  NC_000913.3
# 34                                                   NaN  NC_000913.3
# 35                                                   NaN  NC_000913.3
# 36                                                   NaN  NC_000913.3
# 37                                                   NaN  NC_000913.3
# 38                                                   NaN  NC_000913.3
# 39                                                   NaN  NC_000913.3
# 40                                                   NaN  NC_000913.3
# 41                                                   NaN  NC_000913.3
# 42                                                   NaN  NC_000913.3
# 43                                        100 mM Nitrate  NC_000913.3
# 44                                            Putrescine  NC_000913.3
# 45     250 uM Paraquat (PQ) treatment for 20 min with...  NC_000913.3
# 46                                          0.2% Acetate  NC_000913.3
# 47                                                   NaN  NC_000913.3
# 48                                                   NaN  NC_000913.3
# 49                                                   NaN  NC_000913.3
# 50                                                   NaN  NC_000913.3
# 51                                                   NaN  NC_000913.3
#
#       organism_id  num_binding_sites  num_samples  num_cond       project  \
# index
# 0          e_coli                NaN            4         1           TCS
# 1          e_coli                NaN            2         1           TCS
# 2          e_coli                NaN            8         4      known_TF
# 3          e_coli                NaN            4         2      known_TF
# 4          e_coli                NaN            2         1      known_TF
# 5          e_coli                NaN            2         1      known_TF
# 6          e_coli                NaN            2         1      known_TF
# 7          e_coli                NaN            2         1           TCS
# 8          e_coli                NaN            4         1           TCS
# 9          e_coli                NaN            4         2      known_TF
# 10         e_coli                4.0            2         1          yTF1
# 11         e_coli               41.0            2         1          yTF1
# 12         e_coli               40.0            6         3          yTF1
# 13         e_coli               18.0            2         1          yTF1
# 14         e_coli                4.0            2         1          yTF1
# 15         e_coli                NaN            2         1          yTF1
# 16         e_coli               23.0            4         1          yTF1
# 17         e_coli                NaN            2         1          yTF2
# 18         e_coli                NaN            2         1          yTF2
# 19         e_coli                NaN            2         1          yTF1
# 20         e_coli                NaN            2         1          yTF2
# 21         e_coli                NaN            2         1          yTF2
# 22         e_coli                NaN            2         1          yTF2
# 23         e_coli                NaN            2         1          yTF2
# 24         e_coli                NaN            2         1          yTF2
# 25         e_coli                NaN            3         1           TCS
# 26         e_coli                NaN            2         1        EDL933
# 27         e_coli                NaN            2         1       SMS-3-5
# 28         e_coli                NaN            2         1        UMN026
# 29         e_coli                NaN            4         2  conformation
# 30         e_coli                NaN            4         2  conformation
# 31         e_coli                NaN            4         2  conformation
# 32         e_coli                NaN            4         2  conformation
# 33         e_coli                NaN            4         2  conformation
# 34         e_coli                NaN            4         2  conformation
# 35         e_coli                NaN            4         2  conformation
# 36         e_coli                NaN            4         2  conformation
# 37         e_coli                NaN            4         2  conformation
# 38         e_coli                NaN            4         2  conformation
# 39         e_coli                NaN            4         2  conformation
# 40         e_coli                NaN            4         2  conformation
# 41         e_coli                NaN            4         2  conformation
# 42         e_coli                NaN            4         2  conformation
# 43         e_coli                NaN            2         1          Misc
# 44         e_coli                NaN            2         1          Misc
# 45         e_coli                NaN            2         1          Misc
# 46         e_coli                NaN            6         3          Misc
# 47         e_coli                NaN            2         1        public
# 48         e_coli                NaN            2         1        public
# 49         e_coli                NaN            2         1        public
# 50         e_coli                NaN            2         1        public
# 51         e_coli                NaN            4         1        public
#
#                                           binding tables    accession  \
# index
# 0                      EtOH|baer_EtOH_binding_table.json    GSE143856
# 1                      EtOH|cpxr_EtOH_binding_table.json    GSE143856
# 2      M9|cra_M9_binding_table.json;acetate|cra_aceta...          NaN
# 3      dpd|fur_dpd_binding_table.json;fe|fur_fe_bindi...          NaN
# 4                          M9|gade_M9_binding_table.json          NaN
# 5                          M9|gadw_M9_binding_table.json          NaN
# 6                          M9|gadx_M9_binding_table.json          NaN
# 7                        KCl|kdpe_KCl_binding_table.json    GSE143856
# 8                        M9P|phob_M9P_binding_table.json    GSE143856
# 9      dpd|rpob_dpd_binding_table.json;fe|rpob_fe_bin...          NaN
# 10                         M9|ybao_M9_binding_table.json          NaN
# 11                         M9|ybaq_M9_binding_table.json          NaN
# 12     ph5|ydci_ph5_binding_table.json;ph7|ydci_ph7_b...          NaN
# 13                         M9|yddm_M9_binding_table.json          NaN
# 14                         M9|yheo_M9_binding_table.json          NaN
# 15                         M9|yiag_M9_binding_table.json          NaN
# 16                         M9|yiep_M9_binding_table.json          NaN
# 17                       glc|yihl_glc_binding_table.json          NaN
# 18                       glc|yihw_glc_binding_table.json          NaN
# 19                         M9|yjdc_M9_binding_table.json          NaN
# 20                       glc|yjhi_glc_binding_table.json          NaN
# 21                       glc|ynej_glc_binding_table.json          NaN
# 22                       glc|ynfl_glc_binding_table.json          NaN
# 23                       glc|ypdc_glc_binding_table.json          NaN
# 24                         M9|yqhc_M9_binding_table.json          NaN
# 25                   ZnCl2|zrar_ZnCl2_binding_table.json          NaN
# 26                          Fe|fur_Fe_binding_table.json          NaN
# 27                          Fe|fur_Fe_binding_table.json          NaN
# 28                          Fe|fur_Fe_binding_table.json          NaN
# 29     expo|dps_expo_binding_table.json;sta|dps_sta_b...          NaN
# 30     expo|fis_expo_binding_table.json;sta|fis_sta_b...          NaN
# 31     expo|gyra_expo_binding_table.json;sta|gyra_sta...          NaN
# 32     expo|gyrb_expo_binding_table.json;sta|gyrb_sta...          NaN
# 33     expo|h-ns_expo_binding_table.json;sta|h-ns_sta...          NaN
# 34     expo|hupa_expo_binding_table.json;sta|hupa_sta...          NaN
# 35     expo|hupb_expo_binding_table.json;sta|hupb_sta...          NaN
# 36     expo|infa_expo_binding_table.json;sta|infa_sta...          NaN
# 37     expo|mukb_expo_binding_table.json;sta|mukb_sta...          NaN
# 38     expo|rdgc_expo_binding_table.json;sta|rdgc_sta...          NaN
# 39     expo|rob_expo_binding_table.json;sta|rob_sta_b...          NaN
# 40     expo|stpa_expo_binding_table.json;sta|stpa_sta...          NaN
# 41     expo|topa_expo_binding_table.json;sta|topa_sta...          NaN
# 42     expo|tus_expo_binding_table.json;sta|tus_sta_b...          NaN
# 43               nitrate|narl_nitrate_binding_table.json          NaN
# 44         putrescine|puur_putrescine_binding_table.json          NaN
# 45                                                   NaN          NaN
# 46     MG1655 ace|rpob (cra and crp ko exps)_MG1655 a...          NaN
# 47                                                   NaN  E-MTAB-2457
# 48                                                   NaN  E-MTAB-2457
# 49                                                   NaN  E-MTAB-2457
# 50                                                   NaN     GSE41195
# 51                                                   NaN     GSE41195
#
#                                                 doi           BWcond1_1_name  \
# index
# 0         https://doi.org/10.1128/mSystems.00980-20            bio-rep1 – R1
# 1         https://doi.org/10.1128/mSystems.00980-20                       R1
# 2                                               NaN                 Glu – R1
# 3                                               NaN                  Fe – R1
# 4                                               NaN                       R1
# 5                                               NaN                       R1
# 6                                               NaN                       R1
# 7         https://doi.org/10.1128/mSystems.00980-20                       R1
# 8         https://doi.org/10.1128/mSystems.00980-20            bio-rep1 – R1
# 9                                               NaN                  Fe – R1
# 10                                              NaN                       R1
# 11                                              NaN                       R1
# 12                                              NaN                 pH5 – R1
# 13                                              NaN                       R1
# 14                                              NaN                       R1
# 15                                              NaN                       R1
# 16                                              NaN                       R1
# 17                                              NaN                       R1
# 18                                              NaN                       R1
# 19                                              NaN                       R1
# 20                                              NaN                       R1
# 21                                              NaN                       R1
# 22                                              NaN                       R1
# 23                                              NaN                       R1
# 24                                              NaN                       R1
# 25                                              NaN            bio-rep1 – R1
# 26                                              NaN                       R1
# 27                                              NaN                       R1
# 28                                              NaN                       R1
# 29                                              NaN  exponential growth – R1
# 30                                              NaN  exponential growth – R1
# 31                                              NaN  exponential growth – R1
# 32                                              NaN  exponential growth – R1
# 33                                              NaN  exponential growth – R1
# 34                                              NaN  exponential growth – R1
# 35                                              NaN  exponential growth – R1
# 36                                              NaN  exponential growth – R1
# 37                                              NaN  exponential growth – R1
# 38                                              NaN  exponential growth – R1
# 39                                              NaN  exponential growth – R1
# 40                                              NaN  exponential growth – R1
# 41                                              NaN  exponential growth – R1
# 42                                              NaN  exponential growth – R1
# 43                                              NaN                       R1
# 44                                              NaN                       R1
# 45                                              NaN                       R1
# 46                                              NaN        control (WT) – R1
# 47     https://doi.org/10.1371/journal.pgen.1004649                       R1
# 48     https://doi.org/10.1371/journal.pgen.1004649                       R1
# 49     https://doi.org/10.1371/journal.pgen.1004649                       R1
# 50     https://doi.org/10.1371/journal.pgen.1003565           anaerobic – R1
# 51     https://doi.org/10.1371/journal.pgen.1003565             aerobic – R1
#
#                                              BWcond1_1  \
# index
# 0                                    BaeR_R1_S31_R1.bw
# 1                                      CpxRR1_S1_R1.bw
# 2                                         cra_glu_1.bw
# 3                                          fur_fe_1.bw
# 4                                            gade_1.bw
# 5                                            gadw_1.bw
# 6                                            gadx_1.bw
# 7                                   KdpeE_R2_S34_R1.bw
# 8                                     PhoB_1_S16_R1.bw
# 9                                          rpob_fe1.bw
# 10                                           ybao_1.bw
# 11                                           ybaq_1.bw
# 12                                       ydci_ph5_1.bw
# 13                                           yddm_1.bw
# 14                                           yheo_1.bw
# 15                                           yiag_1.bw
# 16                                           yiep_1.bw
# 17                                           yihl_1.bw
# 18                                           yihw_1.bw
# 19                                           yjdc_1.bw
# 20                                           yjhi_1.bw
# 21                                           ynej_1.bw
# 22                                           ynfl_1.bw
# 23                                           ypdc_1.bw
# 24                                           yqhc_1.bw
# 25                                     ZraR_1_S3_R1.bw
# 26                                  edl933furfinal1.bw
# 27                                     smsfurfinal1.bw
# 28                                  umn026furfinal1.bw
# 29                                       dps_expo_1.bw
# 30                                       fis_expo_1.bw
# 31                                      gyra_expo_1.bw
# 32                                      gyrb_expo_1.bw
# 33                                       hns_expo_1.bw
# 34                                      hupa_expo_1.bw
# 35                                      hupb_expo_1.bw
# 36                                      infa_expo_1.bw
# 37                                      mukb_expo_1.bw
# 38                                      rdgc_expo_1.bw
# 39                                       rob_expo_1.bw
# 40                                      stpa_expo_1.bw
# 41                                      topa_expo_1.bw
# 42                                       tus_expo_1.bw
# 43                                   narl_nitrate_1.bw
# 44                                puur_putrescine_1.bw
# 45                                     rcsa_oxida_1.bw
# 46                                 mg1655_ace_rpob1.bw
# 47                                        ERR475432.bw
# 48                                        ERR475429.bw
# 49                                        ERR475428.bw
# 50           GSM1010219_FNR_IP_ChIP-seq_Anaerobic_A.bw
# 51     GSM1010221_Sigma70_IP_ChIP-seq_Aerobic_A_SET.bw
#
#                 BWcond1_2_name  \
# index
# 0                bio-rep1 – R2
# 1                           R2
# 2                     Glu – R2
# 3                      Fe – R2
# 4                           R2
# 5                           R2
# 6                           R2
# 7                           R2
# 8                bio-rep1 – R2
# 9                      Fe – R2
# 10                          R2
# 11                          R2
# 12                    pH5 – R2
# 13                          R2
# 14                          R2
# 15                          R2
# 16                          R2
# 17                          R2
# 18                          R2
# 19                          R2
# 20                          R2
# 21                          R2
# 22                          R2
# 23                          R2
# 24                          R2
# 25               bio-rep1 – R2
# 26                          R2
# 27                          R2
# 28                          R2
# 29     exponential growth – R2
# 30     exponential growth – R2
# 31     exponential growth – R2
# 32     exponential growth – R2
# 33     exponential growth – R2
# 34     exponential growth – R2
# 35     exponential growth – R2
# 36     exponential growth – R2
# 37     exponential growth – R2
# 38     exponential growth – R2
# 39     exponential growth – R2
# 40     exponential growth – R2
# 41     exponential growth – R2
# 42     exponential growth – R2
# 43                          R2
# 44                          R2
# 45                          R2
# 46           control (WT) – R2
# 47                          R2
# 48                          R2
# 49                          R2
# 50              anaerobic – R2
# 51                aerobic – R2
#
#                                              BWcond1_2  \
# index
# 0                                    BaeR_R1_S31_R2.bw
# 1                                      CpxRR2_S2_R2.bw
# 2                                         cra_glu_2.bw
# 3                                          fur_fe_2.bw
# 4                                            gade_2.bw
# 5                                            gadw_2.bw
# 6                                            gadx_2.bw
# 7                                   KdpeE_R2_S34_R2.bw
# 8                                     PhoB_1_S16_R2.bw
# 9                                          rpob_fe2.bw
# 10                                           ybao_2.bw
# 11                                           ybaq_2.bw
# 12                                       ydci_ph5_2.bw
# 13                                           yddm_2.bw
# 14                                           yheo_2.bw
# 15                                           yiag_2.bw
# 16                                           yiep_2.bw
# 17                                           yihl_2.bw
# 18                                           yihw_2.bw
# 19                                           yjdc_2.bw
# 20                                           yjhi_2.bw
# 21                                           ynej_2.bw
# 22                                           ynfl_2.bw
# 23                                           ypdc_2.bw
# 24                                           yqhc_2.bw
# 25                                     ZraR_1_S3_R2.bw
# 26                                  edl933furfinal2.bw
# 27                                     smsfurfinal2.bw
# 28                                  umn026furfinal2.bw
# 29                                       dps_expo_2.bw
# 30                                       fis_expo_2.bw
# 31                                      gyra_expo_2.bw
# 32                                      gyrb_expo_2.bw
# 33                                       hns_expo_2.bw
# 34                                      hupa_expo_2.bw
# 35                                      hupb_expo_2.bw
# 36                                      infa_expo_2.bw
# 37                                      mukb_expo_2.bw
# 38                                      rdgc_expo_2.bw
# 39                                       rob_expo_2.bw
# 40                                      stpa_expo_2.bw
# 41                                      topa_expo_2.bw
# 42                                       tus_expo_2.bw
# 43                                   narl_nitrate_2.bw
# 44                                puur_putrescine_2.bw
# 45                                     rcsa_oxida_2.bw
# 46                                 mg1655_ace_rpob2.bw
# 47                                        ERR475433.bw
# 48                                        ERR475430.bw
# 49                                        ERR475431.bw
# 50           GSM1010220_FNR_IP_ChIP-seq_Anaerobic_B.bw
# 51     GSM1072326_Sigma70_IP_ChIP-seq_Aerobic_B_SET.bw
#
#                BWcond2_1_name  \
# index
# 0               bio-rep2 – R1
# 1                         NaN
# 2                    Fru – R1
# 3                    DPD – R1
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8               bio-rep2 – R1
# 9                    DPD – R1
# 10                        NaN
# 11                        NaN
# 12                   pH7 – R1
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                   3HP – R1
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25              bio-rep2 – R1
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29     stationary growth – R1
# 30     stationary growth – R1
# 31     stationary growth – R1
# 32     stationary growth – R1
# 33     stationary growth – R1
# 34     stationary growth – R1
# 35     stationary growth – R1
# 36     stationary growth – R1
# 37     stationary growth – R1
# 38     stationary growth – R1
# 39     stationary growth – R1
# 40     stationary growth – R1
# 41     stationary growth – R1
# 42     stationary growth – R1
# 43                        NaN
# 44                        NaN
# 45                        NaN
# 46                cra-KO – R1
# 47                        NaN
# 48                        NaN
# 49                        NaN
# 50                        NaN
# 51             anaerobic – R1
#
#                                                BWcond2_1  \
# index
# 0                                     BaerR_R2_S32_R1.bw
# 1                                                    NaN
# 2                                           cra_fru_1.bw
# 3                                           fur_dpd_1.bw
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                        PhoB_2_S6_R1.bw
# 9                                           rpob_dpd1.bw
# 10                                                   NaN
# 11                                                   NaN
# 12                                         ydci_ph7_1.bw
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                         yiep_3hp_1.bw
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                       ZraR_2_S4_R1.bw
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                          dps_sta_1.bw
# 30                                          fis_sta_1.bw
# 31                                         gyra_sta_1.bw
# 32                                         gyrb_sta_1.bw
# 33                                          hns_sta_1.bw
# 34                                         hupa_sta_1.bw
# 35                                         hupb_sta_1.bw
# 36                                         infa_sta_1.bw
# 37                                         mukb_sta_1.bw
# 38                                         rdgc_sta_1.bw
# 39                                          rob_sta_1.bw
# 40                                         stpa_sta_1.bw
# 41                                         topa_sta_1.bw
# 42                                          tus_sta_1.bw
# 43                                                   NaN
# 44                                                   NaN
# 45                                                   NaN
# 46                                   cra_ko_ace_rpob1.bw
# 47                                                   NaN
# 48                                                   NaN
# 49                                                   NaN
# 50                                                   NaN
# 51     GSM1010222_Sigma70_IP_ChIP-seq_Anaerobic_A_SET.bw
#
#                BWcond2_2_name  \
# index
# 0               bio-rep2 – R2
# 1                         NaN
# 2                    Fru – R2
# 3                    DPD – R2
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8               bio-rep2 – R2
# 9                    DPD – R2
# 10                        NaN
# 11                        NaN
# 12                   pH7 – R2
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                   3HP – R2
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29     stationary growth – R2
# 30     stationary growth – R2
# 31     stationary growth – R2
# 32     stationary growth – R2
# 33     stationary growth – R2
# 34     stationary growth – R2
# 35     stationary growth – R2
# 36     stationary growth – R2
# 37     stationary growth – R2
# 38     stationary growth – R2
# 39     stationary growth – R2
# 40     stationary growth – R2
# 41     stationary growth – R2
# 42     stationary growth – R2
# 43                        NaN
# 44                        NaN
# 45                        NaN
# 46                cra-KO – R2
# 47                        NaN
# 48                        NaN
# 49                        NaN
# 50                        NaN
# 51             anaerobic – R2
#
#                                                BWcond2_2 BWcond3_1_name  \
# index
# 0                                     BaerR_R2_S32_R2.bw            NaN
# 1                                                    NaN            NaN
# 2                                           cra_fru_2.bw       Gal – R1
# 3                                           fur_dpd_2.bw            NaN
# 4                                                    NaN            NaN
# 5                                                    NaN            NaN
# 6                                                    NaN            NaN
# 7                                                    NaN            NaN
# 8                                        PhoB_2_S6_R2.bw            NaN
# 9                                           rpob_dpd2.bw            NaN
# 10                                                   NaN            NaN
# 11                                                   NaN            NaN
# 12                                         ydci_ph7_2.bw       pH8 – R1
# 13                                                   NaN            NaN
# 14                                                   NaN            NaN
# 15                                                   NaN            NaN
# 16                                         yiep_3hp_2.bw            NaN
# 17                                                   NaN            NaN
# 18                                                   NaN            NaN
# 19                                                   NaN            NaN
# 20                                                   NaN            NaN
# 21                                                   NaN            NaN
# 22                                                   NaN            NaN
# 23                                                   NaN            NaN
# 24                                                   NaN            NaN
# 25                                                   NaN            NaN
# 26                                                   NaN            NaN
# 27                                                   NaN            NaN
# 28                                                   NaN            NaN
# 29                                          dps_sta_2.bw            NaN
# 30                                          fis_sta_2.bw            NaN
# 31                                         gyra_sta_2.bw            NaN
# 32                                         gyrb_sta_2.bw            NaN
# 33                                          hns_sta_2.bw            NaN
# 34                                         hupa_sta_2.bw            NaN
# 35                                         hupb_sta_2.bw            NaN
# 36                                         infa_sta_2.bw            NaN
# 37                                         mukb_sta_2.bw            NaN
# 38                                         rdgc_sta_2.bw            NaN
# 39                                          rob_sta_2.bw            NaN
# 40                                         stpa_sta_2.bw            NaN
# 41                                         topa_sta_2.bw            NaN
# 42                                          tus_sta_2.bw            NaN
# 43                                                   NaN            NaN
# 44                                                   NaN            NaN
# 45                                                   NaN            NaN
# 46                                   cra_ko_ace_rpob2.bw    crp-KO – R1
# 47                                                   NaN            NaN
# 48                                                   NaN            NaN
# 49                                                   NaN            NaN
# 50                                                   NaN            NaN
# 51     GSM1072327_Sigma70_IP_ChIP-seq_Anaerobic_B_SET.bw            NaN
#
#                  BWcond3_1 BWcond3_2_name            BWcond3_2 BWcond4_1_name  \
# index
# 0                      NaN            NaN                  NaN            NaN
# 1                      NaN            NaN                  NaN            NaN
# 2             cra_gal_1.bw       Gal – R2         cra_gal_2.bw       Ace – R1
# 3                      NaN            NaN                  NaN            NaN
# 4                      NaN            NaN                  NaN            NaN
# 5                      NaN            NaN                  NaN            NaN
# 6                      NaN            NaN                  NaN            NaN
# 7                      NaN            NaN                  NaN            NaN
# 8                      NaN            NaN                  NaN            NaN
# 9                      NaN            NaN                  NaN            NaN
# 10                     NaN            NaN                  NaN            NaN
# 11                     NaN            NaN                  NaN            NaN
# 12           ydci_ph8_1.bw       pH8 – R2        ydci_ph8_2.bw            NaN
# 13                     NaN            NaN                  NaN            NaN
# 14                     NaN            NaN                  NaN            NaN
# 15                     NaN            NaN                  NaN            NaN
# 16                     NaN            NaN                  NaN            NaN
# 17                     NaN            NaN                  NaN            NaN
# 18                     NaN            NaN                  NaN            NaN
# 19                     NaN            NaN                  NaN            NaN
# 20                     NaN            NaN                  NaN            NaN
# 21                     NaN            NaN                  NaN            NaN
# 22                     NaN            NaN                  NaN            NaN
# 23                     NaN            NaN                  NaN            NaN
# 24                     NaN            NaN                  NaN            NaN
# 25                     NaN            NaN                  NaN            NaN
# 26                     NaN            NaN                  NaN            NaN
# 27                     NaN            NaN                  NaN            NaN
# 28                     NaN            NaN                  NaN            NaN
# 29                     NaN            NaN                  NaN            NaN
# 30                     NaN            NaN                  NaN            NaN
# 31                     NaN            NaN                  NaN            NaN
# 32                     NaN            NaN                  NaN            NaN
# 33                     NaN            NaN                  NaN            NaN
# 34                     NaN            NaN                  NaN            NaN
# 35                     NaN            NaN                  NaN            NaN
# 36                     NaN            NaN                  NaN            NaN
# 37                     NaN            NaN                  NaN            NaN
# 38                     NaN            NaN                  NaN            NaN
# 39                     NaN            NaN                  NaN            NaN
# 40                     NaN            NaN                  NaN            NaN
# 41                     NaN            NaN                  NaN            NaN
# 42                     NaN            NaN                  NaN            NaN
# 43                     NaN            NaN                  NaN            NaN
# 44                     NaN            NaN                  NaN            NaN
# 45                     NaN            NaN                  NaN            NaN
# 46     crp_ko_ace_rpob1.bw    crp-KO – R2  crp_ko_ace_rpob2.bw            NaN
# 47                     NaN            NaN                  NaN            NaN
# 48                     NaN            NaN                  NaN            NaN
# 49                     NaN            NaN                  NaN            NaN
# 50                     NaN            NaN                  NaN            NaN
# 51                     NaN            NaN                  NaN            NaN
#
#           BWcond4_1 BWcond4_2_name     BWcond4_2
# index
# 0               NaN            NaN           NaN
# 1               NaN            NaN           NaN
# 2      cra_ace_1.bw       Ace – R2  cra_ace_2.bw
# 3               NaN            NaN           NaN
# 4               NaN            NaN           NaN
# 5               NaN            NaN           NaN
# 6               NaN            NaN           NaN
# 7               NaN            NaN           NaN
# 8               NaN            NaN           NaN
# 9               NaN            NaN           NaN
# 10              NaN            NaN           NaN
# 11              NaN            NaN           NaN
# 12              NaN            NaN           NaN
# 13              NaN            NaN           NaN
# 14              NaN            NaN           NaN
# 15              NaN            NaN           NaN
# 16              NaN            NaN           NaN
# 17              NaN            NaN           NaN
# 18              NaN            NaN           NaN
# 19              NaN            NaN           NaN
# 20              NaN            NaN           NaN
# 21              NaN            NaN           NaN
# 22              NaN            NaN           NaN
# 23              NaN            NaN           NaN
# 24              NaN            NaN           NaN
# 25              NaN            NaN           NaN
# 26              NaN            NaN           NaN
# 27              NaN            NaN           NaN
# 28              NaN            NaN           NaN
# 29              NaN            NaN           NaN
# 30              NaN            NaN           NaN
# 31              NaN            NaN           NaN
# 32              NaN            NaN           NaN
# 33              NaN            NaN           NaN
# 34              NaN            NaN           NaN
# 35              NaN            NaN           NaN
# 36              NaN            NaN           NaN
# 37              NaN            NaN           NaN
# 38              NaN            NaN           NaN
# 39              NaN            NaN           NaN
# 40              NaN            NaN           NaN
# 41              NaN            NaN           NaN
# 42              NaN            NaN           NaN
# 43              NaN            NaN           NaN
# 44              NaN            NaN           NaN
# 45              NaN            NaN           NaN
# 46              NaN            NaN           NaN
# 47              NaN            NaN           NaN
# 48              NaN            NaN           NaN
# 49              NaN            NaN           NaN
# 50              NaN            NaN           NaN
# 51              NaN            NaN           NaN

# %%
strain = 'NC_000913.3'
DF_gene_info = pd.read_csv(org_folder+strain+'/annotation/gene_info.csv',index_col=0)
DF_gene_info['start_codon_pos'] = [row.start if row.strand == '+' else row.stop for idx,row in DF_gene_info.iterrows()]
TRN = pd.read_csv(org_folder+strain+'/annotation/trn.csv',index_col=0)

DF_gene_info.head()
# Out:
#        start  stop strand gene_name  length   operon  \
# b0001    189   255      +      thrL      66  thrLABC
# b0002    336  2799      +      thrA    2463  thrLABC
# b0003   2800  3733      +      thrB     933  thrLABC
# b0004   3733  5020      +      thrC    1287  thrLABC
# b0005   5233  5530      +      yaaX     297     yaaX
#
#                                        cog  start_codon_pos
# b0001                    No COG Annotation              189
# b0002                    No COG Annotation              336
# b0003  Amino acid transport and metabolism             2800
# b0004  Amino acid transport and metabolism             3733
# b0005                     Function unknown             5233

# %%
for TF_index in range(len(TF_list)):

    TF_name= TF_list.TF[TF_index].lower()
    print(TF_name)
    strain = TF_list.genome_id[TF_index]
    
    if strain != 'NC_000913.3':
        continue

    #find files and format
    curated_loc = glob.glob(org_folder+strain+"/curated_input/"+TF_name+"_*.gff")
    curated_loc.sort()
    curated_files = [i.split("\\")[-1] for i in curated_loc] # change split to "/" on linux
    curated_cond = [i.split("_")[1] for i in curated_files]
    table_string =";".join([curated_cond[i]+"|"+TF_name+"_"+curated_cond[i]+'_binding_table.json' for i in range(len(curated_loc))])
    if table_string!='':
        TF_list.loc[TF_index, 'binding tables'] = table_string
    else:
        TF_list.loc[TF_index, 'binding tables'] = "NA"
    TF_list.loc[TF_index, 'num_cond'] = max(1,len(curated_loc))
    
    # write plot data files to folders
    for file_index in range(len(curated_files)):
        file = curated_files[file_index]
        df = pd.read_csv(org_folder+strain+"/curated_input/"+file,index_col=0, 
                                 delimiter='\t', header=None, 
                                 names = ['ref','condition', 'condition_name', 
                                          "binding_peak_start",'binding_peak_end', 
                                          'binding_peak_strength', 'direction', '.','ID'])
        df = df.set_index(pd.Series(range(1,len(df)+1)))
        peak_annot_DF = annotate_peaks(TF_list.TF[TF_index], curated_cond[file_index], df, 500, DF_gene_info)
        final_annot_DF = validate_peak_info(peak_annot_DF,DF_gene_info)
        final_annot_DF.to_json(org_folder+strain+"/table/"+TF_name+"_"+curated_cond[file_index]+'_binding_table.json',orient='records')
        binding_width_gen(TF_list.TF[TF_index], df, org_folder+strain+"/binding_widths/")
        peak_position_gen(TF_list.TF[TF_index], final_annot_DF, org_folder+strain+"/positions/")
        
        #venn diagrams
        try:
            if strain == 'NC_000913.3' and TF_list.TF[TF_index].split(" ")[0] in TRN.index:
                venn_files = Venn_data_gen(final_annot_DF, TRN)
                venn_files.to_json(org_folder+strain+"/venn/"+TF_list.TF[TF_index]+'_venn.json',orient='records')
        except:
            continue
# Out:
# baer
# cpxr
# cra
# fur
# gade
# gadw
# gadx
# kdpe
# phob
# rpob
# ybao
# ybaq
# ydci
# yddm
# yheo
# yiag
# yiep
# yihl
# yihw
# yjdc
# yjhi
# ynej
# ynfl
# ypdc
# yqhc
# zrar
# fur
# fur
# fur
# dps
# fis
# gyra
# gyrb
# h-ns
# hupa
# hupb
# infa
# mukb
# rdgc
# rob
# stpa
# topa
# tus
# narl
# puur
# rcsa
# rpob (cra and crp ko exps)
# flhc
# flhd
# flia
# fnr
# rpod

# %%
new_TF_list = TF_list.copy()
new_TF_list['binding tables'].fillna('NA',inplace=True)
new_TF_list.insert(12, "curated information", new_TF_list['binding tables'] != 'NA')
new_TF_list.to_csv(org_folder+'TF_list.csv')

# %% [markdown]
# # Other Organisms

# %%
def other_gff_to_geneinfo(org, strain):
    genes = pd.read_csv('../data'+'/'+org+'/'+strain+'/annotation/genes.gff',index_col=0, delimiter='\t', header=None, 
                        names = ['genome', 'ref', 'type', 'start','stop','.', 'strand', '-','details'])
    genes["locus_tag"] = [gene_detail[0].split(" ")[1] for gene_detail in genes.details.str.split("; ")]
    genes.set_index('locus_tag', inplace=True)
    genes = genes.drop(['.', '-','ref','type'], axis=1)

    return(genes)

# %%
def closest_locus(peak_start, peak_end, gene_info):
    min_name = ''
    min_value = float('inf')
    for i in range(len(gene_info)):
        if abs(peak_start - gene_info.stop[i]) < min_value:
            min_name = gene_info.index[i]
            min_value = abs(peak_start - gene_info.stop[i])
        if abs(peak_end - gene_info.start[i]) < min_value:
            min_name = gene_info.index[i]
            min_value = abs(peak_end - gene_info.start[i])

    return(min_name)

# %%
def other_table_gen(TF_name, TF_condition, peak_df, gene_info):
    
    table = peak_df.copy()
    table["index"] = [TF_name+'-'+str(i+1) for i in range(len(table))]
    table["condition"] = [TF_name.lower() + " + " + TF_condition for i in range(len(table))]
    table.drop(["condition_name",".", "ID"], axis=1, inplace=True)
    table["target_locus"] = [closest_locus(table.binding_peak_start.iloc[i], 
                                           table.binding_peak_end.iloc[i],
                                           gene_info) for i in range(len(table))]
    table["target_genes"] = table["target_locus"]
    table["closest_gene"] = table["target_locus"]

    return(table)

# %%
def other_peak_position_gen(TF, final_annot_DF,out_dir, DF_gene_info): 
    peak_scatter_df = pd.DataFrame(columns=final_annot_DF.columns.to_list()+['gene'] +['normalized_dist'])
    counter=0

    for i in range(len(final_annot_DF)):
        peak = final_annot_DF.iloc[i,:]
        peak_center = np.mean([peak.binding_peak_start, peak.binding_peak_end])

        for gene in peak.target_genes.split(","):
            gene_info = DF_gene_info[DF_gene_info.index == gene]
            try:
                if gene_info.strand.iloc[0] == "-":
                    dist = float((gene_info.stop - peak_center)/(gene_info.stop-gene_info.start+1))
                else:
                    dist = float((peak_center - gene_info.start)/(gene_info.stop-gene_info.start+1))
                peak_scatter_df.loc[counter] = peak.to_list()+[gene, dist]
                counter+=1
            except:
                continue
    peak_scatter_df['binding_peak_center'] = peak_scatter_df.binding_peak_start/2 + peak_scatter_df.binding_peak_end/2
    peak_scatter_df.drop(['direction'], axis=1, inplace=True)
    cols = ['index', 'condition', 'binding_peak_start', 'binding_peak_end', 'binding_peak_strength', 'target_locus', 
            'target_genes', 'gene', 'normalized_dist', 'binding_peak_center']
    peak_scatter_df = peak_scatter_df[cols]
    peak_scatter_df.to_csv(out_dir+TF+'_positions.csv')

# %%
org_folder = "../data/all_other/"

# %%
TF_list = pd.read_csv(org_folder+'TF_list.csv', index_col=0)
TF_list.drop(["curated information"], axis=1, inplace=True)

TF_list
# Out:
#             TF                     Organism                      Strain  \
# index
# 0          Fur        Klebsiella pneumoniae                   MGH 78578
# 0          Fur           Pseudomonas putida                      KT2440
# 1      Sigma D           Pseudomonas putida                      KT2440
# 0          Fur          Salmonella enterica             Typhimurium LT2
# 1         YdcI          Salmonella enterica             Typhimurium LT2
# 0          Fur            Shigella flexneri                   2a, 2457T
# 0         CodY        Staphylococcus aureus              LAC chromosome
# 1         SigS        Staphylococcus aureus              USA300_TCH1516
# 2         VraR        Staphylococcus aureus              USA300_TCH1516
# 0          Fur  Yersinia pseudotuberculosis                    IP 32953
# 0         FleQ       Pseudomonas aeruginosa                        PAO1
# 1         GbdR       Pseudomonas aeruginosa                        PAO1
# 2         PchR       Pseudomonas aeruginosa                        PAO1
# 3         PhoB       Pseudomonas aeruginosa                        PAO1
# 4         SphR       Pseudomonas aeruginosa                        PAO1
# 5         MvfR       Pseudomonas aeruginosa                        PAO1
# 6         SoxR       Pseudomonas aeruginosa                        PAO1
# 7         RpoN       Pseudomonas aeruginosa                        PAO1
# 8          Vfr       Pseudomonas aeruginosa                        PAO1
# 9         AlgR       Pseudomonas aeruginosa                        PAO1
# 10        ExsA       Pseudomonas aeruginosa                        PAO1
# 11        GacA       Pseudomonas aeruginosa                        PAO1
# 12        MexT       Pseudomonas aeruginosa                        PAO1
# 13        WspR       Pseudomonas aeruginosa                        PAO1
# 0         HrdB      Streptomyces coelicolor                       A3(2)
# 1         NdgR      Streptomyces coelicolor                       A3(2)
# 0         AmrZ      Pseudomonas fluorescens                        F113
# 0         Lsr2      Streptomyces venezuelae                  ATCC 10712
# 0        LexA1       Leptospira interrogans  Copenhageni Fiocruz L1-130
#
#                Media Supplement      genome_id           organism_id  \
# index
# 0                 M9         Fe     CP000647.1          k_pneumoniae
# 0                 M9         Fe    NC_002947.4              p_putida
# 1                 M9        NaN    NC_002947.4              p_putida
# 0                 M9         Fe    NC_003197.2            s_enterica
# 1                 M9   pH5, MES    NC_003197.2            s_enterica
# 0                 M9         Fe     AE014073.1            s_flexneri
# 0               RPMI     10% LB     CP035369.1              s_aureus
# 1               RPMI     10% LB      NC_010079              s_aureus
# 2               RPMI     10% LB      NC_010079              s_aureus
# 0                BHI         Fe  NZ_CP009712.1  y_pseudotuberculosis
# 0                 LB        NaN    NC_002516.1          p_aeruginosa
# 1                 LB        NaN    NC_002516.1          p_aeruginosa
# 2                 LB        NaN    NC_002516.1          p_aeruginosa
# 3                 LB        NaN    NC_002516.1          p_aeruginosa
# 4                 LB        NaN    NC_002516.1          p_aeruginosa
# 5                 LB        NaN    NC_002516.1          p_aeruginosa
# 6                 LB        NaN    NC_002516.1          p_aeruginosa
# 7                 LB        NaN    NC_002516.1          p_aeruginosa
# 8                 LB        NaN    NC_002516.1          p_aeruginosa
# 9                 LB        NaN    NC_002516.1          p_aeruginosa
# 10                LB        NaN    NC_002516.1          p_aeruginosa
# 11                LB        NaN    NC_002516.1          p_aeruginosa
# 12                LB        NaN    NC_002516.1          p_aeruginosa
# 13                LB        NaN    NC_002516.1          p_aeruginosa
# 0                 MS        NaN    NC_003888.3          s_coelicolor
# 1      minimal media        NaN    NC_003888.3          s_coelicolor
# 0        SA (low Fe)        NaN    NC_016830.1         p_fluorescens
# 0                 MS        NaN    NC_018750.1          s_venezuelae
# 0               EMJH        NaN    NC_005823.1         l_interrogans
#
#        num_binding_sites  num_samples  num_cond         project  \
# index
# 0                    NaN            2         1        MGH78578
# 0                    NaN            1         1           2457T
# 1                    NaN            2         1           2457T
# 0                    NaN            1         1             LT2
# 1                    NaN            6         3             LT2
# 0                    NaN            2         1           2457T
# 0                    NaN            2         1             LAC
# 1                    NaN            8         1  USA300_TCH1516
# 2                    NaN            2         1  USA300_TCH1516
# 0                    NaN            2         1           2457T
# 0                    NaN            2         1     public_data
# 1                    NaN            2         1     public_data
# 2                    NaN            2         1     public_data
# 3                    NaN            2         1     public_data
# 4                    NaN            2         1     public_data
# 5                    NaN            2         1     public_data
# 6                    NaN            2         1     public_data
# 7                    NaN            2         1     public_data
# 8                    NaN            2         1     public_data
# 9                    NaN            2         1     public_data
# 10                   NaN            2         1     public_data
# 11                   NaN            2         1     public_data
# 12                   NaN            2         1     public_data
# 13                   NaN            2         1     public_data
# 0                    NaN            3         1     public_data
# 1                    NaN            1         1     public_data
# 0                    NaN            1         1     public_data
# 0                    NaN            2         1     public_data
# 0                    NaN            2         1     public_data
#
#                                           binding tables    accession  \
# index
# 0                           Fe|fur_Fe_binding_table.json          NaN
# 0                           fe|fur_fe_binding_table.json          NaN
# 1                       M9|sigma d_M9_binding_table.json          NaN
# 0                           Fe|fur_Fe_binding_table.json          NaN
# 1      MES2|ydci_MES2_binding_table.json;MES5|ydci_ME...          NaN
# 0                           Fe|fur_Fe_binding_table.json          NaN
# 0                          M9|cody_M9_binding_table.json          NaN
# 1                      RPMI|sigs_RPMI_binding_table.json          NaN
# 2                      RPMI|vrar_RPMI_binding_table.json          NaN
# 0                           Fe|fur_Fe_binding_table.json          NaN
# 0                                                    NaN    GSE128430
# 1                                                    NaN    GSE128430
# 2                                                    NaN    GSE128430
# 3                                                    NaN    GSE128430
# 4                                                    NaN    GSE128430
# 5                                                    NaN     GSE65356
# 6                                                    NaN     GSE65356
# 7                                                    NaN     GSE65356
# 8                                                    NaN     GSE65356
# 9                                                    NaN     GSE65356
# 10                                                   NaN     GSE65356
# 11                                                   NaN     GSE65356
# 12                                                   NaN     GSE65356
# 13                                                   NaN     GSE65356
# 0                                                    NaN  E-MTAB-6926
# 1                                                    NaN     GSE59010
# 0                                                    NaN    SRP039494
# 0                                                    NaN    GSE115439
# 0                                                    NaN     GSE73688
#
#                                               doi BWcond1_1_name  \
# index
# 0                                             NaN             R1
# 0                                             NaN             R1
# 1                                             NaN             R1
# 0                                             NaN            NaN
# 1                                             NaN      MES5 – R1
# 0                                             NaN             R1
# 0                                             NaN             R1
# 1                                             NaN        M1 – R1
# 2                                             NaN             R1
# 0                                             NaN             R1
# 0      https://doi.org/10.1038/s41467-019-10778-w             R1
# 1      https://doi.org/10.1038/s41467-019-10778-w             R1
# 2      https://doi.org/10.1038/s41467-019-10778-w             R1
# 3      https://doi.org/10.1038/s41467-019-10778-w             R1
# 4      https://doi.org/10.1038/s41467-019-10778-w             R1
# 5              https://doi.org/10.1093/nar/gkv747             R1
# 6              https://doi.org/10.1093/nar/gkv747             R1
# 7              https://doi.org/10.1093/nar/gkv747             R1
# 8              https://doi.org/10.1093/nar/gkv747             R1
# 9              https://doi.org/10.1093/nar/gkv747             R1
# 10             https://doi.org/10.1093/nar/gkv747             R1
# 11             https://doi.org/10.1093/nar/gkv747             R1
# 12             https://doi.org/10.1093/nar/gkv747             R1
# 13             https://doi.org/10.1093/nar/gkv747             R1
# 0             https://doi.org/10.1093/nar/gky1018             R1
# 1       https://doi.org/10.1186/s12864-015-1311-0             R1
# 0        https://doi.org/10.1186/1471-2164-15-237             R1
# 0             https://doi.org/10.7554/eLife.47691             R1
# 0             https://doi.org/10.1093/nar/gkv1536             R1
#
#                              BWcond1_1 BWcond1_2_name  \
# index
# 0                     klebfurfinal1.bw             R2
# 0            putidafurfinal1_202003.bw            NaN
# 1               putidaSigmaD_202003.bw             R2
# 0                                  NaN             R2
# 1               salmone_ydcI_MES5_1.bw      MES5 – R2
# 0                    shigella_fur_1.bw             R2
# 0                StaphLAC_new_cody1.bw             R2
# 1                  StaphTCH_sigs_M1.bw        M1 – R2
# 2      StaphTCH_vraR_7H7C11purified.bw             R2
# 0                    yersifurfinal1.bw             R2
# 0                        SRR8742210.bw             R2
# 1                        SRR8742212.bw             R2
# 2                        SRR8742214.bw             R2
# 3                        SRR8742216.bw             R2
# 4                        SRR8742218.bw             R2
# 5                        SRR1776542.bw             R2
# 6                        SRR1776544.bw             R2
# 7                        SRR1776546.bw             R2
# 8                        SRR1776548.bw             R2
# 9                        SRR1776550.bw             R2
# 10                       SRR1776552.bw             R2
# 11                       SRR1776554.bw             R2
# 12                       SRR1776558.bw             R2
# 13                       SRR1776560.bw             R2
# 0                        ERR2639621.bw             R2
# 1                        SRR1503874.bw            NaN
# 0                        SRR1184483.bw            NaN
# 0                        SRR7282569.bw             R2
# 0                        SRR2549977.bw             R2
#
#                               BWcond1_2 BWcond2_1_name  \
# index
# 0                      klebfurfinal2.bw            NaN
# 0                                   NaN            NaN
# 1                putidaSigmaD_202005.bw            NaN
# 0                Salmonella_Fur_Fe_2.bw            NaN
# 1                salmone_ydcI_MES5_2.bw      MES5 – R3
# 0                     shigella_fur_2.bw            NaN
# 0                 StaphLAC_new_cody2.bw            NaN
# 1                   Staph_SigS_M1_R2.bw        M2 – R1
# 2      StaphTCH_vraR_13F12F6purified.bw            NaN
# 0                     yersifurfinal2.bw            NaN
# 0                         SRR8742211.bw            NaN
# 1                         SRR8742213.bw            NaN
# 2                         SRR8742215.bw            NaN
# 3                         SRR8742217.bw            NaN
# 4                         SRR8742219.bw            NaN
# 5                         SRR1776543.bw            NaN
# 6                         SRR1776545.bw            NaN
# 7                         SRR1776547.bw            NaN
# 8                         SRR1776549.bw            NaN
# 9                         SRR1776551.bw            NaN
# 10                        SRR1776553.bw            NaN
# 11                        SRR1776555.bw            NaN
# 12                        SRR1776559.bw            NaN
# 13                        SRR1776561.bw            NaN
# 0                         ERR2639622.bw             R3
# 1                                   NaN            NaN
# 0                                   NaN            NaN
# 0                         SRR7282569.bw            NaN
# 0                         SRR2549979.bw            NaN
#
#                     BWcond2_1 BWcond2_2_name               BWcond2_2  \
# index
# 0                         NaN            NaN                     NaN
# 0                         NaN            NaN                     NaN
# 1                         NaN            NaN                     NaN
# 0                         NaN            NaN                     NaN
# 1      salmone_ydcI_MES5_3.bw      MES5 – R4  salmone_ydcI_MES5_4.bw
# 0                         NaN            NaN                     NaN
# 0                         NaN            NaN                     NaN
# 1         StaphTCH_sigs_M2.bw        M2 – R2     Staph_SigS_M2_R2.bw
# 2                         NaN            NaN                     NaN
# 0                         NaN            NaN                     NaN
# 0                         NaN            NaN                     NaN
# 1                         NaN            NaN                     NaN
# 2                         NaN            NaN                     NaN
# 3                         NaN            NaN                     NaN
# 4                         NaN            NaN                     NaN
# 5                         NaN            NaN                     NaN
# 6                         NaN            NaN                     NaN
# 7                         NaN            NaN                     NaN
# 8                         NaN            NaN                     NaN
# 9                         NaN            NaN                     NaN
# 10                        NaN            NaN                     NaN
# 11                        NaN            NaN                     NaN
# 12                        NaN            NaN                     NaN
# 13                        NaN            NaN                     NaN
# 0               ERR2639623.bw            NaN                     NaN
# 1                         NaN            NaN                     NaN
# 0                         NaN            NaN                     NaN
# 0                         NaN            NaN                     NaN
# 0                         NaN            NaN                     NaN
#
#       BWcond3_1_name               BWcond3_1 BWcond3_2_name  \
# index
# 0                NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
# 1                NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
# 1           ph5 – R1  salmone_ydcI_ph55_1.bw       ph5 – R2
# 0                NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
# 1            M3 – R1     StaphTCH_sigs_M3.bw        M3 – R2
# 2                NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
# 1                NaN                     NaN            NaN
# 2                NaN                     NaN            NaN
# 3                NaN                     NaN            NaN
# 4                NaN                     NaN            NaN
# 5                NaN                     NaN            NaN
# 6                NaN                     NaN            NaN
# 7                NaN                     NaN            NaN
# 8                NaN                     NaN            NaN
# 9                NaN                     NaN            NaN
# 10               NaN                     NaN            NaN
# 11               NaN                     NaN            NaN
# 12               NaN                     NaN            NaN
# 13               NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
# 1                NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
# 0                NaN                     NaN            NaN
#
#                     BWcond3_2 BWcond4_1_name            BWcond4_1  \
# index
# 0                         NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 1      salmone_ydcI_ph55_2.bw            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 1         Staph_SigS_M3_R2.bw        M4 – R1  StaphTCH_sigs_M4.bw
# 2                         NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
# 5                         NaN            NaN                  NaN
# 6                         NaN            NaN                  NaN
# 7                         NaN            NaN                  NaN
# 8                         NaN            NaN                  NaN
# 9                         NaN            NaN                  NaN
# 10                        NaN            NaN                  NaN
# 11                        NaN            NaN                  NaN
# 12                        NaN            NaN                  NaN
# 13                        NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
# 0                         NaN            NaN                  NaN
#
#       BWcond4_2_name            BWcond4_2
# index
# 0                NaN                  NaN
# 0                NaN                  NaN
# 1                NaN                  NaN
# 0                NaN                  NaN
# 1                NaN                  NaN
# 0                NaN                  NaN
# 0                NaN                  NaN
# 1            M4 – R2  Staph_SigS_M4_R2.bw
# 2                NaN                  NaN
# 0                NaN                  NaN
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN
# 5                NaN                  NaN
# 6                NaN                  NaN
# 7                NaN                  NaN
# 8                NaN                  NaN
# 9                NaN                  NaN
# 10               NaN                  NaN
# 11               NaN                  NaN
# 12               NaN                  NaN
# 13               NaN                  NaN
# 0                NaN                  NaN
# 1                NaN                  NaN
# 0                NaN                  NaN
# 0                NaN                  NaN
# 0                NaN                  NaN

# %%
for TF_index in range(len(TF_list)):

    TF_name= TF_list.TF.iloc[TF_index].lower()
    org_id = TF_list.organism_id.iloc[TF_index]
    genome_id = TF_list.genome_id.iloc[TF_index]

    #find files and format
    curated_loc = glob.glob("../data/"+org_id+"/"+genome_id+"/"+"/curated_input/"+TF_name+"_*.gff")
    curated_loc.sort()
    curated_files = [i.split("\\")[-1] for i in curated_loc] # different for linux vs windows
    curated_cond = [i.split("_")[1] for i in curated_files]
    table_string =";".join([curated_cond[i]+"|"+TF_name+"_"+curated_cond[i]+'_binding_table.json' for i in range(len(curated_loc))])
    if table_string!='':
        TF_list['binding tables'].iloc[TF_index] = table_string
    else:
        TF_list['binding tables'].iloc[TF_index] = "NA"
    TF_list['num_cond'].iloc[TF_index] = max(1,len(curated_loc))
    gene_info = other_gff_to_geneinfo(org_id, genome_id)
    
#     write plot data files to folders
    for file_index in range(len(curated_files)):
        file = curated_files[file_index]
        df = pd.read_csv("../data/"+org_id+"/"+genome_id+"/"+"/curated_input/"+file,index_col=0, 
                                 delimiter='\t', header=None, 
                                 names = ['ref','condition', 'condition_name', 
                                          "binding_peak_start",'binding_peak_end', 
                                          'binding_peak_strength', 'direction', '.','ID'])
        df = df.set_index(pd.Series(range(1,len(df)+1)))
        final_annot_DF = other_table_gen(TF_list.TF.iloc[TF_index], curated_cond[file_index], df, gene_info)
        final_annot_DF.to_json("../data/"+org_id+"/"+genome_id+"/table/"+TF_name+"_"+curated_cond[file_index]+'_binding_table.json',orient='records')
        binding_width_gen(TF_list.TF.iloc[TF_index], df, "../data/"+org_id+"/"+genome_id+"/binding_widths/")
        other_peak_position_gen(TF_list.TF.iloc[TF_index], final_annot_DF, "../data/"+org_id+"/"+genome_id+"/positions/", gene_info)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-139-54e1928e7f9a> in <module>
#      27                                           'binding_peak_strength', 'direction', '.','ID'])
#      28         df = df.set_index(pd.Series(range(1,len(df)+1)))
# ---> 29         final_annot_DF = other_table_gen(TF_list.TF.iloc[TF_index], curated_cond[file_index], df, gene_info)
#      30         final_annot_DF.to_json("../data/"+org_id+"/"+genome_id+"/table/"+TF_name+"_"+curated_cond[file_index]+'_binding_table.json',orient='records')
#      31         binding_width_gen(TF_list.TF.iloc[TF_index], df, "../data/"+org_id+"/"+genome_id+"/binding_widths/")
#
# <ipython-input-132-b2350181469d> in other_table_gen(TF_name, TF_condition, peak_df, gene_info)
#       7     table["target_locus"] = [closest_locus(table.binding_peak_start.iloc[i],
#       8                                            table.binding_peak_end.iloc[i],
# ----> 9                                            gene_info) for i in range(len(table))]
#      10     table["target_genes"] = table["target_locus"]
#      11     table["closest_gene"] = table["target_locus"]
#
# <ipython-input-132-b2350181469d> in <listcomp>(.0)
#       7     table["target_locus"] = [closest_locus(table.binding_peak_start.iloc[i],
#       8                                            table.binding_peak_end.iloc[i],
# ----> 9                                            gene_info) for i in range(len(table))]
#      10     table["target_genes"] = table["target_locus"]
#      11     table["closest_gene"] = table["target_locus"]
#
# <ipython-input-131-6257ff788dbd> in closest_locus(peak_start, peak_end, gene_info)
#       6             min_name = gene_info.index[i]
#       7             min_value = abs(peak_start - gene_info.stop[i])
# ----> 8         if abs(peak_end - gene_info.start[i]) < min_value:
#       9             min_name = gene_info.index[i]
#      10             min_value = abs(peak_end - gene_info.start[i])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
new_TF_list = TF_list.copy()
new_TF_list.insert(12, "curated information", TF_list['binding tables'] != 'NA')
new_TF_list.to_csv(org_folder+'TF_list.csv')

#individual file updates
for org in new_TF_list.organism_id.unique():
    new_TF_list[new_TF_list.organism_id == org].to_csv("../data/"+org+"/TF_list.csv")

# %% [markdown]
# # E. coli - other strains

# %%
org_folder = "../data/e_coli/"

TF_list = pd.read_csv(org_folder+'TF_list.csv', index_col=0)
TF_list.drop(["curated information"], axis=1, inplace=True)

TF_list.head()
# Out:
#          TF          Organism       Strain Media  \
# index
# 0      BaeR  Escherichia coli  K-12 MG1655    LB
# 1      CpxR  Escherichia coli  K-12 MG1655    LB
# 2       Cra  Escherichia coli  K-12 MG1655    M9
# 3       Fur  Escherichia coli  K-12 MG1655    M9
# 4      GadE  Escherichia coli  K-12 MG1655    M9
#
#                                           Supplement    genome_id organism_id  \
# index
# 0                                            5% EtOH  NC_000913.3      e_coli
# 1                                            5% EtOH  NC_000913.3      e_coli
# 2      0.2% Fructose, Galactose, Acetate, or Glucose  NC_000913.3      e_coli
# 3         0.1 mM FeCl2 or 0.2 mM 2,2-dipyridyl (DPD)  NC_000913.3      e_coli
# 4                         pH 5.5 (adjusted with HCl)  NC_000913.3      e_coli
#
#        num_binding_sites  num_samples  num_cond   project  \
# index
# 0                    NaN            4         1       TCS
# 1                    NaN            2         1       TCS
# 2                    NaN            8         4  known_TF
# 3                    NaN            4         2  known_TF
# 4                    NaN            2         1  known_TF
#
#                                           binding tables BWcond1_1_name  \
# index
# 0                      EtOH|baer_EtOH_binding_table.json  bio-rep1 – R1
# 1                      EtOH|cpxr_EtOH_binding_table.json             R1
# 2      M9|cra_M9_binding_table.json;acetate|cra_aceta...       Glu – R1
# 3      dpd|fur_dpd_binding_table.json;fe|fur_fe_bindi...        Fe – R1
# 4                          M9|gade_M9_binding_table.json             R1
#
#                BWcond1_1 BWcond1_2_name          BWcond1_2 BWcond2_1_name  \
# index
# 0      BaeR_R1_S31_R1.bw  bio-rep1 – R2  BaeR_R1_S31_R2.bw  bio-rep2 – R1
# 1        CpxRR1_S1_R1.bw             R2    CpxRR2_S2_R2.bw            NaN
# 2           cra_glu_1.bw       Glu – R2       cra_glu_2.bw       Fru – R1
# 3            fur_fe_1.bw        Fe – R2        fur_fe_2.bw       DPD – R1
# 4              gade_1.bw             R2          gade_2.bw            NaN
#
#                 BWcond2_1 BWcond2_2_name           BWcond2_2 BWcond3_1_name  \
# index
# 0      BaerR_R2_S32_R1.bw  bio-rep2 – R2  BaerR_R2_S32_R2.bw            NaN
# 1                     NaN            NaN                 NaN            NaN
# 2            cra_fru_1.bw       Fru – R2        cra_fru_2.bw       Gal – R1
# 3            fur_dpd_1.bw       DPD – R2        fur_dpd_2.bw            NaN
# 4                     NaN            NaN                 NaN            NaN
#
#           BWcond3_1 BWcond3_2_name     BWcond3_2 BWcond4_1_name     BWcond4_1  \
# index
# 0               NaN            NaN           NaN            NaN           NaN
# 1               NaN            NaN           NaN            NaN           NaN
# 2      cra_gal_1.bw       Gal – R2  cra_gal_2.bw       Ace – R1  cra_ace_1.bw
# 3               NaN            NaN           NaN            NaN           NaN
# 4               NaN            NaN           NaN            NaN           NaN
#
#       BWcond4_2_name     BWcond4_2
# index
# 0                NaN           NaN
# 1                NaN           NaN
# 2           Ace – R2  cra_ace_2.bw
# 3                NaN           NaN
# 4                NaN           NaN

# %%
for TF_index in range(len(TF_list)):
    
    TF_name= TF_list.TF.iloc[TF_index].lower()
    org_id = TF_list.organism_id.iloc[TF_index]
    genome_id = TF_list.genome_id.iloc[TF_index]
    
    if genome_id == 'NC_000913.3':
            continue
            
    #find files and format
    curated_loc = glob.glob("../data/"+org_id+"/"+genome_id+"/"+"/curated_input/"+TF_name+"_*.gff")
    curated_loc.sort()
    curated_files = [i.split("/")[-1] for i in curated_loc]
    curated_cond = [i.split("_")[1] for i in curated_files]
    table_string =";".join([curated_cond[i]+"|"+TF_name+"_"+curated_cond[i]+'_binding_table.json' for i in range(len(curated_loc))])
    if table_string!='':
        TF_list['binding tables'].iloc[TF_index] = table_string
    else:
        TF_list['binding tables'].iloc[TF_index] = "NA"
    TF_list['num_cond'].iloc[TF_index] = max(1,len(curated_loc))
    gene_info = other_gff_to_geneinfo(org_id, genome_id)
    
#     write plot data files to folders
    for file_index in range(len(curated_files)):
#         try:
        file = curated_files[file_index]
        df = pd.read_csv("../data/"+org_id+"/"+genome_id+"/"+"/curated_input/"+file,index_col=0, 
                                 delimiter='\t', header=None, 
                                 names = ['ref','condition', 'condition_name', 
                                          "binding_peak_start",'binding_peak_end', 
                                          'binding_peak_strength', 'direction', '.','ID'])
        df = df.set_index(pd.Series(range(1,len(df)+1)))
        final_annot_DF = other_table_gen(TF_list.TF.iloc[TF_index], curated_cond[file_index], df, gene_info)
        final_annot_DF.to_json("../data/"+org_id+"/"+genome_id+"/table/"+TF_name+"_"+curated_cond[file_index]+'_binding_table.json',orient='records')
        binding_width_gen(TF_list.TF.iloc[TF_index], df, "../data/"+org_id+"/"+genome_id+"/binding_widths/")
        other_peak_position_gen(TF_list.TF.iloc[TF_index], final_annot_DF, "../data/"+org_id+"/"+genome_id+"/positions/", gene_info)
#         except:
#             print(TF_name, file)
#             continue
# Out:
# /home/katherine/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
new_TF_list = TF_list.copy()
new_TF_list['binding tables'].fillna('NA',inplace=True)
new_TF_list.insert(12, "curated information", new_TF_list['binding tables'] != 'NA')
new_TF_list.to_csv(org_folder+'TF_list.csv')
